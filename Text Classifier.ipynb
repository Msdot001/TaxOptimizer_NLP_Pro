# %%
import numpy as np
import pandas as pd
import spacy
import glob 
from tqdm import tqdm
from spacy import displacy
from spacy.lang.nl.stop_words import STOP_WORDS
from string import punctuation
from spacy.lang.nl import Dutch

# %%
# load a medium sized dutch language model in spacy
nlp = spacy.load('nl_core_news_md')

# %%
#Ref for attempting summarization https://www.numpyninja.com/post/text-summarization-through-use-of-spacy-library

# %%
myfile = open("TaxRelatedFile.txt")

# %%
text = myfile.read()

# %%
print(text)
# Out:
# BRUSSELS HOOFDSTEDELIJK GEWEST
# 5 MAART 2020. - Besluit van de Brusselse Hoofdstedelijke Regering tot wijziging van het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen in het kader van de overname van de dienst van de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling door het Brussels Hoofdstedelijk Gewest
#
#
# De Brusselse Hoofdstedelijke Regering,
# Gelet op de bijzondere wet van 8 augustus 1980 tot hervorming der instellingen, artikel 20;
# Gelet op het Wetboek van de met inkomstenbelastingen gelijkgestelde belastingen, artikelen 5, Â§ 1, tweede lid, gewijzigd bij de ordonnantie van 28 november 2019;
# Gelet op het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen;
# Gelet op de gelijkekansentest uitgevoerd op 22 november 2019 in toepassing van artikel 2 van de ordonnantie van 4 oktober 2018 tot invoering van de gelijkekansentest;
# Gelet op advies 66.928/4 van de Raad van State, gegeven op 12 februari 2020, met toepassing van artikel 84, Â§ 1, eerste lid, 2Â°, van de wetten op de Raad van State, gecoÃ¶rdineerd op 12 januari 1973;
# Overwegende dat de ordonnantie van 28 november 2019 tot wijziging van het Wetboek van de met inkomstenbelastingen gelijkgestelde belastingen in het kader van de overname van de dienst van de verkeersbelasting op de autovoertuigen en van de belasting op de inverkeerstelling door het Brussels Hoofdstedelijk Gewest, in zijn artikelen 3, 1Â°, a), iv, et b), 12, 13 en 15, 2Â° en 3Â° de bepalingen die momenteel vervat zijn in de artikelen 15, Â§ 1, en 58 van het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen, heeft geÃ¯ntegreerd in de artikelen 5, eerste lid, 3Â° bis, en tweede lid, en 96, eerste lid, 3Â°, a) en tweede lid van het Wetboek van de met inkomstenbelastingen gelijkgestelde belastingen; dat deze bepalingen derhalve moeten worden opgeheven;
# Overwegende dat de ordonnantie van 19 december 2019 houdende de wijziging van de procedurele bepalingen in het kader van de overname van de dienst van de verkeersbelastingen en houdende diverse bepalingen tot gevolg heeft dat de ordonnantie van 6 maart 2019 betreffende de Brusselse Codex Fiscale Procedure en haar uitvoeringsbesluit van toepassing zijn op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit ontstaat vanaf 1 januari 2020; dat de procedurele bepalingen vervat in Titel I van de het besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen, dus, voor wat deze belastingen betreft, moeten worden opgeheven, voor zover hun doel rechtstreeks wordt overgenomen in de genoemde Codex en zijn uitvoeringsbesluiten;
# Op voorstel van de Minister van FinanciÃ«n, na beraadslaging,
# Besluit :
# HOOFDSTUK 1. - Inleidende bepaling
# Artikel 1. Dit besluit is uitsluitend van toepassing op:
# 1Â° de verkeersbelasting op de autovoertuigen;
# 2Â° de belasting op de inverkeerstelling.
# HOOFDSTUK 2. - Wijzigingen van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit vÃ³Ã³r 1 januari 2020 valt
# Art. 2. De bepalingen van dit hoofdstuk zijn uitsluitend van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit vÃ³Ã³r 1 januari 2020 valt.
# Art. 3. Artikel 8 van het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen, vervangen bij het koninklijk besluit van 27 februari 2019, wordt vervangen als volgt:
# "Art. 8. Onverminderd de bepalingen van artikel 24, zijn de met de inkomstenbelastingen gelijkgestelde belastingen te betalen bij de rekenplichtige van de ontvangsten belast met fiscale zaken van de Gewestelijke Overheidsdienst Brussel Fiscaliteit of, in geval van zijn afwezigheid, bij de plaatsvervangend rekenplichtige van de ontvangsten belast met fiscale zaken van dezelfde dienst.".
# Art. 4. In artikel 11 van hetzelfde besluit, gewijzigd bij het koninklijk besluit van 14 april 1993 en bij het koninklijk besluit van 9 november 1999 en vervangen bij het koninklijk besluit van 17 februari 2019, worden de woorden " op de financiÃ«le rekening van het ontvangkantoor Belastingen-auto's" vervangen door de woorden "volgens de door de Gewestelijke Overheidsdienst Brussel Fiscaliteit aangegeven modaliteiten".
# HOOFDSTUK 3. - Wijzigingen van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit vanaf 1 januari 2020 valt
# Art. 5. De bepalingen van dit hoofdstuk zijn uitsluitend van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit vanaf 1 januari 2020 valt.
# Art. 6. In artikel 15 van hetzelfde besluit, gewijzigd bij het koninklijk besluit van 10 november 1980 en bij de wet van 19 februari 1990, worden de volgende wijzigingen aangebracht :
# 1Â° paragraaf 1 wordt opgeheven;
# 2Â° in paragraaf 2 worden de volgende wijzigingen aangebracht:
# a) in de bepaling onder 1Â° worden de woorden "wet van 27 december 1974 betreffende de taxidiensten en ingericht krachtens een vergunning regelmatig afgeleverd ter uitvoering van gezegde wet" vervangen door de woorden "toepasselijke gewestelijke regelgeving en ingericht krachtens een vergunning regelmatig afgeleverd ter uitvoering van de genoemde regelgeving";
# b) de bepaling onder 2Â° wordt vervangen als volgt:
# "2Â° op de autovoertuigen die uitsluitend aangewend worden tot een dienst voor het verhuren van voertuigen met bestuurder onder de voorwaarden bepaald bij de toepasselijke gewestelijke regelgeving en ingericht krachtens een vergunning regelmatig afgeleverd ter uitvoering van de genoemde regelgeving;".
# Art. 7. In hetzelfde besluit worden de volgende bepalingen opgeheven:
# 1Â° de titel I, die bestaat uit de artikelen 1 tot en met 14 ;
# 2Â° het hoofdstuk III van titel II, dat bestaat uit de artikelen 23 en 24;
# 3Â° het hoofdstuk IV van titel II, dat bestaat uit de artikelen 25 en 26;
# 4Â° het hoofdstuk V van titel II, dat bestaat uit de artikelen 27 tot en met 29;
# 5Â° in het titel V, artikel 58, gewijzigd bij het koninklijk besluit van 14 april 1993.
# HOOFDSTUK 4. - Wijzigingen van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling ongeacht de datum van het belastbaar feit
# Art. 8. In artikel 30, Â§ 2, van hetzelfde besluit opnieuw opgenomen bij het koninklijk besluit van 17 december 1984, worden de volgende wijzigingen aangebracht:
# 1Â° in het eerste lid worden de woorden "gedaan door middel van een formulier dat door Administratie der directe belastingen wordt verstrekt" vervangen door de woorden "ingediend bij de Gewestelijke Overheidsdienst Brussel Fiscaliteit";
# 2Â° het tweede lid wordt opgeheven.
# HOOFDSTUK 5. - Inwerkingtreding en uitvoering
# Art. 9. Dit besluit heeft uitwerking met ingang van 1 januari 2020.
# Art. 10. De Minister bevoegd voor FinanciÃ«n is belast met de uitvoering van dit besluit.
# Brussel, 5 maart 2020.
# Voor de Brusselse Hoofdstedelijke Regering :
# De Minister-President van de Brusselse Hoofdstedelijke Regering,
# R. VERVOORT
# De Minister van de Brusselse Hoofdstedelijke Regering, belast met FinanciÃ«n, Begroting, Openbaar ambt en de Promotie van Meertaligheid,
# S. GATZ

# %%
len(text)
# Out:
# 7592

# %%
doc=nlp(text)

# %%
for sent in doc.sents:
    print(sent)
# Out:
# BRUSSELS HOOFDSTEDELIJK GEWEST
#
# 5 MAART 2020.
# - Besluit van de Brusselse Hoofdstedelijke Regering tot wijziging van het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen in het kader van de overname van de dienst van de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling door het Brussels Hoofdstedelijk Gewest
#
#
# De Brusselse Hoofdstedelijke Regering,
#
# Gelet op de bijzondere wet van 8 augustus 1980 tot hervorming der instellingen, artikel 20;
#
# Gelet op het Wetboek van de met inkomstenbelastingen gelijkgestelde belastingen, artikelen
# 5, Â§
# 1, tweede lid, gewijzigd bij de ordonnantie van 28 november 2019;
#
# Gelet op het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen;
#
# Gelet op de gelijkekansentest uitgevoerd op 22 november 2019 in toepassing van artikel 2 van de ordonnantie van 4 oktober 2018 tot invoering van de gelijkekansentest;
#
# Gelet op advies 66.928/4 van de Raad van State, gegeven op 12 februari 2020, met toepassing van artikel 84, Â§ 1, eerste lid, 2Â°, van de wetten op de Raad van State, gecoÃ¶rdineerd op 12 januari 1973;
#
# Overwegende dat de ordonnantie van 28 november 2019 tot wijziging van het Wetboek van de met inkomstenbelastingen gelijkgestelde belastingen in het kader van de overname van de dienst van de verkeersbelasting op de autovoertuigen en van de belasting op de inverkeerstelling door het Brussels Hoofdstedelijk Gewest, in zijn artikelen 3, 1Â°, a), iv, et b), 12, 13 en 15, 2Â° en 3Â° de bepalingen die momenteel vervat zijn in de artikelen 15, Â§ 1, en 58 van het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen, heeft geÃ¯ntegreerd in de artikelen
# 5, eerste lid, 3Â° bis, en tweede lid, en 96, eerste lid, 3Â°, a) en tweede lid van het Wetboek van de met inkomstenbelastingen gelijkgestelde belastingen; dat deze bepalingen derhalve moeten worden opgeheven;
#
#
# Overwegende dat de ordonnantie van 19 december 2019 houdende de wijziging van de procedurele bepalingen in het kader van de overname van de dienst van de verkeersbelastingen en houdende diverse bepalingen tot gevolg heeft dat de ordonnantie van 6 maart 2019 betreffende de Brusselse Codex
# Fiscale Procedure en haar uitvoeringsbesluit van toepassing zijn op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit ontstaat vanaf 1 januari 2020; dat de procedurele bepalingen vervat in Titel I van de het besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen, dus, voor wat deze belastingen betreft, moeten worden opgeheven, voor zover hun doel rechtstreeks wordt overgenomen in de genoemde Codex en zijn uitvoeringsbesluiten;
#
# Op voorstel van de Minister van FinanciÃ«n, na beraadslaging,
#
# Besluit :
#
# HOOFDSTUK 1.
# -
# Inleidende bepaling
#
# Artikel 1.
# Dit besluit is uitsluitend van toepassing op:
# 1Â°
# de verkeersbelasting op de autovoertuigen;
# 2Â
# ° de belasting op de inverkeerstelling.
#
#
# HOOFDSTUK 2.
# - Wijzigingen van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit vÃ³Ã³r 1 januari 2020 valt
# Art. 2.
# De bepalingen van dit hoofdstuk zijn uitsluitend van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit vÃ³Ã³r 1 januari 2020 valt.
#
#
# Art. 3.
# Artikel 8 van het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen, vervangen bij het koninklijk besluit van 27 februari 2019, wordt vervangen als volgt:
# "Art. 8.
# Onverminderd de bepalingen van artikel 24, zijn de met de inkomstenbelastingen gelijkgestelde belastingen te betalen bij de rekenplichtige van de ontvangsten belast met fiscale zaken van de Gewestelijke Overheidsdienst
# Brussel
# Fiscaliteit of, in geval van zijn afwezigheid, bij de plaatsvervangend rekenplichtige van de ontvangsten belast met fiscale zaken van dezelfde dienst.
# ".
#
#
# Art. 4.
# In artikel 11 van hetzelfde besluit, gewijzigd bij het koninklijk besluit van 14 april 1993 en bij het koninklijk besluit van 9 november 1999 en vervangen bij het koninklijk besluit van 17 februari 2019, worden de woorden " op de financiÃ«le rekening van het ontvangkantoor Belastingen-auto's" vervangen door de woorden "volgens de door de Gewestelijke Overheidsdienst
# Brussel
# Fiscaliteit aangegeven modaliteiten".
#
#
# HOOFDSTUK 3.
# - Wijzigingen van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit vanaf 1 januari 2020 valt
# Art. 5.
# De bepalingen van dit hoofdstuk zijn uitsluitend van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit vanaf 1 januari 2020 valt.
#
#
# Art. 6.
# In artikel 15 van hetzelfde besluit, gewijzigd bij het koninklijk besluit van 10 november 1980 en bij de wet van 19 februari 1990, worden de volgende wijzigingen aangebracht :
# 1Â° paragraaf 1 wordt opgeheven;
# 2Â° in paragraaf 2 worden de volgende wijzigingen aangebracht:
# a) in de bepaling onder 1Â° worden de woorden "wet van 27 december 1974 betreffende de taxidiensten en ingericht krachtens een vergunning regelmatig afgeleverd ter uitvoering van gezegde wet" vervangen door de woorden "toepasselijke gewestelijke regelgeving en ingericht krachtens een vergunning regelmatig afgeleverd ter uitvoering van de genoemde regelgeving";
# b)
# de bepaling onder 2Â° wordt vervangen als volgt:
# "2Â° op de autovoertuigen die uitsluitend aangewend worden tot een dienst voor het verhuren van voertuigen met bestuurder onder de voorwaarden bepaald bij de toepasselijke gewestelijke regelgeving en ingericht krachtens een vergunning regelmatig afgeleverd ter uitvoering van de genoemde regelgeving;
# ".
#
#
# Art. 7.
# In hetzelfde besluit worden de volgende bepalingen opgeheven:
# 1Â°
# de titel I, die bestaat uit de artikelen 1 tot en met 14 ;
# 2Â° het hoofdstuk III van titel II, dat bestaat uit de artikelen 23 en 24;
# 3Â°
# het hoofdstuk IV van titel II, dat bestaat uit de artikelen 25 en 26;
# 4Â°
# het hoofdstuk V van titel II, dat bestaat uit de artikelen 27 tot en met 29;
# 5Â° in het titel V, artikel 58, gewijzigd bij het koninklijk besluit van 14 april 1993.
#
#
# HOOFDSTUK 4.
# - Wijzigingen van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling ongeacht de datum van het belastbaar feit
# Art. 8.
# In artikel 30, Â§ 2, van hetzelfde besluit opnieuw opgenomen bij het koninklijk besluit van 17 december 1984, worden de volgende wijzigingen aangebracht:
# 1Â° in het eerste lid worden de woorden "gedaan door middel van een formulier dat door Administratie der directe belastingen wordt verstrekt" vervangen door de woorden "ingediend bij de Gewestelijke Overheidsdienst
# Brussel
# Fiscaliteit";
#
# 2Â
# °
# het tweede lid wordt opgeheven.
#
#
# HOOFDSTUK 5.
# - Inwerkingtreding en uitvoering
# Art. 9.
# Dit besluit heeft uitwerking met ingang van 1 januari 2020.
#
# Art. 10.
# De Minister bevoegd voor FinanciÃ«n is belast met de uitvoering van dit besluit.
#
#
# Brussel, 5 maart 2020.
#
#
# Voor de Brusselse Hoofdstedelijke Regering :
#
# De Minister-President van de Brusselse Hoofdstedelijke Regering,
#
# R. VERVOORT
#
# De Minister van de Brusselse Hoofdstedelijke Regering, belast met FinanciÃ«n, Begroting, Openbaar ambt en de Promotie van Meertaligheid,
# S. GATZ

# %%
#Take a look at how many words are in the document
len(doc)
# Out:
# 1350

# %%
#Look document-level attributes
dir(doc)
# Out:
# ['_',
#  '__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '_bulk_merge',
#  '_context',
#  '_get_array_attrs',
#  '_realloc',
#  '_vector',
#  '_vector_norm',
#  'cats',
#  'char_span',
#  'copy',
#  'count_by',
#  'doc',
#  'ents',
#  'extend_tensor',
#  'from_array',
#  'from_bytes',
#  'from_dict',
#  'from_disk',
#  'from_docs',
#  'get_extension',
#  'get_lca_matrix',
#  'has_annotation',
#  'has_extension',
#  'has_unknown_spaces',
#  'has_vector',
#  'is_nered',
#  'is_parsed',
#  'is_sentenced',
#  'is_tagged',
#  'lang',
#  'lang_',
#  'mem',
#  'noun_chunks',
#  'noun_chunks_iterator',
#  'remove_extension',
#  'retokenize',
#  'sentiment',
#  'sents',
#  'set_ents',
#  'set_extension',
#  'similarity',
#  'spans',
#  'tensor',
#  'text',
#  'text_with_ws',
#  'to_array',
#  'to_bytes',
#  'to_dict',
#  'to_disk',
#  'to_json',
#  'to_utf8_array',
#  'user_data',
#  'user_hooks',
#  'user_span_hooks',
#  'user_token_hooks',
#  'vector',
#  'vector_norm',
#  'vocab']

# %%
print(doc[5])
# Out:
# MAART

# %% [markdown]
# Using spaCy's built-in visualizer to detect named entities in the document

# %%
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BRUSSELS HOOFDSTEDELIJK GEWEST
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5 MAART 2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . - Besluit van de
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brusselse Hoofdstedelijke Regering
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  tot wijziging van het koninklijk besluit van
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8 juli 1970
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen in het kader van de overname van de dienst van de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling door het
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brussels Hoofdstedelijk Gewest
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br></br></br>De
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brusselse Hoofdstedelijke Regering
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,</br>Gelet op de bijzondere wet van
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8 augustus 1980
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  tot hervorming der instellingen, artikel
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ;</br>Gelet op het
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wetboek van de met inkomstenbelastingen gelijkgestelde belastingen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
# , artikelen
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# , Â§
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tweede
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  lid, gewijzigd bij de ordonnantie van
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     28 november 2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ;</br>Gelet op het koninklijk besluit van
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8 juli 1970
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen;</br>Gelet op de gelijkekansentest uitgevoerd op
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     22 november 2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  in toepassing van artikel
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  van de ordonnantie van
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4 oktober 2018
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  tot invoering van de gelijkekansentest;</br>Gelet op advies
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     66.928/4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  van de
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Raad van State
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , gegeven op
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12 februari 2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , met toepassing van artikel
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     84
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# , Â§
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eerste
#     <span style="font-size: 0.8em; font-weight: bold; line-heig

# %% [markdown]
# Look up at label LAW, some tokens related to taxes were identified by spaCy with this label

# %%
spacy.explain("LAW")
# Out:
# 'Named documents made into laws.'

# %% [markdown]
# ### Lemmatization

# %%
review = str(" ".join([i.lemma_ for i in doc]))

# %%
doc = nlp(review)
spacy.displacy.render(doc, style='ent',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BRUSSELS HOOFDSTEDELIJK gEWEST
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  </br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5 MAART 2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  . - besluit van de
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brussels
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  hoofdstedelijk regering tot wijziging van het koninklijk besluit van
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8 juli 1970
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  houdenen de algemeen verordening betreffen de met de inkomstenbelasting lijkgestelen belasting in het kader van de overname van de dienst van de verkeersbelasting op de autovoertuig en de belasting op de inverkeerstelling door het
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brussels Hoofdstedelijk Gewest
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  </br></br></br> de
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brussels
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  hoofdstedelijk regering , </br> Gelet op de bijzonder wet van
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8 augustus 1980
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  tot hervorming de instelling , artikel
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  ; </br> gelet op het wetboek van de met inkomstenbelasting lijkgestelen belasting , artikel
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  , Â§
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     twee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  lid , wijzigen bij de ordonnantie van
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     28 november 2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  ; </br> gelet op het koninklijk besluit van
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8 juli 1970
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  houdenen de algemeen verordening betreffen de met de inkomstenbelasting gelijkgestelde belasting ; </br> Gelet op de
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gelijkekansentest
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  uit_voeren op
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     22 november 2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  in toepassing van artikel
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  van de ordonnantie van
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4 oktober 2018
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  tot invoering van de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gelijkekansentest
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  ; </br> gelet op advies
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     66.928/4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  van de
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Raad van State
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  , geven op
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12 februari 2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  , met toepassing van artikel
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     84
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  , Â§
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radi

# %% [markdown]
# ### Parts of Speech tagging

# %%
for i in nlp(review):
    print(i, "=>", i.pos_)
# Out:
# BRUSSELS => PROPN
# HOOFDSTEDELIJK => PROPN
# gEWEST => PROPN
#
#   => SPACE
# 5 => NUM
# MAART => PROPN
# 2020 => NUM
# . => PUNCT
# - => PUNCT
# besluit => NOUN
# van => ADP
# de => DET
# Brussels => PROPN
# hoofdstedelijk => ADJ
# regering => NOUN
# tot => ADP
# wijziging => NOUN
# van => ADP
# het => DET
# koninklijk => ADJ
# besluit => NOUN
# van => ADP
# 8 => NUM
# juli => PROPN
# 1970 => NUM
# houdenen => VERB
# de => DET
# algemeen => ADJ
# verordening => NOUN
# betreffen => VERB
# de => DET
# met => ADP
# de => DET
# inkomstenbelasting => NOUN
# lijkgestelen => VERB
# belasting => NOUN
# in => ADP
# het => DET
# kader => NOUN
# van => ADP
# de => DET
# overname => NOUN
# van => ADP
# de => DET
# dienst => NOUN
# van => ADP
# de => DET
# verkeersbelasting => NOUN
# op => ADP
# de => DET
# autovoertuig => NOUN
# en => CCONJ
# de => DET
# belasting => NOUN
# op => ADP
# de => DET
# inverkeerstelling => NOUN
# door => ADP
# het => DET
# Brussels => PROPN
# Hoofdstedelijk => PROPN
# Gewest => PROPN
#
#
#
#   => SPACE
# de => DET
# Brussels => PROPN
# hoofdstedelijk => ADJ
# regering => NOUN
# , => PUNCT
#
#   => SPACE
# Gelet => VERB
# op => ADP
# de => DET
# bijzonder => ADJ
# wet => NOUN
# van => ADP
# 8 => NUM
# augustus => PROPN
# 1980 => NUM
# tot => ADP
# hervorming => NOUN
# de => DET
# instelling => NOUN
# , => PUNCT
# artikel => NOUN
# 20 => NUM
# ; => PUNCT
#
#   => SPACE
# gelet => VERB
# op => ADP
# het => DET
# wetboek => NOUN
# van => ADP
# de => DET
# met => ADP
# inkomstenbelasting => NOUN
# lijkgestelen => VERB
# belasting => NOUN
# , => PUNCT
# artikel => NOUN
# 5 => NUM
# , => PUNCT
# Â§ => NOUN
# 1 => NUM
# , => PUNCT
# twee => NUM
# lid => NOUN
# , => PUNCT
# wijzigen => VERB
# bij => ADP
# de => DET
# ordonnantie => NOUN
# van => ADP
# 28 => NUM
# november => PROPN
# 2019 => NUM
# ; => PUNCT
#
#   => SPACE
# gelet => VERB
# op => ADP
# het => DET
# koninklijk => ADJ
# besluit => NOUN
# van => ADP
# 8 => NUM
# juli => PROPN
# 1970 => NUM
# houdenen => VERB
# de => DET
# algemeen => ADJ
# verordening => NOUN
# betreffen => VERB
# de => DET
# met => ADP
# de => DET
# inkomstenbelasting => NOUN
# gelijkgestelde => VERB
# belasting => NOUN
# ; => PUNCT
#
#   => SPACE
# Gelet => ADJ
# op => ADP
# de => DET
# gelijkekansentest => NOUN
# uit_voeren => PROPN
# op => ADP
# 22 => NUM
# november => PROPN
# 2019 => NUM
# in => ADP
# toepassing => NOUN
# van => ADP
# artikel => NOUN
# 2 => NUM
# van => ADP
# de => DET
# ordonnantie => NOUN
# van => ADP
# 4 => NUM
# oktober => PROPN
# 2018 => NUM
# tot => ADP
# invoering => NOUN
# van => ADP
# de => DET
# Gelijkekansentest => PROPN
# ; => PUNCT
#
#   => SPACE
# gelet => VERB
# op => ADP
# advies => NOUN
# 66.928/4 => VERB
# van => ADP
# de => DET
# Raad => PROPN
# van => PROPN
# State => PROPN
# , => PUNCT
# geven => VERB
# op => ADP
# 12 => NUM
# februari => PROPN
# 2020 => NUM
# , => PUNCT
# met => ADP
# toepassing => NOUN
# van => ADP
# artikel => NOUN
# 84 => NUM
# , => PUNCT
# Â§ => NOUN
# 1 => NUM
# , => PUNCT
# één => NUM
# lid => NOUN
# , => PUNCT
# 2Â => SYM
# ° => SYM
# , => PUNCT
# van => ADP
# de => DET
# wet => NOUN
# op => ADP
# de => DET
# Raad => PROPN
# van => PROPN
# State => PROPN
# , => PUNCT
# coÃ¶rdineren => VERB
# op => ADP
# 12 => NUM
# januari => PROPN
# 1973 => NUM
# ; => PUNCT
#
#   => SPACE
# overwegende => CCONJ
# dat => SCONJ
# de => DET
# ordonnantie => NOUN
# van => ADP
# 28 => NUM
# november => PROPN
# 2019 => NUM
# tot => ADP
# wijziging => NOUN
# van => ADP
# het => DET
# wetboek => NOUN
# van => ADP
# de => DET
# met => ADP
# inkomstenbelasting => NOUN
# lijkgestelen => VERB
# belasting => NOUN
# in => ADP
# het => DET
# kader => NOUN
# van => ADP
# de => DET
# overname => NOUN
# van => ADP
# de => DET
# dienst => NOUN
# van => ADP
# de => DET
# verkeersbelasting => NOUN
# op => ADP
# de => DET
# autovoertuig => NOUN
# en => CCONJ
# van => ADP
# de => DET
# belasting => NOUN
# op => ADP
# de => DET
# inverkeerstelling => NOUN
# door => ADP
# het => DET
# Brussels => PROPN
# Hoofdstedelijk => PROPN
# Gewest => PROPN
# , => PUNCT
# in => ADP
# zijn => PRON
# artikel => NOUN
# 3 => NUM
# , => PUNCT
# 1Â => SYM
# ° => PUNCT
# , => SYM
# a => SYM
# ) => PUNCT
# , => PUNCT
# iv => SYM
# , => SYM
# et => SYM
# b => SYM
# ) => PUNCT
# , => PUNCT
# 12 => NUM
# , => PUNCT
# 13 => NUM
# en => CCONJ
# 15 => NUM
# , => PUNCT
# 2Â => SYM
# ° => SYM
# en => CCONJ
# 3Â => SYM
# ° => SYM
# de => DET
# bepaling => NOUN
# die => PRON
# momenteel => ADJ
# vervat => VERB
# zijn => AUX
# in => ADP
# de => DET
# artikel => NOUN
# 15 => NUM
# , => PUNCT
# Â§ => NOUN
# 1 => NUM
# , => PUNCT
# en => CCONJ
# 58 => NUM
# van => ADP
# het => DET
# koninklijk => ADJ
# besluit => NOUN
# van => ADP
# 8 => NUM
# juli => PROPN
# 1970 => NUM
# houdenen => VERB
# de => DET
# algemeen => ADJ
# verordening => NOUN
# betreffen => VERB
# de => DET
# met => ADP
# de => DET
# inkomstenbelasting => NOUN
# lijkgestelen => VERB
# belasting => NOUN
# , => PUNCT
# hebben => AUX
# Ã¯ntegreren => NOUN
# in => ADP
# de => DET
# artikel => NOUN
# 5 => NUM
# , => PUNCT
# één => NUM
# lid => NOUN
# , => PUNCT
# 3Â => SYM
# ° => SYM
# bis => SYM
# , => PUNCT
# en => CCONJ
# twee => NUM
# lid => NOUN
# , => PUNCT
# en => CCONJ
# 96 => NUM
# , => PUNCT
# één => NUM
# lid => NOUN
# , => PUNCT
# 3Â => SYM
# ° => SYM
# , => SYM
# a => SYM
# ) => PUNCT
# en => CCONJ
# twee => NUM
# lid => NOUN
# van => ADP
# het => DET
# wetboek => NOUN
# van => ADP
# de => DET
# met => ADP
# inkomstenbelasting => NOUN
# lijkgestelen => VERB
# belasting => NOUN
# ; => PUNCT
# dat => SCONJ
# deze => DET
# bepaling => NOUN
# derhalve => ADV
# moeten => AUX
# worden => AUX
# op_heffen => NOUN
# ; => PUNCT
#
#   => SPACE
# overwegende => CCONJ
# dat => SCONJ
# de => DET
# ordonnantie => NOUN
# van => ADP
# 19 => NUM
# december => PROPN
# 2019 => NUM
# houdenen => VERB
# de => DET
# wijziging => NOUN
# van => ADP
# de => DET
# procedureel => NOUN
# bepaling => NOUN
# in => ADP
# het => DET
# kader => NOUN
# van => ADP
# de => DET
# overname => NOUN
# van => ADP
# de => DET
# dienst => NOUN
# van => ADP
# de => DET
# verkeersbelastingen => NOUN
# en => CCONJ
# houden => VERB
# divers => ADJ
# bepaling => NOUN
# tot => ADP
# gevolg => NOUN
# hebben => VERB
# dat => SCONJ
# de => DET
# ordonnantie => NOUN
# van => ADP
# 6 => NUM
# maart => PROPN
# 2019 => NUM
# betreffen => VERB
# de => DET
# Brussels => PROPN
# Codex => PROPN
# Fiscale => ADJ
# Procedure => NOUN
# en => CCONJ
# haar => PRON
# uitvoeringsbesluit => NOUN
# van => ADP
# toepassing => NOUN
# zijn => AUX
# op => ADP
# de => DET
# verkeersbelasting => NOUN
# op => ADP
# de => DET
# autovoertuig => NOUN
# en => CCONJ
# de => DET
# belasting => NOUN
# op => ADP
# de => DET
# inverkeerstelling => NOUN
# waarvan => ADV
# het => DET
# belastbaar => ADJ
# feit => NOUN
# ontstaan => VERB
# vanaf => ADP
# 1 => NUM
# januari => PROPN
# 2020 => NUM
# ; => PUNCT
# dat => SCONJ
# de => DET
# procedureel => NOUN
# bepaling => NOUN
# vervat => VERB
# in => ADP
# Titel => PROPN
# I => PROPN
# van => ADP
# de => DET
# het => DET
# besluit => NOUN
# van => ADP
# 8 => NUM
# juli => PROPN
# 1970 => NUM
# houdenen => VERB
# de => DET
# algemeen => ADJ
# verordening => NOUN
# betreffen => VERB
# de => DET
# met => ADP
# de => DET
# inkomstenbelasting => NOUN
# lijkgestelen => VERB
# belasting => NOUN
# , => PUNCT
# dus => CCONJ
# , => PUNCT
# voor => ADP
# wat => PRON
# deze => DET
# belasting => NOUN
# betreffen => VERB
# , => PUNCT
# moeten => AUX
# worden => AUX
# op_heffen => NOUN
# , => PUNCT
# voor => ADP
# zover => ADV
# hun => PRON
# doel => NOUN
# rechtstreeks => ADJ
# worden => AUX
# over_nemen => PROPN
# in => ADP
# de => DET
# noemen => NOUN
# Codex => PROPN
# en => CCONJ
# zijn => AUX
# uitvoeringsbeslui => NOUN
# ; => PUNCT
#
#   => SPACE
# op => ADP
# voorstel => NOUN
# van => ADP
# de => DET
# minister => NOUN
# van => ADP
# FinanciÃ => NOUN
# « => PUNCT
# n => INTJ
# , => PUNCT
# na => ADP
# beraadslaging => NOUN
# , => PUNCT
#
#   => SPACE
# besluit => NOUN
# : => PUNCT
#
#   => SPACE
# HOOFDSTUK => PROPN
# 1 => NUM
# . => PUNCT
# - => PUNCT
# Inleidende => ADJ
# bepaling => NOUN
#
#   => SPACE
# artikel => NOUN
# 1 => NUM
# . => PUNCT
# dit => DET
# besluit => NOUN
# zijn => AUX
# uitsluitend => ADJ
# van => ADP
# toepassing => NOUN
# op => ADP
# : => PUNCT
#
#   => SPACE
# 1Â => SYM
# ° => PUNCT
# de => DET
# verkeersbelasting => NOUN
# op => ADP
# de => DET
# autovoertuig => NOUN
# ; => PUNCT
#
#   => SPACE
# 2Â => SYM
# ° => SYM
# de => DET
# belasting => NOUN
# op => ADP
# de => DET
# inverkeerstelling => NOUN
# . => PUNCT
#
#   => SPACE
# HOOFDSTUK => PROPN
# 2 => NUM
# . => PUNCT
# - => PUNCT
# Wijzigingen => NOUN
# van => ADP
# toepassing => NOUN
# op => ADP
# de => DET
# verkeersbelasting => NOUN
# op => ADP
# de => DET
# autovoertuig => NOUN
# en => CCONJ
# de => DET
# belasting => NOUN
# op => ADP
# de => DET
# inverkeerstelling => NOUN
# waarvan => ADV
# het => DET
# belastbaar => ADJ
# feit => NOUN
# vÃ³Ã³r => ADP
# 1 => NUM
# januari => PROPN
# 2020 => NUM
# vallen => VERB
#
#   => SPACE
# Art. => X
# 2 => NUM
# . => PUNCT
# de => DET
# bepaling => NOUN
# van => ADP
# dit => DET
# hoofdstuk => NOUN
# zijn => AUX
# uitsluitend => ADJ
# van => ADP
# toepassing => NOUN
# op => ADP
# de => DET
# verkeersbelasting => NOUN
# op => ADP
# de => DET
# autovoertuig => NOUN
# en => CCONJ
# de => DET
# belasting => NOUN
# op => ADP
# de => DET
# inverkeerstelling => NOUN
# waarvan => ADV
# het => DET
# belastbaar => ADJ
# feit => NOUN
# vÃ³Ã³r => ADP
# 1 => NUM
# januari => PROPN
# 2020 => NUM
# vallen => VERB
# . => PUNCT
#
#   => SPACE
# Art. => X
# 3 => NUM
# . => PUNCT
# artikel => NOUN
# 8 => NUM
# van => ADP
# het => DET
# koninklijk => ADJ
# besluit => NOUN
# van => ADP
# 8 => NUM
# juli => PROPN
# 1970 => NUM
# houdenen => VERB
# de => DET
# algemeen => ADJ
# verordening => NOUN
# betreffen => VERB
# de => DET
# met => ADP
# de => DET
# inkomstenbelasting => NOUN
# lijkgestelen => VERB
# belasting => NOUN
# , => PUNCT
# vervangen => VERB
# bij => ADP
# het => DET
# koninklijk => ADJ
# besluit => NOUN
# van => ADP
# 27 => NUM
# februari => PROPN
# 2019 => NUM
# , => PUNCT
# worden => AUX
# vervangen => VERB
# als => SCONJ
# volgen => VERB
# : => PUNCT
#
#   => SPACE
# " => PUNCT
# Art. => X
# 8 => NUM
# . => PUNCT
# onverminderd => VERB
# de => DET
# bepaling => NOUN
# van => ADP
# artikel => NOUN
# 24 => NUM
# , => PUNCT
# zijn => AUX
# de => DET
# met => ADP
# de => DET
# inkomstenbelasting => NOUN
# gelijkgestelde => VERB
# belasting => NOUN
# te => ADP
# betalen => VERB
# bij => ADP
# de => DET
# rekenplichtig => ADJ
# van => ADP
# de => DET
# ontvan_gst => ADJ
# belasten => VERB
# met => ADP
# fiscaal => ADJ
# zaak => NOUN
# van => ADP
# de => DET
# Gewestelijke => ADJ
# overheidsdienst => NOUN
# Brussel => PROPN
# Fiscaliteit => NOUN
# of => CCONJ
# , => PUNCT
# in => ADP
# geval => NOUN
# van => ADP
# zijn => PRON
# afwezigheid => NOUN
# , => PUNCT
# bij => ADP
# de => DET
# plaatsvervangend => ADJ
# rekenplichtig => ADJ
# van => ADP
# de => DET
# ontvangsat => NOUN
# belasten => VERB
# met => ADP
# fiscaal => ADJ
# zaak => NOUN
# van => ADP
# dezelfde => DET
# dienst => NOUN
# . => PUNCT
# " => PUNCT
# . => PUNCT
#
#   => SPACE
# Art. => X
# 4 => NUM
# . => PUNCT
# in => ADP
# artikel => NOUN
# 11 => NUM
# van => ADP
# hetzelfde => DET
# besluit => NOUN
# , => PUNCT
# wijzigen => VERB
# bij => ADP
# het => DET
# koninklijk => ADJ
# besluit => NOUN
# van => ADP
# 14 => NUM
# april => PROPN
# 1993 => NUM
# en => CCONJ
# bij => ADP
# het => DET
# koninklijk => ADJ
# besluit => NOUN
# van => ADP
# 9 => NUM
# november => PROPN
# 1999 => NUM
# en => CCONJ
# vervangen => VERB
# bij => ADP
# het => DET
# koninklijk => ADJ
# besluit => NOUN
# van => ADP
# 17 => NUM
# februari => PROPN
# 2019 => NUM
# , => PUNCT
# worden => AUX
# de => DET
# woord => NOUN
# " => PUNCT
# op => ADP
# de => DET
# financiÃ => NOUN
# « => PUNCT
# Le => SYM
# rekening => NOUN
# van => ADP
# het => DET
# ontvangkantoor => NOUN
# Belastingen-auto => PROPN
# " => PUNCT
# vervangen => VERB
# door => ADP
# de => DET
# woord => NOUN
# " => PUNCT
# volgens => ADP
# de => DET
# door => ADP
# de => DET
# gewestelijk => ADJ
# overheidsdienst => NOUN
# Brussel => PROPN
# fiscaliteit => ADJ
# aangegeven => VERB
# modaliteit => NOUN
# " => PUNCT
# . => PUNCT
#
#   => SPACE
# HOOFDSTUK => PROPN
# 3 => NUM
# . => PUNCT
# - => PUNCT
# Wijzigingen => NOUN
# van => ADP
# toepassing => NOUN
# op => ADP
# de => DET
# verkeersbelasting => NOUN
# op => ADP
# de => DET
# autovoertuig => NOUN
# en => CCONJ
# de => DET
# belasting => NOUN
# op => ADP
# de => DET
# inverkeerstelling => NOUN
# waarvan => ADV
# het => DET
# belastbaar => ADJ
# feit => NOUN
# vanaf => ADP
# 1 => NUM
# januari => PROPN
# 2020 => NUM
# vallen => VERB
#
#   => SPACE
# Art. => X
# 5 => NUM
# . => PUNCT
# de => DET
# bepaling => NOUN
# van => ADP
# dit => DET
# hoofdstuk => NOUN
# zijn => AUX
# uitsluitend => ADJ
# van => ADP
# toepassing => NOUN
# op => ADP
# de => DET
# verkeersbelasting => NOUN
# op => ADP
# de => DET
# autovoertuig => NOUN
# en => CCONJ
# de => DET
# belasting => NOUN
# op => ADP
# de => DET
# inverkeerstelling => NOUN
# waarvan => ADV
# het => DET
# belastbaar => ADJ
# feit => NOUN
# vanaf => ADP
# 1 => NUM
# januari => PROPN
# 2020 => NUM
# vallen => VERB
# . => PUNCT
#
#   => SPACE
# Art. => X
# 6 => NUM
# . => PUNCT
# in => ADP
# artikel => NOUN
# 15 => NUM
# van => ADP
# hetzelfde => DET
# besluit => NOUN
# , => PUNCT
# wijzigen => VERB
# bij => ADP
# het => DET
# koninklijk => ADJ
# besluit => NOUN
# van => ADP
# 10 => NUM
# november => PROPN
# 1980 => NUM
# en => CCONJ
# bij => ADP
# de => DET
# wet => NOUN
# van => ADP
# 19 => NUM
# februari => PROPN
# 1990 => NUM
# , => PUNCT
# worden => AUX
# de => DET
# volgen => VERB
# wijziging => NOUN
# aan_brengen => PROPN
# : => PUNCT
#
#   => SPACE
# 1Â => SYM
# ° => PUNCT
# paragraaf => NOUN
# 1 => NUM
# worden => AUX
# op_heffen => NOUN
# ; => PUNCT
#
#   => SPACE
# 2Â => SYM
# ° => SYM
# in => ADP
# paragraaf => NOUN
# 2 => NUM
# worden => AUX
# de => DET
# volgen => VERB
# wijziging => NOUN
# aan_brengen => PROPN
# : => PUNCT
#
#   => SPACE
# à => SYM
# ) => PUNCT
# in => ADP
# de => DET
# bepaling => NOUN
# onder => ADP
# 1Â => SYM
# ° => PUNCT
# worden => AUX
# de => DET
# woord => NOUN
# " => PUNCT
# wet => NOUN
# van => ADP
# 27 => NUM
# december => PROPN
# 1974 => NUM
# betreffen => VERB
# de => DET
# taxidienst => NOUN
# en => CCONJ
# in_richten => NOUN
# krachtens => ADP
# een => DET
# vergunning => NOUN
# regelmatig => ADJ
# afgelevren => ADJ
# te => ADP
# uitvoering => NOUN
# van => ADP
# gezegen => NOUN
# wet => NOUN
# " => PUNCT
# vervangen => VERB
# door => ADP
# de => DET
# woord => NOUN
# " => PUNCT
# toepasselijk => ADJ
# gewestelijk => ADJ
# regelgeving => NOUN
# en => CCONJ
# in_richten => NOUN
# krachtens => ADP
# een => DET
# vergunning => NOUN
# regelmatig => ADJ
# afgelevren => ADJ
# te => ADP
# uitvoering => NOUN
# van => ADP
# de => DET
# noemen => VERB
# regelgeving => NOUN
# " => PUNCT
# ; => PUNCT
#
#   => SPACE
# b => SYM
# ) => PUNCT
# de => DET
# bepaling => NOUN
# onder => ADP
# 2Â => SYM
# ° => PUNCT
# worden => AUX
# vervangen => VERB
# als => SCONJ
# volgen => VERB
# : => PUNCT
#
#   => SPACE
# " => SYM
# 2Â => SYM
# ° => SYM
# op => ADP
# de => DET
# autovoertuig => NOUN
# die => PRON
# uitsluitend => ADJ
# aangewend => VERB
# worden => AUX
# tot => ADP
# een => DET
# dienst => NOUN
# voor => ADP
# het => DET
# verhuren => VERB
# van => ADP
# voertuig => NOUN
# met => ADP
# bestuurder => NOUN
# onder => ADP
# de => DET
# voorwaarde => NOUN
# bepalen => VERB
# bij => ADP
# de => DET
# toepasselijk => ADJ
# gewestelijk => ADJ
# regelgeving => NOUN
# en => CCONJ
# in_richten => NOUN
# krachtens => ADP
# een => DET
# vergunning => NOUN
# regelmatig => ADJ
# afgelevren => ADJ
# te => ADP
# uitvoering => NOUN
# van => ADP
# de => DET
# noemen => VERB
# regelgeving => NOUN
# ; => PUNCT
# " => PUNCT
# . => PUNCT
#
#   => SPACE
# Art. => X
# 7 => NUM
# . => PUNCT
# in => ADP
# hetzelfde => DET
# besluit => NOUN
# worden => AUX
# de => DET
# volgen => VERB
# bepaling => NOUN
# op_heffen => NOUN
# : => PUNCT
#
#   => SPACE
# 1Â => SYM
# ° => PUNCT
# de => DET
# titel => NOUN
# I => PROPN
# , => PUNCT
# die => PRON
# bestaan => VERB
# uit => ADP
# de => DET
# artikel => NOUN
# 1 => NUM
# tot => ADP
# en => CCONJ
# met => ADP
# 14 => NUM
# ; => PUNCT
#
#   => SPACE
# 2Â => SYM
# ° => SYM
# het => DET
# hoofdstuk => NOUN
# III => NUM
# van => ADP
# titel => NOUN
# II => PROPN
# , => PUNCT
# dat => PRON
# bestaan => VERB
# uit => ADP
# de => DET
# artikel => NOUN
# 23 => NUM
# en => CCONJ
# 24 => NUM
# ; => PUNCT
#
#   => SPACE
# 3Â => SYM
# ° => SYM
# het => DET
# hoofdstuk => NOUN
# IV => NUM
# van => ADP
# titel => NOUN
# II => PROPN
# , => PUNCT
# dat => PRON
# bestaan => VERB
# uit => ADP
# de => DET
# artikel => NOUN
# 25 => NUM
# en => CCONJ
# 26 => NUM
# ; => PUNCT
#
#   => SPACE
# 4Â => SYM
# ° => SYM
# het => DET
# hoofdstuk => NOUN
# V => NUM
# van => ADP
# titel => NOUN
# II => PROPN
# , => PUNCT
# dat => PRON
# bestaan => VERB
# uit => ADP
# de => DET
# artikel => NOUN
# 27 => NUM
# tot => ADP
# en => CCONJ
# met => ADP
# 29 => NUM
# ; => PUNCT
#
#   => SPACE
# 5Â => SYM
# ° => SYM
# in => ADP
# het => DET
# titel => NOUN
# V => NUM
# , => PUNCT
# artikel => NOUN
# 58 => NUM
# , => PUNCT
# wijzigen => VERB
# bij => ADP
# het => DET
# koninklijk => ADJ
# besluit => NOUN
# van => ADP
# 14 => NUM
# april => PROPN
# 1993 => NUM
# . => PUNCT
#
#   => SPACE
# HOOFDSTUK => PROPN
# 4 => NUM
# . => PUNCT
# - => PUNCT
# Wijzigingen => NOUN
# van => ADP
# toepassing => NOUN
# op => ADP
# de => DET
# verkeersbelasting => NOUN
# op => ADP
# de => DET
# autovoertuig => NOUN
# en => CCONJ
# de => DET
# belasting => NOUN
# op => ADP
# de => DET
# inverkeerstelling => NOUN
# ongeacht => ADP
# de => DET
# datum => NOUN
# van => ADP
# het => DET
# belastbaar => ADJ
# feit => NOUN
#
#   => SPACE
# Art. => X
# 8 => NUM
# . => PUNCT
# in => ADP
# artikel => NOUN
# 30 => NUM
# , => PUNCT
# Â§ => NOUN
# 2 => NUM
# , => PUNCT
# van => ADP
# hetzelfde => DET
# besluit => NOUN
# opnieuw => ADV
# op_nemen => VERB
# bij => ADP
# het => DET
# koninklijk => ADJ
# besluit => NOUN
# van => ADP
# 17 => NUM
# december => PROPN
# 1984 => NUM
# , => PUNCT
# worden => AUX
# de => DET
# volgen => VERB
# wijziging => NOUN
# aan_brengen => PROPN
# : => PUNCT
#
#   => SPACE
# 1Â => SYM
# ° => PUNCT
# in => ADP
# het => DET
# één => NUM
# lid => NOUN
# worden => VERB
# de => DET
# woord => NOUN
# " => PUNCT
# doen => VERB
# door => ADP
# middel => NOUN
# van => ADP
# een => DET
# formulier => NOUN
# dat => PRON
# door => ADP
# administratie => NOUN
# de => DET
# direct => ADJ
# belasting => NOUN
# worden => AUX
# verstrekken => VERB
# " => PUNCT
# vervangen => VERB
# door => ADP
# de => DET
# woord => NOUN
# " => PUNCT
# in_dienen => NOUN
# bij => ADP
# de => DET
# Gewestelijke => ADJ
# overheidsdienst => NOUN
# Brussel => PROPN
# Fiscaliteit => NOUN
# " => PUNCT
# ; => PUNCT
#
#   => SPACE
# 2Â => SYM
# ° => SYM
# het => DET
# twee => NUM
# lid => NOUN
# worden => VERB
# op_heffen => NOUN
# . => PUNCT
#
#   => SPACE
# HOOFDSTUK => NOUN
# 5 => NUM
# . => PUNCT
# - => PUNCT
# Inwerkingtreding => NOUN
# en => CCONJ
# uitvoering => NOUN
#
#   => SPACE
# Art. => X
# 9 => NUM
# . => PUNCT
# dit => DET
# besluit => NOUN
# hebben => AUX
# uitwerking => NOUN
# met => ADP
# ingang => NOUN
# van => ADP
# 1 => NUM
# januari => PROPN
# 2020 => NUM
# . => PUNCT
#
#   => SPACE
# Art. => X
# 10 => NUM
# . => PUNCT
# de => DET
# minister => NOUN
# bevoegd => ADJ
# voor => ADP
# FinanciÃ => NOUN
# « => PUNCT
# n => PRON
# zijn => AUX
# belasten => NOUN
# met => ADP
# de => DET
# uitvoering => NOUN
# van => ADP
# dit => DET
# besluit => NOUN
# . => PUNCT
#
#   => SPACE
# Brussel => PROPN
# , => PUNCT
# 5 => NUM
# maart => PROPN
# 2020 => NUM
# . => PUNCT
#
#   => SPACE
# voor => ADP
# de => DET
# Brussels => PROPN
# hoofdstedelijk => ADJ
# regering => NOUN
# : => PUNCT
#
#   => SPACE
# de => DET
# Minister_President => SYM
# van => ADP
# de => DET
# Brussels => PROPN
# hoofdstedelijk => ADJ
# regering => NOUN
# , => PUNCT
#
#   => SPACE
# R. => PROPN
# VERVOORT => PROPN
#
#   => SPACE
# de => DET
# minister => NOUN
# van => ADP
# de => DET
# Brussels => PROPN
# hoofdstedelijk => ADJ
# regering => NOUN
# , => PUNCT
# belasten => VERB
# met => ADP
# FinanciÃ => NOUN
# « => PUNCT
# n => INTJ
# , => PUNCT
# begroting => NOUN
# , => PUNCT
# openbaar => ADJ
# ambt => NOUN
# en => CCONJ
# de => DET
# Promotie => PROPN
# van => ADP
# Meertaligheid => PROPN
# , => PUNCT
#
#   => SPACE
# S. => PROPN
# GATZ => PROPN
#
#  => SPACE

# %%
#Import puntuaction marks from string and also add additional next line tag in it
punctuation=punctuation+ '\n'

# %%
#Tokenize the words from the sentence:
tokens=[token.text for token in doc]
print(tokens)
# Out:
# ['BRUSSELS', 'HOOFDSTEDELIJK', 'gEWEST', '\n ', '5', 'MAART', '2020', '.', '-', 'besluit', 'van', 'de', 'Brussels', 'hoofdstedelijk', 'regering', 'tot', 'wijziging', 'van', 'het', 'koninklijk', 'besluit', 'van', '8', 'juli', '1970', 'houdenen', 'de', 'algemeen', 'verordening', 'betreffen', 'de', 'met', 'de', 'inkomstenbelasting', 'lijkgestelen', 'belasting', 'in', 'het', 'kader', 'van', 'de', 'overname', 'van', 'de', 'dienst', 'van', 'de', 'verkeersbelasting', 'op', 'de', 'autovoertuig', 'en', 'de', 'belasting', 'op', 'de', 'inverkeerstelling', 'door', 'het', 'Brussels', 'Hoofdstedelijk', 'Gewest', '\n\n\n ', 'de', 'Brussels', 'hoofdstedelijk', 'regering', ',', '\n ', 'Gelet', 'op', 'de', 'bijzonder', 'wet', 'van', '8', 'augustus', '1980', 'tot', 'hervorming', 'de', 'instelling', ',', 'artikel', '20', ';', '\n ', 'gelet', 'op', 'het', 'wetboek', 'van', 'de', 'met', 'inkomstenbelasting', 'lijkgestelen', 'belasting', ',', 'artikel', '5', ',', 'Â§', '1', ',', 'twee', 'lid', ',', 'wijzigen', 'bij', 'de', 'ordonnantie', 'van', '28', 'november', '2019', ';', '\n ', 'gelet', 'op', 'het', 'koninklijk', 'besluit', 'van', '8', 'juli', '1970', 'houdenen', 'de', 'algemeen', 'verordening', 'betreffen', 'de', 'met', 'de', 'inkomstenbelasting', 'gelijkgestelde', 'belasting', ';', '\n ', 'Gelet', 'op', 'de', 'gelijkekansentest', 'uit_voeren', 'op', '22', 'november', '2019', 'in', 'toepassing', 'van', 'artikel', '2', 'van', 'de', 'ordonnantie', 'van', '4', 'oktober', '2018', 'tot', 'invoering', 'van', 'de', 'Gelijkekansentest', ';', '\n ', 'gelet', 'op', 'advies', '66.928/4', 'van', 'de', 'Raad', 'van', 'State', ',', 'geven', 'op', '12', 'februari', '2020', ',', 'met', 'toepassing', 'van', 'artikel', '84', ',', 'Â§', '1', ',', 'één', 'lid', ',', '2Â', '°', ',', 'van', 'de', 'wet', 'op', 'de', 'Raad', 'van', 'State', ',', 'coÃ¶rdineren', 'op', '12', 'januari', '1973', ';', '\n ', 'overwegende', 'dat', 'de', 'ordonnantie', 'van', '28', 'november', '2019', 'tot', 'wijziging', 'van', 'het', 'wetboek', 'van', 'de', 'met', 'inkomstenbelasting', 'lijkgestelen', 'belasting', 'in', 'het', 'kader', 'van', 'de', 'overname', 'van', 'de', 'dienst', 'van', 'de', 'verkeersbelasting', 'op', 'de', 'autovoertuig', 'en', 'van', 'de', 'belasting', 'op', 'de', 'inverkeerstelling', 'door', 'het', 'Brussels', 'Hoofdstedelijk', 'Gewest', ',', 'in', 'zijn', 'artikel', '3', ',', '1Â', '°', ',', 'a', ')', ',', 'iv', ',', 'et', 'b', ')', ',', '12', ',', '13', 'en', '15', ',', '2Â', '°', 'en', '3Â', '°', 'de', 'bepaling', 'die', 'momenteel', 'vervat', 'zijn', 'in', 'de', 'artikel', '15', ',', 'Â§', '1', ',', 'en', '58', 'van', 'het', 'koninklijk', 'besluit', 'van', '8', 'juli', '1970', 'houdenen', 'de', 'algemeen', 'verordening', 'betreffen', 'de', 'met', 'de', 'inkomstenbelasting', 'lijkgestelen', 'belasting', ',', 'hebben', 'Ã¯ntegreren', 'in', 'de', 'artikel', '5', ',', 'één', 'lid', ',', '3Â', '°', 'bis', ',', 'en', 'twee', 'lid', ',', 'en', '96', ',', 'één', 'lid', ',', '3Â', '°', ',', 'a', ')', 'en', 'twee', 'lid', 'van', 'het', 'wetboek', 'van', 'de', 'met', 'inkomstenbelasting', 'lijkgestelen', 'belasting', ';', 'dat', 'deze', 'bepaling', 'derhalve', 'moeten', 'worden', 'op_heffen', ';', '\n ', 'overwegende', 'dat', 'de', 'ordonnantie', 'van', '19', 'december', '2019', 'houdenen', 'de', 'wijziging', 'van', 'de', 'procedureel', 'bepaling', 'in', 'het', 'kader', 'van', 'de', 'overname', 'van', 'de', 'dienst', 'van', 'de', 'verkeersbelastingen', 'en', 'houden', 'divers', 'bepaling', 'tot', 'gevolg', 'hebben', 'dat', 'de', 'ordonnantie', 'van', '6', 'maart', '2019', 'betreffen', 'de', 'Brussels', 'Codex', 'Fiscale', 'Procedure', 'en', 'haar', 'uitvoeringsbesluit', 'van', 'toepassing', 'zijn', 'op', 'de', 'verkeersbelasting', 'op', 'de', 'autovoertuig', 'en', 'de', 'belasting', 'op', 'de', 'inverkeerstelling', 'waarvan', 'het', 'belastbaar', 'feit', 'ontstaan', 'vanaf', '1', 'januari', '2020', ';', 'dat', 'de', 'procedureel', 'bepaling', 'vervat', 'in', 'Titel', 'I', ' ...

# %%
#Calculating word frequencies from the text after removing stopwords and puntuactions:

stopwords = list(STOP_WORDS)

word_frequencies={}
for word in doc:
    if word.text.lower() not in stopwords:
        if word.text.lower() not in punctuation:
            if word.text not in word_frequencies.keys():
                word_frequencies[word.text] = 1
            else:
                word_frequencies[word.text] += 1

# %%
#Print and see word frequencies to know important words.
print(word_frequencies)
# Out:
# {'BRUSSELS': 1, 'HOOFDSTEDELIJK': 1, 'gEWEST': 1, '\n ': 46, '5': 6, 'MAART': 1, '2020': 9, 'besluit': 21, 'Brussels': 8, 'hoofdstedelijk': 5, 'regering': 5, 'wijziging': 6, 'koninklijk': 11, '8': 9, 'juli': 5, '1970': 5, 'houdenen': 6, 'algemeen': 5, 'verordening': 5, 'betreffen': 8, 'inkomstenbelasting': 9, 'lijkgestelen': 7, 'belasting': 20, 'kader': 3, 'overname': 3, 'dienst': 5, 'verkeersbelasting': 9, 'autovoertuig': 10, 'inverkeerstelling': 9, 'Hoofdstedelijk': 2, 'Gewest': 2, '\n\n\n ': 1, 'Gelet': 2, 'bijzonder': 1, 'wet': 5, 'augustus': 1, '1980': 2, 'hervorming': 1, 'instelling': 1, 'artikel': 18, '20': 1, 'gelet': 3, 'wetboek': 3, 'Â§': 4, '1': 13, 'twee': 4, 'lid': 8, 'wijzigen': 4, 'ordonnantie': 5, '28': 2, 'november': 5, '2019': 7, 'gelijkgestelde': 2, 'gelijkekansentest': 1, 'uit_voeren': 1, '22': 1, 'toepassing': 9, '2': 5, '4': 3, 'oktober': 1, '2018': 1, 'invoering': 1, 'Gelijkekansentest': 1, 'advies': 1, '66.928/4': 1, 'Raad': 2, 'State': 2, '12': 3, 'februari': 4, '84': 1, 'één': 4, '2Â': 8, '°': 20, 'coÃ¶rdineren': 1, 'januari': 7, '1973': 1, 'overwegende': 2, '3': 3, '1Â': 6, 'a': 2, 'iv': 1, 'et': 1, 'b': 2, '13': 1, '15': 3, '3Â': 4, 'bepaling': 12, 'momenteel': 1, 'vervat': 2, '58': 2, 'Ã¯ntegreren': 1, 'bis': 1, '96': 1, 'derhalve': 1, 'op_heffen': 5, '19': 2, 'december': 3, 'procedureel': 2, 'verkeersbelastingen': 1, 'houden': 1, 'divers': 1, 'gevolg': 1, '6': 2, 'maart': 2, 'Codex': 2, 'Fiscale': 1, 'Procedure': 1, 'uitvoeringsbesluit': 1, 'waarvan': 5, 'belastbaar': 6, 'feit': 6, 'ontstaan': 1, 'Titel': 1, 'I': 2, 'zover': 1, 'doel': 1, 'rechtstreeks': 1, 'over_nemen': 1, 'noemen': 3, 'uitvoeringsbeslui': 1, 'voorstel': 1, 'minister': 3, 'FinanciÃ': 3, '«': 4, 'n': 3, 'beraadslaging': 1, 'HOOFDSTUK': 5, 'Inleidende': 1, 'uitsluitend': 4, 'Wijzigingen': 3, 'vÃ³Ã³r': 2, 'vallen': 4, 'Art.': 10, 'hoofdstuk': 5, 'vervangen': 7, '27': 3, 'volgen': 6, 'onverminderd': 1, '24': 2, 'betalen': 1, 'rekenplichtig': 2, 'ontvan_gst': 1, 'belasten': 4, 'fiscaal': 2, 'zaak': 2, 'Gewestelijke': 2, 'overheidsdienst': 3, 'Brussel': 4, 'Fiscaliteit': 2, 'geval': 1, 'afwezigheid': 1, 'plaatsvervangend': 1, 'ontvangsat': 1, '11': 1, 'hetzelfde': 4, '14': 3, 'april': 2, '1993': 2, '9': 2, '1999': 1, '17': 2, 'woord': 6, 'financiÃ': 1, 'Le': 1, 'rekening': 1, 'ontvangkantoor': 1, 'Belastingen-auto': 1, 'gewestelijk': 3, 'fiscaliteit': 1, 'aangegeven': 1, 'modaliteit': 1, '10': 2, '1990': 1, 'aan_brengen': 3, 'paragraaf': 2, 'à': 1, '1974': 1, 'taxidienst': 1, 'in_richten': 3, 'vergunning': 3, 'regelmatig': 3, 'afgelevren': 3, 'uitvoering': 5, 'gezegen': 1, 'toepasselijk': 2, 'regelgeving': 4, 'aangewend': 1, 'verhuren': 1, 'voertuig': 1, 'bestuurder': 1, 'voorwaarde': 1, 'bepalen': 1, '7': 1, 'titel': 5, 'bestaan': 4, 'III': 1, 'II': 3, '23': 1, 'IV': 1, '25': 1, '26': 1, '4Â': 1, 'V': 2, '29': 1, '5Â': 1, 'ongeacht': 1, 'datum': 1, '30': 1, 'op_nemen': 1, '1984': 1, 'middel': 1, 'formulier': 1, 'administratie': 1, 'direct': 1, 'verstrekken': 1, 'in_dienen': 1, 'Inwerkingtreding': 1, 'uitwerking': 1, 'ingang': 1, 'bevoegd': 1, 'Minister_President': 1, 'R.': 1, 'VERVOORT': 1, 'begroting': 1, 'openbaar': 1, 'ambt': 1, 'Promotie': 1, 'Meertaligheid': 1, 'S.': 1, 'GATZ': 1}

# %%
#Calculate the maximum frequency and divide it by all frequencies to get normalized word frequencies.
max_frequency=max(word_frequencies.values())
for word in word_frequencies.keys():
    word_frequencies[word]=word_frequencies[word]/max_frequency

# %%
#Printing normalized word frequencies:
#Printing in descending order 

#print(word_frequencies)
w_sorted_keys = sorted(word_frequencies, key=word_frequencies.get, reverse=True)
for w in w_sorted_keys:
    print(w, word_frequencies[w])
# Out:
#   1.0
# besluit 0.45652173913043476
# belasting 0.43478260869565216
# ° 0.43478260869565216
# artikel 0.391304347826087
# 1 0.2826086956521739
# bepaling 0.2608695652173913
# koninklijk 0.2391304347826087
# autovoertuig 0.21739130434782608
# Art. 0.21739130434782608
# 2020 0.1956521739130435
# 8 0.1956521739130435
# inkomstenbelasting 0.1956521739130435
# verkeersbelasting 0.1956521739130435
# inverkeerstelling 0.1956521739130435
# toepassing 0.1956521739130435
# Brussels 0.17391304347826086
# betreffen 0.17391304347826086
# lid 0.17391304347826086
# 2Â 0.17391304347826086
# lijkgestelen 0.15217391304347827
# 2019 0.15217391304347827
# januari 0.15217391304347827
# vervangen 0.15217391304347827
# 5 0.13043478260869565
# wijziging 0.13043478260869565
# houdenen 0.13043478260869565
# 1Â 0.13043478260869565
# belastbaar 0.13043478260869565
# feit 0.13043478260869565
# volgen 0.13043478260869565
# woord 0.13043478260869565
# hoofdstedelijk 0.10869565217391304
# regering 0.10869565217391304
# juli 0.10869565217391304
# 1970 0.10869565217391304
# algemeen 0.10869565217391304
# verordening 0.10869565217391304
# dienst 0.10869565217391304
# wet 0.10869565217391304
# ordonnantie 0.10869565217391304
# november 0.10869565217391304
# 2 0.10869565217391304
# op_heffen 0.10869565217391304
# waarvan 0.10869565217391304
# HOOFDSTUK 0.10869565217391304
# hoofdstuk 0.10869565217391304
# uitvoering 0.10869565217391304
# titel 0.10869565217391304
# Â§ 0.08695652173913043
# twee 0.08695652173913043
# wijzigen 0.08695652173913043
# februari 0.08695652173913043
# één 0.08695652173913043
# 3Â 0.08695652173913043
# « 0.08695652173913043
# uitsluitend 0.08695652173913043
# vallen 0.08695652173913043
# belasten 0.08695652173913043
# Brussel 0.08695652173913043
# hetzelfde 0.08695652173913043
# regelgeving 0.08695652173913043
# bestaan 0.08695652173913043
# kader 0.06521739130434782
# overname 0.06521739130434782
# gelet 0.06521739130434782
# wetboek 0.06521739130434782
# 4 0.06521739130434782
# 12 0.06521739130434782
# 3 0.06521739130434782
# 15 0.06521739130434782
# december 0.06521739130434782
# noemen 0.06521739130434782
# minister 0.06521739130434782
# FinanciÃ 0.06521739130434782
# n 0.06521739130434782
# Wijzigingen 0.06521739130434782
# 27 0.06521739130434782
# overheidsdienst 0.06521739130434782
# 14 0.06521739130434782
# gewestelijk 0.06521739130434782
# aan_brengen 0.06521739130434782
# in_richten 0.06521739130434782
# vergunning 0.06521739130434782
# regelmatig 0.06521739130434782
# afgelevren 0.06521739130434782
# II 0.06521739130434782
# Hoofdstedelijk 0.043478260869565216
# Gewest 0.043478260869565216
# Gelet 0.043478260869565216
# 1980 0.043478260869565216
# 28 0.043478260869565216
# gelijkgestelde 0.043478260869565216
# Raad 0.043478260869565216
# State 0.043478260869565216
# overwegende 0.043478260869565216
# a 0.043478260869565216
# b 0.043478260869565216
# vervat 0.043478260869565216
# 58 0.043478260869565216
# 19 0.043478260869565216
# procedureel 0.043478260869565216
# 6 0.043478260869565216
# maart 0.043478260869565216
# Codex 0.043478260869565216
# I 0.043478260869565216
# vÃ³Ã³r 0.043478260869565216
# 24 0.043478260869565216
# rekenplichtig 0.043478260869565216
# fiscaal 0.043478260869565216
# zaak 0.043478260869565216
# Gewestelijke 0.043478260869565216
# Fiscaliteit 0.043478260869565216
# april 0.043478260869565216
# 1993 0.043478260869565216
# 9 0.043478260869565216
# 17 0.043478260869565216
# 10 0.043478260869565216
# paragraaf 0.043478260869565216
# toepasselijk 0.043478260869565216
# V 0.043478260869565216
# BRUSSELS 0.021739130434782608
# HOOFDSTEDELIJK 0.021739130434782608
# gEWEST 0.021739130434782608
# MAART 0.021739130434782608
#
#
#
#   0.021739130434782608
# bijzonder 0.021739130434782608
# augustus 0.021739130434782608
# hervorming 0.021739130434782608
# instelling 0.021739130434782608
# 20 0.021739130434782608
# gelijkekansentest 0.021739130434782608
# uit_voeren 0.021739130434782608
# 22 0.021739130434782608
# oktober 0.021739130434782608
# 2018 0.021739130434782608
# invoering 0.021739130434782608
# Gelijkekansentest 0.021739130434782608
# advies 0.021739130434782608
# 66.928/4 0.021739130434782608
# 84 0.021739130434782608
# coÃ¶rdineren 0.021739130434782608
# 1973 0.021739130434782608
# iv 0.021739130434782608
# et 0.021739130434782608
# 13 0.021739130434782608
# momenteel 0.021739130434782608
# Ã¯ntegreren 0.021739130434782608
# bis 0.021739130434782608
# 96 0.021739130434782608
# derhalve 0.021739130434782608
# verkeersbelastingen 0.021739130434782608
# houden 0.021739130434782608
# divers 0.021739130434782608
# gevolg 0.021739130434782608
# Fiscale 0.021739130434782608
# Procedure 0.021739130434782608
# uitvoeringsbesluit 0.021739130434782608
# ontstaan 0.021739130434782608
# Titel 0.021739130434782608
# zover 0.021739130434782608
# doel 0.021739130434782608
# rechtstreeks 0.021739130434782608
# over_nemen 0.021739130434782608
# uitvoeringsbeslui 0.021739130434782608
# voorstel 0.021739130434782608
# beraadslaging 0.021739130434782608
# Inleidende 0.021739130434782608
# onverminderd 0.021739130434782608
# betalen 0.021739130434782608
# ontvan_gst 0.021739130434782608
# geval 0.021739130434782608
# afwezigheid 0.021739130434782608
# plaatsvervangend 0.021739130434782608
# ontvangsat 0.021739130434782608
# 11 0.021739130434782608
# 1999 0.021739130434782608
# financiÃ 0.021739130434782608
# Le 0.021739130434782608
# rekening 0.021739130434782608
# ontvangkantoor 0.021739130434782608
# Belastingen-auto 0.021739130434782608
# fiscaliteit 0.021739130434782608
# aangegeven 0.021739130434782608
# modaliteit 0.021739130434782608
# 1990 0.021739130434782608
# à 0.021739130434782608
# 1974 0.021739130434782608
# taxidienst 0.021739130434782608
# gezegen 0.021739130434782608
# aangewend 0.021739130434782608
# verhuren 0.021739130434782608
# voertuig 0.021739130434782608
# bestuurder 0.021739130434782608
# voorwaarde 0.021739130434782608
# bepalen 0.021739130434782608
# 7 0.021739130434782608
# III 0.021739130434782608
# 23 0.021739130434782608
# IV 0.021739130434782608
# 25 0.021739130434782608
# 26 0.021739130434782608
# 4Â 0.021739130434782608
# 29 0.021739130434782608
# 5Â 0.021739130434782608
# ongeacht 0.021739130434782608
# datum 0.021739130434782608
# 30 0.021739130434782608
# op_nemen 0.021739130434782608
# 1984 0.021739130434782608
# middel 0.021739130434782608
# formulier 0.021739130434782608
# administratie 0.021739130434782608
# direct 0.021739130434782608
# verstrekken 0.021739130434782608
# in_dienen 0.021739130434782608
# Inwerkingtreding 0.021739130434782608
# uitwerking 0.021739130434782608
# ingang 0.021739130434782608
# bevoegd 0.021739130434782608
# Minister_President 0.021739130434782608
# R. 0.021739130434782608
# VERVOORT 0.021739130434782608
# begroting 0.021739130434782608
# openbaar 0.021739130434782608
# ambt 0.021739130434782608
# Promotie 0.021739130434782608
# Meertaligheid 0.021739130434782608
# S. 0.021739130434782608
# GATZ 0.021739130434782608

# %%
#Get sentence tokens 
sentence_tokens= [sent for sent in doc.sents]
print(sentence_tokens)
# Out:
# [BRUSSELS HOOFDSTEDELIJK gEWEST,
#  5 MAART 2020 ., - besluit van de Brussels hoofdstedelijk regering tot wijziging van het koninklijk besluit van 8 juli 1970 houdenen, de algemeen verordening betreffen de met de inkomstenbelasting lijkgestelen belasting in het kader van de overname van de dienst van de verkeersbelasting op de autovoertuig en de belasting op de inverkeerstelling door het Brussels Hoofdstedelijk Gewest
#
#
#  de Brussels hoofdstedelijk regering ,
#  , Gelet op de bijzonder wet van 8 augustus 1980 tot hervorming de instelling , artikel 20 ;
#  gelet op het wetboek van de met inkomstenbelasting lijkgestelen belasting , artikel 5 , Â§ 1 , twee lid , wijzigen bij de ordonnantie van 28 november 2019 ;
#  gelet op het koninklijk besluit van 8 juli 1970 houdenen, de algemeen verordening betreffen de met de inkomstenbelasting gelijkgestelde belasting ;,
#  , Gelet op de gelijkekansentest uit_voeren op 22 november 2019 in toepassing van artikel 2 van de ordonnantie van 4 oktober 2018 tot invoering van de Gelijkekansentest ;
#  gelet op advies 66.928/4 van de Raad van State , geven op 12 februari 2020 , met toepassing van artikel 84 , Â§ 1 , één lid , 2Â ° , van de wet op de Raad van State , coÃ¶rdineren op 12 januari 1973 ;
#  overwegende dat de ordonnantie van 28 november 2019 tot wijziging van het wetboek van de met inkomstenbelasting lijkgestelen belasting in het kader van de overname van de dienst van de verkeersbelasting op de autovoertuig en van de belasting op de inverkeerstelling door het Brussels Hoofdstedelijk Gewest , in zijn artikel 3 , 1Â ° , a ) , iv , et b ) , 12 , 13 en 15 , 2Â ° en 3Â ° de bepaling die momenteel vervat zijn in de artikel 15 , Â§ 1 , en 58 van het koninklijk besluit van 8 juli 1970 houdenen, de algemeen verordening betreffen de met de inkomstenbelasting lijkgestelen belasting , hebben Ã¯ntegreren in de artikel 5 , één lid , 3Â ° bis , en twee lid , en 96 , één lid , 3Â ° , a ) en twee lid van het wetboek van de met inkomstenbelasting lijkgestelen belasting ; dat deze bepaling derhalve moeten worden op_heffen ;,
#  overwegende dat de ordonnantie van 19 december 2019 houdenen, de wijziging van de procedureel bepaling in het kader van de overname van de dienst van de verkeersbelastingen en houden divers bepaling tot gevolg hebben dat de ordonnantie van 6 maart 2019 betreffen de Brussels Codex, Fiscale Procedure en haar uitvoeringsbesluit van toepassing zijn op de verkeersbelasting op de autovoertuig en de belasting op de inverkeerstelling waarvan het belastbaar feit ontstaan vanaf 1 januari 2020 ; dat de procedureel bepaling vervat in Titel I van de het besluit van 8 juli 1970 houdenen, de algemeen verordening betreffen de met de inkomstenbelasting lijkgestelen belasting , dus , voor wat deze belasting betreffen , moeten worden op_heffen , voor zover hun doel rechtstreeks worden over_nemen in de noemen Codex en zijn uitvoeringsbeslui ;
#  op voorstel van de minister van FinanciÃ « n , na beraadslaging ,
#  besluit :,
#  , HOOFDSTUK 1 ., -, Inleidende bepaling
#  artikel 1 ., dit besluit zijn uitsluitend van toepassing op :,
#  1Â °, de verkeersbelasting op de autovoertuig ;
#  2Â ° de belasting op de inverkeerstelling .,
#  , HOOFDSTUK 2 ., - Wijzigingen van toepassing op de verkeersbelasting op de autovoertuig en de belasting op de inverkeerstelling waarvan het belastbaar feit vÃ³Ã³r 1 januari 2020 vallen
#  Art. 2 ., de bepaling van dit hoofdstuk zijn uitsluitend van toepassing op de verkeersbelasting op de autovoertuig en de belasting op de inverkeerstelling waarvan het belastbaar feit vÃ³Ã³r 1 januari 2020 vallen .,
#  Art. 3 ., artikel 8 van het koninklijk besluit van 8 juli 1970 houdenen, de algemeen verordening betreffen de met de inkomstenbelasting lijkgestelen belasting , vervangen bij het koninklijk besluit van 27 februari 2019 , worden vervangen als volgen :,
#  " Art. 8 ., onverminderd de bepaling van artikel 24 , zijn de met de inkomstenbelasting gelijkgestelde belasting te betalen bij de rekenplichtig van de ontvan_gst belasten met fiscaal zaak van de Gewestelijke overheidsdienst Brussel, Fiscaliteit of , in geval van zijn afwezigheid , bij de plaatsvervangend rekenplichtig van de ontvangsat belasten met fiscaal zaak van dezelfde dienst ., " .,
#  Art. 4 ., in artikel 11 van hetzelfde besluit , wijzigen bij het koninklijk besluit van 14 april 1993 en bij het koninklijk besluit van 9 november 1999 en vervangen bij het koninklijk besluit van 17 februari 2019 , worden de woord " op de financiÃ « Le rekening van het ontvangkantoor Belastingen-auto " vervangen door de woord " volgens de door de gewestelijk overheidsdienst Brussel fiscaliteit aangegeven modaliteit " .,
#  , HOOFDSTUK 3 ., - Wijzigingen van toepassing op de verkeersbelasting op de autovoertuig en de belasting op de inverkeerstelling waarvan het belastbaar feit vanaf 1 januari 2020 vallen
#  Art. 5 ., de bepaling van dit hoofdstuk zijn uitsluitend van toepassing op de verkeersbelasting op de autovoertuig en de belasting op de inverkeerstelling waarvan het belastbaar feit vanaf 1 januari 2020 vallen .,
#  Art. 6 ., in artikel 15 van hetzelfde besluit , wijzigen bij het koninklijk besluit van 10 november 1980 en bij de wet van 19 februari 1990 , worden de volgen wijziging aan_brengen :
#  1Â ° paragraaf 1 worden op_heffen ;,
#  2Â ° in paragraaf 2 worden, de volgen, wijziging aan_brengen :
#  à ) in de bepaling onder 1Â ° worden de woord " wet van 27 december 1974 betreffen de taxidienst en in_richten krachtens een vergunning regelmatig afgelevren te uitvoering van gezegen wet " vervangen door de woord " toepasselijk gewestelijk regelgeving en in_richten krachtens een vergunning regelmatig afgelevren te uitvoering van de noemen regelgeving " ;,
#  b ) de bepaling onder 2Â ° worden vervangen als volgen :,
#  " 2Â °, op de autovoertuig die uitsluitend aangewend worden tot een dienst voor het verhuren van voertuig met bestuurder onder de voorwaarde bepalen bij de toepasselijk gewestelijk regelgeving en in_richten krachtens een vergunning regelmatig afgelevren te uitvoering van de noemen regelgeving ;, " .,
#  Art. 7 ., in hetzelfde besluit worden de volgen bepaling op_heffen :
#  1Â ° de titel I , die bestaan uit de artikel 1 tot en met 14 ;,
#  2Â, ° het hoofdstuk III van titel II , dat bestaan uit de artikel 23 en 24 ;,
#  3Â °, het hoofdstuk IV van titel II , dat bestaan uit de artikel 25 en 26 ;
#  4Â, ° het hoofdstuk V van titel II , dat bestaan uit de artikel 27 tot en met 29 ;,
#  5Â ° in het titel V , artikel 58 , wijzigen bij het koninklijk besluit van 14 april 1993 .,
#  , HOOFDSTUK 4 ., - Wijzigingen van toepassing op de verkeersbelasting op de autovoertuig en de belasting op de inverkeerstelling ongeacht de datum van het belastbaar feit
#  Art. 8 ., in artikel 30 , Â§ 2 , van hetzelfde besluit opnieuw op_nemen bij het koninklijk besluit van 17 december 1984 , worden de volgen wijziging aan_brengen :
#  1Â ° in het één lid worden de woord " doen door middel van een formulier dat door administratie de direct belasting worden verstrekken " vervangen door de woord " in_dienen bij de Gewestelijke overheidsdienst, Brussel, Fiscaliteit " ;
#  2Â, °, het twee lid worden op_heffen .,
#  , HOOFDSTUK 5 ., - Inwerkingtreding en uitvoering,
#  Art. 9 ., dit besluit hebben uitwerking met ingang van 1 januari 2020 .,
#  Art. 10 ., de minister bevoegd voor FinanciÃ « n zijn belasten met de uitvoering van dit besluit .,
#  Brussel , 5 maart 2020 .,
#  voor de Brussels hoofdstedelijk regering :
#  de Minister_President van de Brussels hoofdstedelijk regering ,
#  R. VERVOORT
#  de minister van de Brussels hoofdstedelijk regering , belasten met FinanciÃ « n , begroting , openbaar ambt en de Promotie van Meertaligheid ,
#  S. GATZ
# ]

# %%
#Calculate the most important sentences by adding the word frequencies in each sentence.
sentence_scores = {}
for sent in sentence_tokens:
    for word in sent:
        if word.text.lower() in word_frequencies.keys():
            if sent not in sentence_scores.keys():                            
             sentence_scores[sent]=word_frequencies[word.text.lower()]
            else:
             sentence_scores[sent]+=word_frequencies[word.text.lower()]

# %%
#Print sentence scores
sentence_scores
# Out:
# {BRUSSELS HOOFDSTEDELIJK gEWEST: 0.10869565217391304,
#
#   5 MAART 2020 .: 1.3695652173913042,
#  - besluit van de Brussels hoofdstedelijk regering tot wijziging van het koninklijk besluit van 8 juli 1970 houdenen: 2.0434782608695654,
#  de algemeen verordening betreffen de met de inkomstenbelasting lijkgestelen belasting in het kader van de overname van de dienst van de verkeersbelasting op de autovoertuig en de belasting op de inverkeerstelling door het Brussels Hoofdstedelijk Gewest
#
#
#   de Brussels hoofdstedelijk regering ,
#   : 3.804347826086957,
#  Gelet op de bijzonder wet van 8 augustus 1980 tot hervorming de instelling , artikel 20 ;
#   gelet op het wetboek van de met inkomstenbelasting lijkgestelen belasting , artikel 5 , Â§ 1 , twee lid , wijzigen bij de ordonnantie van 28 november 2019 ;
#   gelet op het koninklijk besluit van 8 juli 1970 houdenen: 6.695652173913043,
#  de algemeen verordening betreffen de met de inkomstenbelasting gelijkgestelde belasting ;: 1.0652173913043477,
#
#   : 1.0,
#  Gelet op de gelijkekansentest uit_voeren op 22 november 2019 in toepassing van artikel 2 van de ordonnantie van 4 oktober 2018 tot invoering van de Gelijkekansentest ;
#   gelet op advies 66.928/4 van de Raad van State , geven op 12 februari 2020 , met toepassing van artikel 84 , Â§ 1 , één lid , 2Â ° , van de wet op de Raad van State , coÃ¶rdineren op 12 januari 1973 ;
#   overwegende dat de ordonnantie van 28 november 2019 tot wijziging van het wetboek van de met inkomstenbelasting lijkgestelen belasting in het kader van de overname van de dienst van de verkeersbelasting op de autovoertuig en van de belasting op de inverkeerstelling door het Brussels Hoofdstedelijk Gewest , in zijn artikel 3 , 1Â ° , a ) , iv , et b ) , 12 , 13 en 15 , 2Â ° en 3Â ° de bepaling die momenteel vervat zijn in de artikel 15 , Â§ 1 , en 58 van het koninklijk besluit van 8 juli 1970 houdenen: 12.956521739130434,
#  de algemeen verordening betreffen de met de inkomstenbelasting lijkgestelen belasting , hebben Ã¯ntegreren in de artikel 5 , één lid , 3Â ° bis , en twee lid , en 96 , één lid , 3Â ° , a ) en twee lid van het wetboek van de met inkomstenbelasting lijkgestelen belasting ; dat deze bepaling derhalve moeten worden op_heffen ;: 4.934782608695652,
#
#   overwegende dat de ordonnantie van 19 december 2019 houdenen: 1.5434782608695652,
#  de wijziging van de procedureel bepaling in het kader van de overname van de dienst van de verkeersbelastingen en houden divers bepaling tot gevolg hebben dat de ordonnantie van 6 maart 2019 betreffen de Brussels Codex: 1.5434782608695654,
#  Fiscale Procedure en haar uitvoeringsbesluit van toepassing zijn op de verkeersbelasting op de autovoertuig en de belasting op de inverkeerstelling waarvan het belastbaar feit ontstaan vanaf 1 januari 2020 ; dat de procedureel bepaling vervat in Titel I van de het besluit van 8 juli 1970 houdenen: 3.739130434782609,
#  de algemeen verordening betreffen de met de inkomstenbelasting lijkgestelen belasting , dus , voor wat deze belasting betreffen , moeten worden op_heffen , voor zover hun doel rechtstreeks worden over_nemen in de noemen Codex en zijn uitvoeringsbeslui ;
#   op voorstel van de minister van FinanciÃ « n , na beraadslaging ,
#   besluit :: 4.782608695652174,
#
#   : 1.0,
#  HOOFDSTUK 1 .: 0.3913043478260869,
#  Inleidende bepaling
#   artikel 1 .: 1.934782608695652,
#  dit besluit zijn uitsluitend van toepassing op :: 0.7391304347826086,
#
#   1Â °: 1.434782608695652,
#  de verkeersbelasting op de autovoertuig ;
#   2Â ° de belasting op de inverkeerstelling .: 2.4782608695652173,
#
#   : 1.0,
#  HOOFDSTUK 2 .: 0.21739130434782608,
#  - Wijzigingen van toepassing op de verkeersbelasting op de autovoertuig en de belasting op de inverkeerstelling waarvan het belastbaar feit vÃ³Ã³r 1 januari 2020 vallen
#   Art. 2 .: 3.434782608695652,
#  de bepaling van dit hoofdstuk zijn uitsluitend van toepassing op de verkeersbelasting op de autovoertuig en de belasting op de inverkeerstelling waarvan het belastbaar feit vÃ³Ã³r 1 januari 2020 vallen .: 2.782608695652174,
#
#   Art. 3 .: 1.065217391304348,
#  artikel 8 van het koninklijk besluit van 8 juli 1970 houdenen: 1.8260869565217392,
#  de algemeen verordening betreffen de met de inkomstenbelasting lijkgestelen belasting , vervangen bij het koninklijk besluit van 27 februari 2019 , worden vervangen als volgen :: 2.6086956521739126,
#
#   " Art. 8 .: 1.1956521739130435,
#  onverminderd de bepaling van artikel 24 , zijn de met de inkomstenbelasting gelijkgestelde belasting te betalen bij de rekenplichtig van de ontvan_gst belasten met fiscaal zaak van de Gewestelijke overheidsdienst Brussel: 1.7173913043478262,
#  Fiscaliteit of , in geval van zijn afwezigheid , bij de plaatsvervangend rekenplichtig van de ontvangsat belasten met fiscaal zaak van dezelfde dienst .: 0.43478260869565216,
#
#   Art. 4 .: 1.065217391304348,
#  in artikel 11 van hetzelfde besluit , wijzigen bij het koninklijk besluit van 14 april 1993 en bij het koninklijk besluit van 9 november 1999 en vervangen bij het koninklijk besluit van 17 februari 2019 , worden de woord " op de financiÃ « Le rekening van het ontvangkantoor Belastingen-auto " vervangen door de woord " volgens de door de gewestelijk overheidsdienst Brussel fiscaliteit aangegeven modaliteit " .: 4.6304347826086945,
#
#   : 1.0,
#  HOOFDSTUK 3 .: 0.17391304347826086,
#  - Wijzigingen van toepassing op de verkeersbelasting op de autovoertuig en de belasting op de inverkeerstelling waarvan het belastbaar feit vanaf 1 januari 2020 vallen
#   Art. 5 .: 3.4565217391304346,
#  de bepaling van dit hoofdstuk zijn uitsluitend van toepassing op de verkeersbelasting op de autovoertuig en de belasting op de inverkeerstelling waarvan het belastbaar feit vanaf 1 januari 2020 vallen .: 2.782608695652174,
#
#   Art. 6 .: 1.0434782608695652,
#  in artikel 15 van hetzelfde besluit , wijzigen bij het koninklijk besluit van 10 november 1980 en bij de wet van 19 februari 1990 , worden de volgen wijziging aan_brengen :
#   1Â ° paragraaf 1 worden op_heffen ;: 4.434782608695652,
#
#   2Â ° in paragraaf 2 worden: 1.5869565217391304,
#  de volgen: 0.13043478260869565,
#  wijziging aan_brengen :
#   à ) in de bepaling onder 1Â ° worden de woord " wet van 27 december 1974 betreffen de taxidienst en in_richten krachtens een vergunning regelmatig afgelevren te uitvoering van gezegen wet " vervangen door de woord " toepasselijk gewestelijk regelgeving en in_richten krachtens een vergunning regelmatig afgelevren te uitvoering van de noemen regelgeving " ;: 3.9999999999999987,
#
#   b ) de bepaling onder 2Â ° worden vervangen als volgen :: 2.0217391304347827,
#
#   " 2Â °: 1.434782608695652,
#  op de autovoertuig die uitsluitend aangewend worden tot een dienst voor het verhuren van voertuig met bestuurder onder de voorwaarde bepalen bij de toepasselijk gewestelijk regelgeving en in_richten krachtens een vergunning regelmatig afgelevren te uitvoering van de noemen regelgeving ;: 1.2608695652173911,
#
#   Art. 7 .: 1.0217391304347827,
#  in hetzelfde besluit worden de volgen bepaling op_heffen :
#   1Â ° de titel I , die bestaan uit de artikel 1 tot en met 14 ;: 3.4130434782608696,
#
#   2Â: 1.0,
#  ° het hoofdstuk III van titel II , dat bestaan uit de artikel 23 en 24 ;: 1.1956521739130435,
#
#   3Â °: 1.434782608695652,
#  het hoofdstuk IV van titel II , dat bestaan uit de artikel 25 en 26 ;
#   4Â: 1.7608695652173914,
#  ° het hoofdstuk V van titel II , dat bestaan uit de artikel 27 tot en met 29 ;: 1.2173913043478262,
#
#   5Â ° in het titel V , artikel 58 , wijzigen bij het koninklijk besluit van 14 april 1993 .: 2.9130434782608696,
#
#   : 1.0,
#  HOOFDSTUK 4 .: 0.17391304347826086,
#  - Wijzigingen van toepassing op de verkeersbelasting op de autovoertuig en de belasting op de inverkeerstelling ongeacht de datum van het belastbaar feit
#   Art. 8 .: 2.739130434782609,
#  in artikel 30 , Â§ 2 , van hetzelfde besluit opnieuw op_nemen bij het koninklijk besluit van 17 december 1984 , worden de volgen wijziging aan_brengen :
#   1Â ° in het één lid worden de woord " doen door middel van een formulier dat door administratie de direct belasting worden verstrekken " vervangen door de woord " in_dienen bij de Gewestelijke overheidsdienst: 4.978260869565215,
#  Fiscaliteit " ;
#   2Â: 1.0217391304347827,
#  °: 0.43478260869565216,
#  het twee lid worden op_heffen .: 0.3695652173913043,
#
#   : 1.0,
#  HOOFDSTUK 5 .: 0.2391304347826087,
#  - Inwerkingtreding en uitvoering: 0.10869565217391304,
#
#   Art. 9 .: 1.0434782608695652,
#  dit besluit hebben uitwerking met ingang van 1 januari 2020 .: 1.1304347826086956,
#
#   Art. 10 .: 1.0434782608695652,
#  de minister bevoegd voor FinanciÃ « n zijn belasten met de uitvoering van dit besluit .: 0.8913043478260869,
#
#   Brussel , 5 maart 2020 .: 1.3695652173913042,
#
#   voor de Brussels hoofdstedelijk regering :
#   de Minister_President van de Brussels hoofdstedelijk regering ,
#   R. VERVOORT
#   de minister van de Brussels hoofdstedelijk regering , belasten met FinanciÃ « n , begroting , openbaar ambt en de Promotie van Meertaligheid ,
#   S. GATZ : 6.021739130434782}

# %%
#From headhq import nlargest and calculate  30% of text with maximum score.
from heapq import nlargest
select_length=int(len(sentence_tokens)*0.3)
select_length
summary=nlargest(select_length, sentence_scores,key=sentence_scores.get)
summary
# Out:
# [Gelet op de gelijkekansentest uit_voeren op 22 november 2019 in toepassing van artikel 2 van de ordonnantie van 4 oktober 2018 tot invoering van de Gelijkekansentest ;
#   gelet op advies 66.928/4 van de Raad van State , geven op 12 februari 2020 , met toepassing van artikel 84 , Â§ 1 , één lid , 2Â ° , van de wet op de Raad van State , coÃ¶rdineren op 12 januari 1973 ;
#   overwegende dat de ordonnantie van 28 november 2019 tot wijziging van het wetboek van de met inkomstenbelasting lijkgestelen belasting in het kader van de overname van de dienst van de verkeersbelasting op de autovoertuig en van de belasting op de inverkeerstelling door het Brussels Hoofdstedelijk Gewest , in zijn artikel 3 , 1Â ° , a ) , iv , et b ) , 12 , 13 en 15 , 2Â ° en 3Â ° de bepaling die momenteel vervat zijn in de artikel 15 , Â§ 1 , en 58 van het koninklijk besluit van 8 juli 1970 houdenen,
#  Gelet op de bijzonder wet van 8 augustus 1980 tot hervorming de instelling , artikel 20 ;
#   gelet op het wetboek van de met inkomstenbelasting lijkgestelen belasting , artikel 5 , Â§ 1 , twee lid , wijzigen bij de ordonnantie van 28 november 2019 ;
#   gelet op het koninklijk besluit van 8 juli 1970 houdenen,
#
#   voor de Brussels hoofdstedelijk regering :
#   de Minister_President van de Brussels hoofdstedelijk regering ,
#   R. VERVOORT
#   de minister van de Brussels hoofdstedelijk regering , belasten met FinanciÃ « n , begroting , openbaar ambt en de Promotie van Meertaligheid ,
#   S. GATZ ,
#  in artikel 30 , Â§ 2 , van hetzelfde besluit opnieuw op_nemen bij het koninklijk besluit van 17 december 1984 , worden de volgen wijziging aan_brengen :
#   1Â ° in het één lid worden de woord " doen door middel van een formulier dat door administratie de direct belasting worden verstrekken " vervangen door de woord " in_dienen bij de Gewestelijke overheidsdienst,
#  de algemeen verordening betreffen de met de inkomstenbelasting lijkgestelen belasting , hebben Ã¯ntegreren in de artikel 5 , één lid , 3Â ° bis , en twee lid , en 96 , één lid , 3Â ° , a ) en twee lid van het wetboek van de met inkomstenbelasting lijkgestelen belasting ; dat deze bepaling derhalve moeten worden op_heffen ;,
#  de algemeen verordening betreffen de met de inkomstenbelasting lijkgestelen belasting , dus , voor wat deze belasting betreffen , moeten worden op_heffen , voor zover hun doel rechtstreeks worden over_nemen in de noemen Codex en zijn uitvoeringsbeslui ;
#   op voorstel van de minister van FinanciÃ « n , na beraadslaging ,
#   besluit :,
#  in artikel 11 van hetzelfde besluit , wijzigen bij het koninklijk besluit van 14 april 1993 en bij het koninklijk besluit van 9 november 1999 en vervangen bij het koninklijk besluit van 17 februari 2019 , worden de woord " op de financiÃ « Le rekening van het ontvangkantoor Belastingen-auto " vervangen door de woord " volgens de door de gewestelijk overheidsdienst Brussel fiscaliteit aangegeven modaliteit " .,
#  in artikel 15 van hetzelfde besluit , wijzigen bij het koninklijk besluit van 10 november 1980 en bij de wet van 19 februari 1990 , worden de volgen wijziging aan_brengen :
#   1Â ° paragraaf 1 worden op_heffen ;,
#  wijziging aan_brengen :
#   à ) in de bepaling onder 1Â ° worden de woord " wet van 27 december 1974 betreffen de taxidienst en in_richten krachtens een vergunning regelmatig afgelevren te uitvoering van gezegen wet " vervangen door de woord " toepasselijk gewestelijk regelgeving en in_richten krachtens een vergunning regelmatig afgelevren te uitvoering van de noemen regelgeving " ;,
#  de algemeen verordening betreffen de met de inkomstenbelasting lijkgestelen belasting in het kader van de overname van de dienst van de verkeersbelasting op de autovoertuig en de belasting op de inverkeerstelling door het Brussels Hoofdstedelijk Gewest
#
#
#   de Brussels hoofdstedelijk regering ,
#   ,
#  Fiscale Procedure en haar uitvoeringsbesluit van toepassing zijn op de verkeersbelasting op de autovoertuig en de belasting op de inverkeerstelling waarvan het belastbaar feit ontstaan vanaf 1 januari 2020 ; dat de procedureel bepaling vervat in Titel I van de het besluit van 8 juli 1970 houdenen,
#  - Wijzigingen van toepassing op de verkeersbelasting op de autovoertuig en de belasting op de inverkeerstelling waarvan het belastbaar feit vanaf 1 januari 2020 vallen
#   Art. 5 .,
#  - Wijzigingen van toepassing op de verkeersbelasting op de autovoertuig en de belasting op de inverkeerstelling waarvan het belastbaar feit vÃ³Ã³r 1 januari 2020 vallen
#   Art. 2 .,
#  in hetzelfde besluit worden de volgen bepaling op_heffen :
#   1Â ° de titel I , die bestaan uit de artikel 1 tot en met 14 ;,
#
#   5Â ° in het titel V , artikel 58 , wijzigen bij het koninklijk besluit van 14 april 1993 .,
#  de bepaling van dit hoofdstuk zijn uitsluitend van toepassing op de verkeersbelasting op de autovoertuig en de belasting op de inverkeerstelling waarvan het belastbaar feit vÃ³Ã³r 1 januari 2020 vallen .,
#  de bepaling van dit hoofdstuk zijn uitsluitend van toepassing op de verkeersbelasting op de autovoertuig en de belasting op de inverkeerstelling waarvan het belastbaar feit vanaf 1 januari 2020 vallen .,
#  - Wijzigingen van toepassing op de verkeersbelasting op de autovoertuig en de belasting op de inverkeerstelling ongeacht de datum van het belastbaar feit
#   Art. 8 .,
#  de algemeen verordening betreffen de met de inkomstenbelasting lijkgestelen belasting , vervangen bij het koninklijk besluit van 27 februari 2019 , worden vervangen als volgen :,
#  de verkeersbelasting op de autovoertuig ;
#   2Â ° de belasting op de inverkeerstelling .,
#  - besluit van de Brussels hoofdstedelijk regering tot wijziging van het koninklijk besluit van 8 juli 1970 houdenen]

# %%
#Get the summary of text
final_summary=[word.text for word in summary]
final_summary
summary=''.join(final_summary)
summary
# Out:
# 'Gelet op de gelijkekansentest uit_voeren op 22 november 2019 in toepassing van artikel 2 van de ordonnantie van 4 oktober 2018 tot invoering van de Gelijkekansentest ; \n gelet op advies 66.928/4 van de Raad van State , geven op 12 februari 2020 , met toepassing van artikel 84 , Â§ 1 , één lid , 2Â ° , van de wet op de Raad van State , coÃ¶rdineren op 12 januari 1973 ; \n overwegende dat de ordonnantie van 28 november 2019 tot wijziging van het wetboek van de met inkomstenbelasting lijkgestelen belasting in het kader van de overname van de dienst van de verkeersbelasting op de autovoertuig en van de belasting op de inverkeerstelling door het Brussels Hoofdstedelijk Gewest , in zijn artikel 3 , 1Â ° , a ) , iv , et b ) , 12 , 13 en 15 , 2Â ° en 3Â ° de bepaling die momenteel vervat zijn in de artikel 15 , Â§ 1 , en 58 van het koninklijk besluit van 8 juli 1970 houdenenGelet op de bijzonder wet van 8 augustus 1980 tot hervorming de instelling , artikel 20 ; \n gelet op het wetboek van de met inkomstenbelasting lijkgestelen belasting , artikel 5 , Â§ 1 , twee lid , wijzigen bij de ordonnantie van 28 november 2019 ; \n gelet op het koninklijk besluit van 8 juli 1970 houdenen\n voor de Brussels hoofdstedelijk regering : \n de Minister_President van de Brussels hoofdstedelijk regering , \n R. VERVOORT \n de minister van de Brussels hoofdstedelijk regering , belasten met FinanciÃ « n , begroting , openbaar ambt en de Promotie van Meertaligheid , \n S. GATZ \nin artikel 30 , Â§ 2 , van hetzelfde besluit opnieuw op_nemen bij het koninklijk besluit van 17 december 1984 , worden de volgen wijziging aan_brengen : \n 1Â ° in het één lid worden de woord " doen door middel van een formulier dat door administratie de direct belasting worden verstrekken " vervangen door de woord " in_dienen bij de Gewestelijke overheidsdienstde algemeen verordening betreffen de met de inkomstenbelasting lijkgestelen belasting , hebben Ã¯ntegreren in de artikel 5 , één lid , 3Â ° bis , en twee lid , en 96 , één lid , 3Â ° , a ) en twee lid van het wetboek van de met inkomstenbelasting lijkgestelen belasting ; dat deze bepaling derhalve moeten worden op_heffen ;de algemeen verordening betreffen de met de inkomstenbelasting lijkgestelen belasting , dus , voor wat deze belasting betreffen , moeten worden op_heffen , voor zover hun doel rechtstreeks worden over_nemen in de noemen Codex en zijn uitvoeringsbeslui ; \n op voorstel van de minister van FinanciÃ « n , na beraadslaging , \n besluit :in artikel 11 van hetzelfde besluit , wijzigen bij het koninklijk besluit van 14 april 1993 en bij het koninklijk besluit van 9 november 1999 en vervangen bij het koninklijk besluit van 17 februari 2019 , worden de woord " op de financiÃ « Le rekening van het ontvangkantoor Belastingen-auto " vervangen door de woord " volgens de door de gewestelijk overheidsdienst Brussel fiscaliteit aangegeven modaliteit " .in artikel 15 van hetzelfde besluit , wijzigen bij het koninklijk besluit van 10 november 1980 en bij de wet van 19 februari 1990 , worden de volgen wijziging aan_brengen : \n 1Â ° paragraaf 1 worden op_heffen ;wijziging aan_brengen : \n à ) in de bepaling onder 1Â ° worden de woord " wet van 27 december 1974 betreffen de taxidienst en in_richten krachtens een vergunning regelmatig afgelevren te uitvoering van gezegen wet " vervangen door de woord " toepasselijk gewestelijk regelgeving en in_richten krachtens een vergunning regelmatig afgelevren te uitvoering van de noemen regelgeving " ;de algemeen verordening betreffen de met de inkomstenbelasting lijkgestelen belasting in het kader van de overname van de dienst van de verkeersbelasting op de autovoertuig en de belasting op de inverkeerstelling door het Brussels Hoofdstedelijk Gewest \n\n\n de Brussels hoofdstedelijk regering , \n Fiscale Procedure en haar uitvoeringsbesluit van toepassing zijn op de verkeersbelasting op de autovoertuig en de belasting op de inverkeerstelling waarvan het belastbaar feit ontstaan vanaf 1 ...

# %%
len(summary)
# Out:
# 5605

# %%
# all the texts together
# import glob 

# path = 'text_nl/*.txt'

# all_texts=""

# for file in glob.glob(path):
#     with open(file, encoding='utf-8', errors='ignore') as file_in:
#         text = file_in.read()
#         all_texts+=text
#         lines = text.split('\n')
#         for line in lines:
#             line = nlp(line)
#             for token in line:
#                 print(token)

# %%
#len(all_texts)

# %%
#docs = list(nlp.pipe(all_texts), n_process=4)
# docs = nlp.pipe(all_texts, n_process=4)

# %%
# from collections import Counter

# all_laws = []

# for d in docs:
#     laws = [ent.text for ent in d.ents if ent.label_ == "LAW"]
#     all_laws.extend(laws)

# Counter(all_laws).most_common(2)

# %% [markdown]
# ### Creating a dataframe from files

# %%
#all the texts together
def createDF(path):
    """
    This function receives a path where files and merge the files into a dataframe
    
    """

    path = path
    dataframes = []
    df = pd.DataFrame(columns = ["article_content"])

    for file in glob.glob(path):
        with open(file, encoding='utf-8', errors='ignore') as file_in:
            dataframe = file_in.read().replace('\n', '')
            dataframes.append(dataframe)
    to_append = dataframes
    my_series = pd.Series(to_append)
    df["article_content"]= my_series
    
    return df

# %%
df = createDF('clean_text_nl/*.txt')

# %%
df.head()
# Out:
#                                      article_content
# 0  Dienst Reglementering. - Akkoord in onderling ...
# 1  Wet houdende fiscale, fraudebestrijdende, fina...
# 2  Decreet houdende bekrachtiging van de besluite...
# 3  Dienst Reglementering. - Akkoord in onderling ...
# 4  Bijzondere machtenbesluit van de Brusselse Hoo...

# %%
df.iloc[[5]]
# Out:
#                                      article_content
# 5  Ministerieel besluit houdende wijziging van he...

# %%
df.iloc[[6]].to_string()
# Out:
# '                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...

# %%
# # Parser for content
# parser = Dutch()
# punctuations = punctuation
# stopwords = list(STOP_WORDS)
# def spacy_tokenizer(sentence):
#     mytokens = parser(sentence)
#     mytokens = [word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in mytokens ]
#     print(mytokens)
#     mytokens = [word for word in mytokens if word not in stopwords and word not in punctuations ]
#     mytokens = " ".join([i for i in mytokens])
#     return mytokens

# %%
#ref: https://stackoverflow.com/questions/45605946/how-to-do-text-pre-processing-using-spacy
stopwords = list(STOP_WORDS)
punctuations = punctuation
def normalize(comment, lowercase, remove_stopwords):
    """
    This function is used to normalize the text, remove stopwords and punctuations
    
    """
    if lowercase:
        comment = comment.lower()
    comment = nlp(comment)
    lemmatized = list()
    for word in comment:
        lemma = word.lemma_.strip()
        if lemma:
            if not remove_stopwords or (remove_stopwords and lemma not in stopwords and lemma not in punctuations):
                lemmatized.append(lemma)
    return " ".join(lemmatized)

# %%
tqdm.pandas()
df["processed_content"] = df["article_content"].progress_apply(normalize, lowercase=True, remove_stopwords=True)
#df["processed_content"] = df["article_content"].progress_apply(spacy_tokenizer)
# Out:
# 100%|██████████| 673/673 [03:02<00:00,  3.68it/s]

# %%
df
# Out:
#                                        article_content  \
# 0    Dienst Reglementering. - Akkoord in onderling ...
# 1    Wet houdende fiscale, fraudebestrijdende, fina...
# 2    Decreet houdende bekrachtiging van de besluite...
# 3    Dienst Reglementering. - Akkoord in onderling ...
# 4    Bijzondere machtenbesluit van de Brusselse Hoo...
# ..                                                 ...
# 668  Wet houdende diverse dringende fiscale bepalin...
# 669  Selectienummer: AFG20033 Deze selectie werd af...
# 670  Selectienummer: ANG21030 Solliciteren kan tot ...
# 671  Besluit van de Vlaamse Regering tot wijziging ...
# 672  Besluit van de Brusselse Hoofdstedelijke Reger...
#
#                                      processed_content
# 0    dienst reglementering akkoord onderling overle...
# 1    wet houden fiscaal fraudebestrijdend financile...
# 2    decreet houden bekrachtiging besluit Waals reg...
# 3    dienst reglementering akkoord onderling overle...
# 4    bijzonder machtenbesluit Brussels hoofdstedeli...
# ..                                                 ...
# 668  wet houden divers dringend fiscaal bepaling ge...
# 669  selectie_nummer Afg20033 selectie af_sluiten 2...
# 670  selectie_nummer ang21030 solliciteren 06/04/20...
# 671  besluit Vlaams regering wijziging besluit Vlaa...
# 672  besluit Brussels hoofdstedelijk regering betre...
#
# [673 rows x 2 columns]

# %%
df["processed_content"][6]
# Out:
# 'bijzonderemachtenbesluit Brussels hoofdstedelijk regering nummer 2020/051 houden divers maatregel oog tijdelijk opschorting belasting inrichting toeristisch logie grond gezondheidscrisis covid-19 verslag Brussels hoofdstedelijk regering attentie lid regering voorontwerp besluit onderzoek voor_leggen strekt ertoe exploitant actief Brussels sector toeristisch verblijf financieel helpen normaal omstandigheid uitbater inrichting toeristisch logie onderwerpen city tax berekenen per overnachting voorzien ordonnantie 23 december 2016 betreffen gewestbelasting inrichting toeristisch logie uit_breken gezondheidscrisis gevolg covid-19-coronavirus effect wereldwijde crisis economisch activiteit toerisme vraag overnachting inrichting toeristisch logies sterk verminderen vermindering internationaal toeristisch verplaatsing bijzonder zakentoerisme waarvan Brussels hotelsector sterk afhankelijk sterk impact sector ondanks laag bezettingsgraad trachten overleven aanzienlijk aantal inrichting toeristisch logies dwingen activiteit staken sector moment groot gevaar dringend maatregel nemen voortbestaan ervan waarborgen verhopen terugkeer niveau activiteit vr De gezondheidscrisis steunmaatrege aan_nemen Brussels hoofdstedelijk gewest gunst bovengenoemd exploitant bestaan erin bepalen verplichting betrekking gewestbelasting inrichting toeristisch logies op_schorten belasting inrichting toeristisch logies schorsen 1 januari 2020 30 juni 2020 gevolg goedkeuring bijzonderemachtenbesluit Brussels hoofdstedelijk regering nummer 2020/005 houden 16 april 2020 divers maatregel betrekking belasting inrichting toeristisch logie grond gezondheidscrisis covid-19 situatie verbeteren maatregel één keer verlengen 1 juli 31 december 2020 bepalen ordonnantie 29 oktober 2020 houden divers maatregel betrekking belasting inrichting toeristisch logie grond gezondheidscrisis covid-19 kwetsbar toestand sector toeristisch logie verwachten respijt krijgen sector blijven dicht faillissement naam aankondiging risico drie verspreidingsgolf covid-19-_virus geval socio-economisch effect pandemie loop één semester 2021 voelbaar zowel restrictief maatregel waarschijnlijk aan_houden één semester 2021 langetermijneffect economisch crisis economisch sector Brussels hoofdstedelijk gewest hard treffen sector verdienen steun regering zien belang gewestelijk economie werkgelegenheid concreet omvatten opschorting belasting inrichting toeristisch logie volgen maatregel lopen 1 januari 2021 30 juni 2021 1 verschuldigen belasting uitbater inrichting toeristisch logies bepalen geval eigenaar onroerend goed waarin inrichting uit_baaten 2 opschorting verplichting kennisgeving uitbating opening inrichting toeristisch logies termijn 31 dag 3 schorsing rechtzetting gewestelijk fiscaal administratie aangift in_dienen belastingplichtig 4 schorsing ambtshalf heffing fiscaal administratie 5 schorsing vraag voorafbetaling op_stellen fiscaal administratie basis belastingplichtig aan_geven daarmee samenhangen belastingplichtig verplichten dergelijk voorafbetaling verrichten belasting verschuldigen 6 bedrag eventueel ondanks bovengenoemd maatregel gewestelijk fiscaal administratie ontvangen terug_betalen belastingplichtig moratoir interest beginnen lopen belastingplichtig vrij_stellen verplichting ingevulen on_derteken aangifte_formulier gewestelijk fiscaal administratie terug af_sturen doel behoud verplichting regering staat stellen ontwikkeling sector toeristisch logies dicht op_volgen relevantie toekomstig bij_komen maatregel in_schatten informatie Brussels hoofdstedelijk regering minister Financin begroting s. gatz 7 januari 2021 bijzonderemachtenbesluit Brussels hoofdstedelijk regering nummer 2020/051 houden divers maatregel oog tijdelijk opschorting belasting inrichting toeristisch logie grond gezondheidscrisis covid-19 Brussels hoofdstedelijk regering letten ordonnantie 23 december 2016 betreffen gewestbelasting inrichting toeristisch logi_e artikel 3 6 7 8 9 10 letten ordonnantie 23 november 20 ...

# %%
df["article_content"][6]
# Out:
# 'Bijzonderemachtenbesluit van de Brusselse Hoofdstedelijke Regering nr. 2020/051 houdende diverse maatregelen met het oog op de tijdelijke opschorting van de belasting op de inrichtingen van toeristisch logies op grond van de gezondheidscrisis van de COVID-19 VERSLAG AAN DE BRUSSELSE HOOFDSTEDELIJKE REGERING Ter attentie van de leden van de Regering, Het voorontwerp van besluit dat aan u ter onderzoek wordt voorgelegd strekt ertoe de exploitanten die actief zijn in de Brusselse sector van het toeristisch verblijf financieel te helpen. Onder normale omstandigheden zijn de uitbaters van inrichtingen van toeristisch logies onderworpen aan de City Tax, berekend per overnachting, die is voorzien in de ordonnantie van 23 december 2016 betreffende de gewestbelasting op de inrichtingen van toeristisch logies. Sinds het uitbreken van de gezondheidscrisis als gevolg van het COVID-19-coronavirus, hebben de effecten van deze wereldwijde crisis op de economische activiteit en het toerisme de vraag naar overnachtingen in inrichtingen van toeristisch logies zeer sterk verminderd. De vermindering van de internationale toeristische verplaatsingen, en in het bijzonder van het zakentoerisme waarvan de Brusselse hotelsector sterk afhankelijk is, heeft een sterke impact gehad op deze sector, die ondanks een zeer lage bezettingsgraad tracht te overleven, terwijl een aanzienlijk aantal inrichtingen van toeristisch logies gedwongen zijn hun activiteiten in het geheel te staken. Deze sector is op dit moment in groot gevaar en er moeten dringende maatregelen worden genomen om het voortbestaan ervan te waarborgen tot de verhoopte terugkeer naar het niveau van de activiteiten van vr de gezondheidscrisis. En van de steunmaatregelen aangenomen door het Brusselse Hoofdstedelijke Gewest ten gunste van de bovengenoemde exploitanten bestond erin om bepaalde van hun verplichtingen met betrekking tot de gewestbelasting op de inrichtingen van toeristisch logies op te schorten. Zo werd de belasting op de inrichtingen van toeristisch logies geschorst van 1 januari 2020 tot en met 30 juni 2020, als gevolg van de goedkeuring van het bijzonderemachtenbesluit van de Brusselse Hoofdstedelijke Regering nr. 2020/005 en houdende van 16 april 2020 diverse maatregelen met betrekking tot de belasting op de inrichtingen van toeristisch logies op grond van de gezondheidscrisis van de COVID-19. Aangezien de situatie niet verbeterde, werden de maatregelen een eerste keer verlengd, van 1 juli tot en met 31 december 2020, zoals bepaald door de ordonnantie van 29 oktober 2020 houdende diverse maatregelen met betrekking tot de belasting op de inrichtingen van toeristisch logies op grond van de gezondheidscrisis van de COVID-19. De kwetsbare toestand van de sector van het toeristisch logies heeft echter niet het verwachte respijt gekregen en de sector blijft dicht bij het faillissement, met name door de aankondiging van het risico van een derde verspreidingsgolf van het COVID-19-virus. In elk geval zullen de socio-economische effecten van de pandemie in de loop van het eerste semester van 2021 nog steeds voelbaar zijn, zowel omdat de restrictieve maatregelen waarschijnlijk zullen worden aangehouden tijdens het eerste semester van 2021, als door de langetermijneffecten van de economische crisis die deze economische sector van het Brusselse Hoofdstedelijke Gewest hard heeft getroffen. Deze sector verdient de steun van de Regering gezien haar belang voor de gewestelijke economie en werkgelegenheid. Concreet omvat de opschorting van de belasting op de inrichtingen van toeristisch logies de volgende maatregelen die lopen van 1 januari 2021 tot en met 30 juni 2021: 1) het niet verschuldigd zijn van de belasting door de uitbater van een inrichting van toeristisch logies, of in bepaalde gevallen door de eigenaar van het onroerend goed waarin de inrichting wordt uitgebaat; 2) de opschorting van de verplichting tot kennisgeving van de uitbating of de opening van een inrichting van toeristisch l ...
