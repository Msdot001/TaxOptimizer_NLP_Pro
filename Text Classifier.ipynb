# %%
import numpy as np
import pandas as pd
import spacy
from spacy import displacy
from spacy.lang.nl.stop_words import STOP_WORDS
from string import punctuation
from spacy.lang.nl import Dutch

# %%
# load a medium sized dutch language model in spacy
nlp = spacy.load('nl_core_news_md')

# %%
#Ref for attempting summarization https://www.numpyninja.com/post/text-summarization-through-use-of-spacy-library

# %%
myfile = open("TaxRelatedFile.txt")

# %%
text = myfile.read()

# %%
print(text)
# Out:
# BRUSSELS HOOFDSTEDELIJK GEWEST
# 5 MAART 2020. - Besluit van de Brusselse Hoofdstedelijke Regering tot wijziging van het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen in het kader van de overname van de dienst van de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling door het Brussels Hoofdstedelijk Gewest
#
#
# De Brusselse Hoofdstedelijke Regering,
# Gelet op de bijzondere wet van 8 augustus 1980 tot hervorming der instellingen, artikel 20;
# Gelet op het Wetboek van de met inkomstenbelastingen gelijkgestelde belastingen, artikelen 5, Â§ 1, tweede lid, gewijzigd bij de ordonnantie van 28 november 2019;
# Gelet op het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen;
# Gelet op de gelijkekansentest uitgevoerd op 22 november 2019 in toepassing van artikel 2 van de ordonnantie van 4 oktober 2018 tot invoering van de gelijkekansentest;
# Gelet op advies 66.928/4 van de Raad van State, gegeven op 12 februari 2020, met toepassing van artikel 84, Â§ 1, eerste lid, 2Â°, van de wetten op de Raad van State, gecoÃ¶rdineerd op 12 januari 1973;
# Overwegende dat de ordonnantie van 28 november 2019 tot wijziging van het Wetboek van de met inkomstenbelastingen gelijkgestelde belastingen in het kader van de overname van de dienst van de verkeersbelasting op de autovoertuigen en van de belasting op de inverkeerstelling door het Brussels Hoofdstedelijk Gewest, in zijn artikelen 3, 1Â°, a), iv, et b), 12, 13 en 15, 2Â° en 3Â° de bepalingen die momenteel vervat zijn in de artikelen 15, Â§ 1, en 58 van het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen, heeft geÃ¯ntegreerd in de artikelen 5, eerste lid, 3Â° bis, en tweede lid, en 96, eerste lid, 3Â°, a) en tweede lid van het Wetboek van de met inkomstenbelastingen gelijkgestelde belastingen; dat deze bepalingen derhalve moeten worden opgeheven;
# Overwegende dat de ordonnantie van 19 december 2019 houdende de wijziging van de procedurele bepalingen in het kader van de overname van de dienst van de verkeersbelastingen en houdende diverse bepalingen tot gevolg heeft dat de ordonnantie van 6 maart 2019 betreffende de Brusselse Codex Fiscale Procedure en haar uitvoeringsbesluit van toepassing zijn op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit ontstaat vanaf 1 januari 2020; dat de procedurele bepalingen vervat in Titel I van de het besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen, dus, voor wat deze belastingen betreft, moeten worden opgeheven, voor zover hun doel rechtstreeks wordt overgenomen in de genoemde Codex en zijn uitvoeringsbesluiten;
# Op voorstel van de Minister van FinanciÃ«n, na beraadslaging,
# Besluit :
# HOOFDSTUK 1. - Inleidende bepaling
# Artikel 1. Dit besluit is uitsluitend van toepassing op:
# 1Â° de verkeersbelasting op de autovoertuigen;
# 2Â° de belasting op de inverkeerstelling.
# HOOFDSTUK 2. - Wijzigingen van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit vÃ³Ã³r 1 januari 2020 valt
# Art. 2. De bepalingen van dit hoofdstuk zijn uitsluitend van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit vÃ³Ã³r 1 januari 2020 valt.
# Art. 3. Artikel 8 van het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen, vervangen bij het koninklijk besluit van 27 februari 2019, wordt vervangen als volgt:
# "Art. 8. Onverminderd de bepalingen van artikel 24, zijn de met de inkomstenbelastingen gelijkgestelde belastingen te betalen bij de rekenplichtige van de ontvangsten belast met fiscale zaken van de Gewestelijke Overheidsdienst Brussel Fiscaliteit of, in geval van zijn afwezigheid, bij de plaatsvervangend rekenplichtige van de ontvangsten belast met fiscale zaken van dezelfde dienst.".
# Art. 4. In artikel 11 van hetzelfde besluit, gewijzigd bij het koninklijk besluit van 14 april 1993 en bij het koninklijk besluit van 9 november 1999 en vervangen bij het koninklijk besluit van 17 februari 2019, worden de woorden " op de financiÃ«le rekening van het ontvangkantoor Belastingen-auto's" vervangen door de woorden "volgens de door de Gewestelijke Overheidsdienst Brussel Fiscaliteit aangegeven modaliteiten".
# HOOFDSTUK 3. - Wijzigingen van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit vanaf 1 januari 2020 valt
# Art. 5. De bepalingen van dit hoofdstuk zijn uitsluitend van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit vanaf 1 januari 2020 valt.
# Art. 6. In artikel 15 van hetzelfde besluit, gewijzigd bij het koninklijk besluit van 10 november 1980 en bij de wet van 19 februari 1990, worden de volgende wijzigingen aangebracht :
# 1Â° paragraaf 1 wordt opgeheven;
# 2Â° in paragraaf 2 worden de volgende wijzigingen aangebracht:
# a) in de bepaling onder 1Â° worden de woorden "wet van 27 december 1974 betreffende de taxidiensten en ingericht krachtens een vergunning regelmatig afgeleverd ter uitvoering van gezegde wet" vervangen door de woorden "toepasselijke gewestelijke regelgeving en ingericht krachtens een vergunning regelmatig afgeleverd ter uitvoering van de genoemde regelgeving";
# b) de bepaling onder 2Â° wordt vervangen als volgt:
# "2Â° op de autovoertuigen die uitsluitend aangewend worden tot een dienst voor het verhuren van voertuigen met bestuurder onder de voorwaarden bepaald bij de toepasselijke gewestelijke regelgeving en ingericht krachtens een vergunning regelmatig afgeleverd ter uitvoering van de genoemde regelgeving;".
# Art. 7. In hetzelfde besluit worden de volgende bepalingen opgeheven:
# 1Â° de titel I, die bestaat uit de artikelen 1 tot en met 14 ;
# 2Â° het hoofdstuk III van titel II, dat bestaat uit de artikelen 23 en 24;
# 3Â° het hoofdstuk IV van titel II, dat bestaat uit de artikelen 25 en 26;
# 4Â° het hoofdstuk V van titel II, dat bestaat uit de artikelen 27 tot en met 29;
# 5Â° in het titel V, artikel 58, gewijzigd bij het koninklijk besluit van 14 april 1993.
# HOOFDSTUK 4. - Wijzigingen van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling ongeacht de datum van het belastbaar feit
# Art. 8. In artikel 30, Â§ 2, van hetzelfde besluit opnieuw opgenomen bij het koninklijk besluit van 17 december 1984, worden de volgende wijzigingen aangebracht:
# 1Â° in het eerste lid worden de woorden "gedaan door middel van een formulier dat door Administratie der directe belastingen wordt verstrekt" vervangen door de woorden "ingediend bij de Gewestelijke Overheidsdienst Brussel Fiscaliteit";
# 2Â° het tweede lid wordt opgeheven.
# HOOFDSTUK 5. - Inwerkingtreding en uitvoering
# Art. 9. Dit besluit heeft uitwerking met ingang van 1 januari 2020.
# Art. 10. De Minister bevoegd voor FinanciÃ«n is belast met de uitvoering van dit besluit.
# Brussel, 5 maart 2020.
# Voor de Brusselse Hoofdstedelijke Regering :
# De Minister-President van de Brusselse Hoofdstedelijke Regering,
# R. VERVOORT
# De Minister van de Brusselse Hoofdstedelijke Regering, belast met FinanciÃ«n, Begroting, Openbaar ambt en de Promotie van Meertaligheid,
# S. GATZ

# %%
len(text)
# Out:
# 7592

# %%
doc=nlp(text)

# %%
for sent in doc.sents:
    print(sent)
# Out:
# BRUSSELS HOOFDSTEDELIJK GEWEST
#
# 5 MAART 2020.
# - Besluit van de Brusselse Hoofdstedelijke Regering tot wijziging van het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen in het kader van de overname van de dienst van de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling door het Brussels Hoofdstedelijk Gewest
#
#
# De Brusselse Hoofdstedelijke Regering,
#
# Gelet op de bijzondere wet van 8 augustus 1980 tot hervorming der instellingen, artikel 20;
#
# Gelet op het Wetboek van de met inkomstenbelastingen gelijkgestelde belastingen, artikelen
# 5, Â§
# 1, tweede lid, gewijzigd bij de ordonnantie van 28 november 2019;
#
# Gelet op het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen;
#
# Gelet op de gelijkekansentest uitgevoerd op 22 november 2019 in toepassing van artikel 2 van de ordonnantie van 4 oktober 2018 tot invoering van de gelijkekansentest;
#
# Gelet op advies 66.928/4 van de Raad van State, gegeven op 12 februari 2020, met toepassing van artikel 84, Â§ 1, eerste lid, 2Â°, van de wetten op de Raad van State, gecoÃ¶rdineerd op 12 januari 1973;
#
# Overwegende dat de ordonnantie van 28 november 2019 tot wijziging van het Wetboek van de met inkomstenbelastingen gelijkgestelde belastingen in het kader van de overname van de dienst van de verkeersbelasting op de autovoertuigen en van de belasting op de inverkeerstelling door het Brussels Hoofdstedelijk Gewest, in zijn artikelen 3, 1Â°, a), iv, et b), 12, 13 en 15, 2Â° en 3Â° de bepalingen die momenteel vervat zijn in de artikelen 15, Â§ 1, en 58 van het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen, heeft geÃ¯ntegreerd in de artikelen
# 5, eerste lid, 3Â° bis, en tweede lid, en 96, eerste lid, 3Â°, a) en tweede lid van het Wetboek van de met inkomstenbelastingen gelijkgestelde belastingen; dat deze bepalingen derhalve moeten worden opgeheven;
#
#
# Overwegende dat de ordonnantie van 19 december 2019 houdende de wijziging van de procedurele bepalingen in het kader van de overname van de dienst van de verkeersbelastingen en houdende diverse bepalingen tot gevolg heeft dat de ordonnantie van 6 maart 2019 betreffende de Brusselse Codex
# Fiscale Procedure en haar uitvoeringsbesluit van toepassing zijn op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit ontstaat vanaf 1 januari 2020; dat de procedurele bepalingen vervat in Titel I van de het besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen, dus, voor wat deze belastingen betreft, moeten worden opgeheven, voor zover hun doel rechtstreeks wordt overgenomen in de genoemde Codex en zijn uitvoeringsbesluiten;
#
# Op voorstel van de Minister van FinanciÃ«n, na beraadslaging,
#
# Besluit :
#
# HOOFDSTUK 1.
# -
# Inleidende bepaling
#
# Artikel 1.
# Dit besluit is uitsluitend van toepassing op:
# 1Â°
# de verkeersbelasting op de autovoertuigen;
# 2Â
# ° de belasting op de inverkeerstelling.
#
#
# HOOFDSTUK 2.
# - Wijzigingen van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit vÃ³Ã³r 1 januari 2020 valt
# Art. 2.
# De bepalingen van dit hoofdstuk zijn uitsluitend van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit vÃ³Ã³r 1 januari 2020 valt.
#
#
# Art. 3.
# Artikel 8 van het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen, vervangen bij het koninklijk besluit van 27 februari 2019, wordt vervangen als volgt:
# "Art. 8.
# Onverminderd de bepalingen van artikel 24, zijn de met de inkomstenbelastingen gelijkgestelde belastingen te betalen bij de rekenplichtige van de ontvangsten belast met fiscale zaken van de Gewestelijke Overheidsdienst
# Brussel
# Fiscaliteit of, in geval van zijn afwezigheid, bij de plaatsvervangend rekenplichtige van de ontvangsten belast met fiscale zaken van dezelfde dienst.
# ".
#
#
# Art. 4.
# In artikel 11 van hetzelfde besluit, gewijzigd bij het koninklijk besluit van 14 april 1993 en bij het koninklijk besluit van 9 november 1999 en vervangen bij het koninklijk besluit van 17 februari 2019, worden de woorden " op de financiÃ«le rekening van het ontvangkantoor Belastingen-auto's" vervangen door de woorden "volgens de door de Gewestelijke Overheidsdienst
# Brussel
# Fiscaliteit aangegeven modaliteiten".
#
#
# HOOFDSTUK 3.
# - Wijzigingen van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit vanaf 1 januari 2020 valt
# Art. 5.
# De bepalingen van dit hoofdstuk zijn uitsluitend van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit vanaf 1 januari 2020 valt.
#
#
# Art. 6.
# In artikel 15 van hetzelfde besluit, gewijzigd bij het koninklijk besluit van 10 november 1980 en bij de wet van 19 februari 1990, worden de volgende wijzigingen aangebracht :
# 1Â° paragraaf 1 wordt opgeheven;
# 2Â° in paragraaf 2 worden de volgende wijzigingen aangebracht:
# a) in de bepaling onder 1Â° worden de woorden "wet van 27 december 1974 betreffende de taxidiensten en ingericht krachtens een vergunning regelmatig afgeleverd ter uitvoering van gezegde wet" vervangen door de woorden "toepasselijke gewestelijke regelgeving en ingericht krachtens een vergunning regelmatig afgeleverd ter uitvoering van de genoemde regelgeving";
# b)
# de bepaling onder 2Â° wordt vervangen als volgt:
# "2Â° op de autovoertuigen die uitsluitend aangewend worden tot een dienst voor het verhuren van voertuigen met bestuurder onder de voorwaarden bepaald bij de toepasselijke gewestelijke regelgeving en ingericht krachtens een vergunning regelmatig afgeleverd ter uitvoering van de genoemde regelgeving;
# ".
#
#
# Art. 7.
# In hetzelfde besluit worden de volgende bepalingen opgeheven:
# 1Â°
# de titel I, die bestaat uit de artikelen 1 tot en met 14 ;
# 2Â° het hoofdstuk III van titel II, dat bestaat uit de artikelen 23 en 24;
# 3Â°
# het hoofdstuk IV van titel II, dat bestaat uit de artikelen 25 en 26;
# 4Â°
# het hoofdstuk V van titel II, dat bestaat uit de artikelen 27 tot en met 29;
# 5Â° in het titel V, artikel 58, gewijzigd bij het koninklijk besluit van 14 april 1993.
#
#
# HOOFDSTUK 4.
# - Wijzigingen van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling ongeacht de datum van het belastbaar feit
# Art. 8.
# In artikel 30, Â§ 2, van hetzelfde besluit opnieuw opgenomen bij het koninklijk besluit van 17 december 1984, worden de volgende wijzigingen aangebracht:
# 1Â° in het eerste lid worden de woorden "gedaan door middel van een formulier dat door Administratie der directe belastingen wordt verstrekt" vervangen door de woorden "ingediend bij de Gewestelijke Overheidsdienst
# Brussel
# Fiscaliteit";
#
# 2Â
# °
# het tweede lid wordt opgeheven.
#
#
# HOOFDSTUK 5.
# - Inwerkingtreding en uitvoering
# Art. 9.
# Dit besluit heeft uitwerking met ingang van 1 januari 2020.
#
# Art. 10.
# De Minister bevoegd voor FinanciÃ«n is belast met de uitvoering van dit besluit.
#
#
# Brussel, 5 maart 2020.
#
#
# Voor de Brusselse Hoofdstedelijke Regering :
#
# De Minister-President van de Brusselse Hoofdstedelijke Regering,
#
# R. VERVOORT
#
# De Minister van de Brusselse Hoofdstedelijke Regering, belast met FinanciÃ«n, Begroting, Openbaar ambt en de Promotie van Meertaligheid,
# S. GATZ

# %%
#Take a look at how many words are in the document
len(doc)
# Out:
# 1350

# %%
#Look document-level attributes
dir(doc)
# Out:
# ['_',
#  '__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '_bulk_merge',
#  '_context',
#  '_get_array_attrs',
#  '_realloc',
#  '_vector',
#  '_vector_norm',
#  'cats',
#  'char_span',
#  'copy',
#  'count_by',
#  'doc',
#  'ents',
#  'extend_tensor',
#  'from_array',
#  'from_bytes',
#  'from_dict',
#  'from_disk',
#  'from_docs',
#  'get_extension',
#  'get_lca_matrix',
#  'has_annotation',
#  'has_extension',
#  'has_unknown_spaces',
#  'has_vector',
#  'is_nered',
#  'is_parsed',
#  'is_sentenced',
#  'is_tagged',
#  'lang',
#  'lang_',
#  'mem',
#  'noun_chunks',
#  'noun_chunks_iterator',
#  'remove_extension',
#  'retokenize',
#  'sentiment',
#  'sents',
#  'set_ents',
#  'set_extension',
#  'similarity',
#  'spans',
#  'tensor',
#  'text',
#  'text_with_ws',
#  'to_array',
#  'to_bytes',
#  'to_dict',
#  'to_disk',
#  'to_json',
#  'to_utf8_array',
#  'user_data',
#  'user_hooks',
#  'user_span_hooks',
#  'user_token_hooks',
#  'vector',
#  'vector_norm',
#  'vocab']

# %%
print(doc[5])
# Out:
# MAART

# %% [markdown]
# Using spaCy's built-in visualizer to detect named entities in the document

# %%
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BRUSSELS HOOFDSTEDELIJK GEWEST
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5 MAART 2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . - Besluit van de
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brusselse Hoofdstedelijke Regering
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  tot wijziging van het koninklijk besluit van
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8 juli 1970
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen in het kader van de overname van de dienst van de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling door het
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brussels Hoofdstedelijk Gewest
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br></br></br>De
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brusselse Hoofdstedelijke Regering
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,</br>Gelet op de bijzondere wet van
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8 augustus 1980
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  tot hervorming der instellingen, artikel
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ;</br>Gelet op het
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wetboek van de met inkomstenbelastingen gelijkgestelde belastingen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
# , artikelen
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# , Â§
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tweede
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  lid, gewijzigd bij de ordonnantie van
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     28 november 2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ;</br>Gelet op het koninklijk besluit van
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8 juli 1970
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen;</br>Gelet op de gelijkekansentest uitgevoerd op
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     22 november 2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  in toepassing van artikel
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  van de ordonnantie van
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4 oktober 2018
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  tot invoering van de gelijkekansentest;</br>Gelet op advies
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     66.928/4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  van de
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Raad van State
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , gegeven op
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12 februari 2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , met toepassing van artikel
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     84
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# , Â§
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eerste
#     <span style="font-size: 0.8em; font-weight: bold; line-heig

# %% [markdown]
# Look up at label LAW, some tokens related to taxes were identified by spaCy with this label

# %%
spacy.explain("LAW")
# Out:
# 'Named documents made into laws.'

# %% [markdown]
# ### Lemmatization

# %%
review = str(" ".join([i.lemma_ for i in doc]))

# %%
doc = nlp(review)
spacy.displacy.render(doc, style='ent',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BRUSSELS HOOFDSTEDELIJK gEWEST
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  </br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5 MAART 2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  . - besluit van de
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brussels
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  hoofdstedelijk regering tot wijziging van het koninklijk besluit van
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8 juli 1970
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  houdenen de algemeen verordening betreffen de met de inkomstenbelasting lijkgestelen belasting in het kader van de overname van de dienst van de verkeersbelasting op de autovoertuig en de belasting op de inverkeerstelling door het
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brussels Hoofdstedelijk Gewest
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  </br></br></br> de
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brussels
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  hoofdstedelijk regering , </br> Gelet op de bijzonder wet van
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8 augustus 1980
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  tot hervorming de instelling , artikel
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  ; </br> gelet op het wetboek van de met inkomstenbelasting lijkgestelen belasting , artikel
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  , Â§
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     twee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  lid , wijzigen bij de ordonnantie van
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     28 november 2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  ; </br> gelet op het koninklijk besluit van
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8 juli 1970
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  houdenen de algemeen verordening betreffen de met de inkomstenbelasting gelijkgestelde belasting ; </br> Gelet op de
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gelijkekansentest
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  uit_voeren op
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     22 november 2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  in toepassing van artikel
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  van de ordonnantie van
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4 oktober 2018
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  tot invoering van de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gelijkekansentest
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  ; </br> gelet op advies
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     66.928/4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  van de
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Raad van State
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  , geven op
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12 februari 2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  , met toepassing van artikel
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     84
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  , Â§
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radi

# %% [markdown]
# ### Parts of Speech tagging

# %%
for i in nlp(review):
    print(i, "=>", i.pos_)
# Out:
# BRUSSELS => PROPN
# HOOFDSTEDELIJK => PROPN
# gEWEST => PROPN
#
#   => SPACE
# 5 => NUM
# MAART => PROPN
# 2020 => NUM
# . => PUNCT
# - => PUNCT
# besluit => NOUN
# van => ADP
# de => DET
# Brussels => PROPN
# hoofdstedelijk => ADJ
# regering => NOUN
# tot => ADP
# wijziging => NOUN
# van => ADP
# het => DET
# koninklijk => ADJ
# besluit => NOUN
# van => ADP
# 8 => NUM
# juli => PROPN
# 1970 => NUM
# houdenen => VERB
# de => DET
# algemeen => ADJ
# verordening => NOUN
# betreffen => VERB
# de => DET
# met => ADP
# de => DET
# inkomstenbelasting => NOUN
# lijkgestelen => VERB
# belasting => NOUN
# in => ADP
# het => DET
# kader => NOUN
# van => ADP
# de => DET
# overname => NOUN
# van => ADP
# de => DET
# dienst => NOUN
# van => ADP
# de => DET
# verkeersbelasting => NOUN
# op => ADP
# de => DET
# autovoertuig => NOUN
# en => CCONJ
# de => DET
# belasting => NOUN
# op => ADP
# de => DET
# inverkeerstelling => NOUN
# door => ADP
# het => DET
# Brussels => PROPN
# Hoofdstedelijk => PROPN
# Gewest => PROPN
#
#
#
#   => SPACE
# de => DET
# Brussels => PROPN
# hoofdstedelijk => ADJ
# regering => NOUN
# , => PUNCT
#
#   => SPACE
# Gelet => VERB
# op => ADP
# de => DET
# bijzonder => ADJ
# wet => NOUN
# van => ADP
# 8 => NUM
# augustus => PROPN
# 1980 => NUM
# tot => ADP
# hervorming => NOUN
# de => DET
# instelling => NOUN
# , => PUNCT
# artikel => NOUN
# 20 => NUM
# ; => PUNCT
#
#   => SPACE
# gelet => VERB
# op => ADP
# het => DET
# wetboek => NOUN
# van => ADP
# de => DET
# met => ADP
# inkomstenbelasting => NOUN
# lijkgestelen => VERB
# belasting => NOUN
# , => PUNCT
# artikel => NOUN
# 5 => NUM
# , => PUNCT
# Â§ => NOUN
# 1 => NUM
# , => PUNCT
# twee => NUM
# lid => NOUN
# , => PUNCT
# wijzigen => VERB
# bij => ADP
# de => DET
# ordonnantie => NOUN
# van => ADP
# 28 => NUM
# november => PROPN
# 2019 => NUM
# ; => PUNCT
#
#   => SPACE
# gelet => VERB
# op => ADP
# het => DET
# koninklijk => ADJ
# besluit => NOUN
# van => ADP
# 8 => NUM
# juli => PROPN
# 1970 => NUM
# houdenen => VERB
# de => DET
# algemeen => ADJ
# verordening => NOUN
# betreffen => VERB
# de => DET
# met => ADP
# de => DET
# inkomstenbelasting => NOUN
# gelijkgestelde => VERB
# belasting => NOUN
# ; => PUNCT
#
#   => SPACE
# Gelet => ADJ
# op => ADP
# de => DET
# gelijkekansentest => NOUN
# uit_voeren => PROPN
# op => ADP
# 22 => NUM
# november => PROPN
# 2019 => NUM
# in => ADP
# toepassing => NOUN
# van => ADP
# artikel => NOUN
# 2 => NUM
# van => ADP
# de => DET
# ordonnantie => NOUN
# van => ADP
# 4 => NUM
# oktober => PROPN
# 2018 => NUM
# tot => ADP
# invoering => NOUN
# van => ADP
# de => DET
# Gelijkekansentest => PROPN
# ; => PUNCT
#
#   => SPACE
# gelet => VERB
# op => ADP
# advies => NOUN
# 66.928/4 => VERB
# van => ADP
# de => DET
# Raad => PROPN
# van => PROPN
# State => PROPN
# , => PUNCT
# geven => VERB
# op => ADP
# 12 => NUM
# februari => PROPN
# 2020 => NUM
# , => PUNCT
# met => ADP
# toepassing => NOUN
# van => ADP
# artikel => NOUN
# 84 => NUM
# , => PUNCT
# Â§ => NOUN
# 1 => NUM
# , => PUNCT
# één => NUM
# lid => NOUN
# , => PUNCT
# 2Â => SYM
# ° => SYM
# , => PUNCT
# van => ADP
# de => DET
# wet => NOUN
# op => ADP
# de => DET
# Raad => PROPN
# van => PROPN
# State => PROPN
# , => PUNCT
# coÃ¶rdineren => VERB
# op => ADP
# 12 => NUM
# januari => PROPN
# 1973 => NUM
# ; => PUNCT
#
#   => SPACE
# overwegende => CCONJ
# dat => SCONJ
# de => DET
# ordonnantie => NOUN
# van => ADP
# 28 => NUM
# november => PROPN
# 2019 => NUM
# tot => ADP
# wijziging => NOUN
# van => ADP
# het => DET
# wetboek => NOUN
# van => ADP
# de => DET
# met => ADP
# inkomstenbelasting => NOUN
# lijkgestelen => VERB
# belasting => NOUN
# in => ADP
# het => DET
# kader => NOUN
# van => ADP
# de => DET
# overname => NOUN
# van => ADP
# de => DET
# dienst => NOUN
# van => ADP
# de => DET
# verkeersbelasting => NOUN
# op => ADP
# de => DET
# autovoertuig => NOUN
# en => CCONJ
# van => ADP
# de => DET
# belasting => NOUN
# op => ADP
# de => DET
# inverkeerstelling => NOUN
# door => ADP
# het => DET
# Brussels => PROPN
# Hoofdstedelijk => PROPN
# Gewest => PROPN
# , => PUNCT
# in => ADP
# zijn => PRON
# artikel => NOUN
# 3 => NUM
# , => PUNCT
# 1Â => SYM
# ° => PUNCT
# , => SYM
# a => SYM
# ) => PUNCT
# , => PUNCT
# iv => SYM
# , => SYM
# et => SYM
# b => SYM
# ) => PUNCT
# , => PUNCT
# 12 => NUM
# , => PUNCT
# 13 => NUM
# en => CCONJ
# 15 => NUM
# , => PUNCT
# 2Â => SYM
# ° => SYM
# en => CCONJ
# 3Â => SYM
# ° => SYM
# de => DET
# bepaling => NOUN
# die => PRON
# momenteel => ADJ
# vervat => VERB
# zijn => AUX
# in => ADP
# de => DET
# artikel => NOUN
# 15 => NUM
# , => PUNCT
# Â§ => NOUN
# 1 => NUM
# , => PUNCT
# en => CCONJ
# 58 => NUM
# van => ADP
# het => DET
# koninklijk => ADJ
# besluit => NOUN
# van => ADP
# 8 => NUM
# juli => PROPN
# 1970 => NUM
# houdenen => VERB
# de => DET
# algemeen => ADJ
# verordening => NOUN
# betreffen => VERB
# de => DET
# met => ADP
# de => DET
# inkomstenbelasting => NOUN
# lijkgestelen => VERB
# belasting => NOUN
# , => PUNCT
# hebben => AUX
# Ã¯ntegreren => NOUN
# in => ADP
# de => DET
# artikel => NOUN
# 5 => NUM
# , => PUNCT
# één => NUM
# lid => NOUN
# , => PUNCT
# 3Â => SYM
# ° => SYM
# bis => SYM
# , => PUNCT
# en => CCONJ
# twee => NUM
# lid => NOUN
# , => PUNCT
# en => CCONJ
# 96 => NUM
# , => PUNCT
# één => NUM
# lid => NOUN
# , => PUNCT
# 3Â => SYM
# ° => SYM
# , => SYM
# a => SYM
# ) => PUNCT
# en => CCONJ
# twee => NUM
# lid => NOUN
# van => ADP
# het => DET
# wetboek => NOUN
# van => ADP
# de => DET
# met => ADP
# inkomstenbelasting => NOUN
# lijkgestelen => VERB
# belasting => NOUN
# ; => PUNCT
# dat => SCONJ
# deze => DET
# bepaling => NOUN
# derhalve => ADV
# moeten => AUX
# worden => AUX
# op_heffen => NOUN
# ; => PUNCT
#
#   => SPACE
# overwegende => CCONJ
# dat => SCONJ
# de => DET
# ordonnantie => NOUN
# van => ADP
# 19 => NUM
# december => PROPN
# 2019 => NUM
# houdenen => VERB
# de => DET
# wijziging => NOUN
# van => ADP
# de => DET
# procedureel => NOUN
# bepaling => NOUN
# in => ADP
# het => DET
# kader => NOUN
# van => ADP
# de => DET
# overname => NOUN
# van => ADP
# de => DET
# dienst => NOUN
# van => ADP
# de => DET
# verkeersbelastingen => NOUN
# en => CCONJ
# houden => VERB
# divers => ADJ
# bepaling => NOUN
# tot => ADP
# gevolg => NOUN
# hebben => VERB
# dat => SCONJ
# de => DET
# ordonnantie => NOUN
# van => ADP
# 6 => NUM
# maart => PROPN
# 2019 => NUM
# betreffen => VERB
# de => DET
# Brussels => PROPN
# Codex => PROPN
# Fiscale => ADJ
# Procedure => NOUN
# en => CCONJ
# haar => PRON
# uitvoeringsbesluit => NOUN
# van => ADP
# toepassing => NOUN
# zijn => AUX
# op => ADP
# de => DET
# verkeersbelasting => NOUN
# op => ADP
# de => DET
# autovoertuig => NOUN
# en => CCONJ
# de => DET
# belasting => NOUN
# op => ADP
# de => DET
# inverkeerstelling => NOUN
# waarvan => ADV
# het => DET
# belastbaar => ADJ
# feit => NOUN
# ontstaan => VERB
# vanaf => ADP
# 1 => NUM
# januari => PROPN
# 2020 => NUM
# ; => PUNCT
# dat => SCONJ
# de => DET
# procedureel => NOUN
# bepaling => NOUN
# vervat => VERB
# in => ADP
# Titel => PROPN
# I => PROPN
# van => ADP
# de => DET
# het => DET
# besluit => NOUN
# van => ADP
# 8 => NUM
# juli => PROPN
# 1970 => NUM
# houdenen => VERB
# de => DET
# algemeen => ADJ
# verordening => NOUN
# betreffen => VERB
# de => DET
# met => ADP
# de => DET
# inkomstenbelasting => NOUN
# lijkgestelen => VERB
# belasting => NOUN
# , => PUNCT
# dus => CCONJ
# , => PUNCT
# voor => ADP
# wat => PRON
# deze => DET
# belasting => NOUN
# betreffen => VERB
# , => PUNCT
# moeten => AUX
# worden => AUX
# op_heffen => NOUN
# , => PUNCT
# voor => ADP
# zover => ADV
# hun => PRON
# doel => NOUN
# rechtstreeks => ADJ
# worden => AUX
# over_nemen => PROPN
# in => ADP
# de => DET
# noemen => NOUN
# Codex => PROPN
# en => CCONJ
# zijn => AUX
# uitvoeringsbeslui => NOUN
# ; => PUNCT
#
#   => SPACE
# op => ADP
# voorstel => NOUN
# van => ADP
# de => DET
# minister => NOUN
# van => ADP
# FinanciÃ => NOUN
# « => PUNCT
# n => INTJ
# , => PUNCT
# na => ADP
# beraadslaging => NOUN
# , => PUNCT
#
#   => SPACE
# besluit => NOUN
# : => PUNCT
#
#   => SPACE
# HOOFDSTUK => PROPN
# 1 => NUM
# . => PUNCT
# - => PUNCT
# Inleidende => ADJ
# bepaling => NOUN
#
#   => SPACE
# artikel => NOUN
# 1 => NUM
# . => PUNCT
# dit => DET
# besluit => NOUN
# zijn => AUX
# uitsluitend => ADJ
# van => ADP
# toepassing => NOUN
# op => ADP
# : => PUNCT
#
#   => SPACE
# 1Â => SYM
# ° => PUNCT
# de => DET
# verkeersbelasting => NOUN
# op => ADP
# de => DET
# autovoertuig => NOUN
# ; => PUNCT
#
#   => SPACE
# 2Â => SYM
# ° => SYM
# de => DET
# belasting => NOUN
# op => ADP
# de => DET
# inverkeerstelling => NOUN
# . => PUNCT
#
#   => SPACE
# HOOFDSTUK => PROPN
# 2 => NUM
# . => PUNCT
# - => PUNCT
# Wijzigingen => NOUN
# van => ADP
# toepassing => NOUN
# op => ADP
# de => DET
# verkeersbelasting => NOUN
# op => ADP
# de => DET
# autovoertuig => NOUN
# en => CCONJ
# de => DET
# belasting => NOUN
# op => ADP
# de => DET
# inverkeerstelling => NOUN
# waarvan => ADV
# het => DET
# belastbaar => ADJ
# feit => NOUN
# vÃ³Ã³r => ADP
# 1 => NUM
# januari => PROPN
# 2020 => NUM
# vallen => VERB
#
#   => SPACE
# Art. => X
# 2 => NUM
# . => PUNCT
# de => DET
# bepaling => NOUN
# van => ADP
# dit => DET
# hoofdstuk => NOUN
# zijn => AUX
# uitsluitend => ADJ
# van => ADP
# toepassing => NOUN
# op => ADP
# de => DET
# verkeersbelasting => NOUN
# op => ADP
# de => DET
# autovoertuig => NOUN
# en => CCONJ
# de => DET
# belasting => NOUN
# op => ADP
# de => DET
# inverkeerstelling => NOUN
# waarvan => ADV
# het => DET
# belastbaar => ADJ
# feit => NOUN
# vÃ³Ã³r => ADP
# 1 => NUM
# januari => PROPN
# 2020 => NUM
# vallen => VERB
# . => PUNCT
#
#   => SPACE
# Art. => X
# 3 => NUM
# . => PUNCT
# artikel => NOUN
# 8 => NUM
# van => ADP
# het => DET
# koninklijk => ADJ
# besluit => NOUN
# van => ADP
# 8 => NUM
# juli => PROPN
# 1970 => NUM
# houdenen => VERB
# de => DET
# algemeen => ADJ
# verordening => NOUN
# betreffen => VERB
# de => DET
# met => ADP
# de => DET
# inkomstenbelasting => NOUN
# lijkgestelen => VERB
# belasting => NOUN
# , => PUNCT
# vervangen => VERB
# bij => ADP
# het => DET
# koninklijk => ADJ
# besluit => NOUN
# van => ADP
# 27 => NUM
# februari => PROPN
# 2019 => NUM
# , => PUNCT
# worden => AUX
# vervangen => VERB
# als => SCONJ
# volgen => VERB
# : => PUNCT
#
#   => SPACE
# " => PUNCT
# Art. => X
# 8 => NUM
# . => PUNCT
# onverminderd => VERB
# de => DET
# bepaling => NOUN
# van => ADP
# artikel => NOUN
# 24 => NUM
# , => PUNCT
# zijn => AUX
# de => DET
# met => ADP
# de => DET
# inkomstenbelasting => NOUN
# gelijkgestelde => VERB
# belasting => NOUN
# te => ADP
# betalen => VERB
# bij => ADP
# de => DET
# rekenplichtig => ADJ
# van => ADP
# de => DET
# ontvan_gst => ADJ
# belasten => VERB
# met => ADP
# fiscaal => ADJ
# zaak => NOUN
# van => ADP
# de => DET
# Gewestelijke => ADJ
# overheidsdienst => NOUN
# Brussel => PROPN
# Fiscaliteit => NOUN
# of => CCONJ
# , => PUNCT
# in => ADP
# geval => NOUN
# van => ADP
# zijn => PRON
# afwezigheid => NOUN
# , => PUNCT
# bij => ADP
# de => DET
# plaatsvervangend => ADJ
# rekenplichtig => ADJ
# van => ADP
# de => DET
# ontvangsat => NOUN
# belasten => VERB
# met => ADP
# fiscaal => ADJ
# zaak => NOUN
# van => ADP
# dezelfde => DET
# dienst => NOUN
# . => PUNCT
# " => PUNCT
# . => PUNCT
#
#   => SPACE
# Art. => X
# 4 => NUM
# . => PUNCT
# in => ADP
# artikel => NOUN
# 11 => NUM
# van => ADP
# hetzelfde => DET
# besluit => NOUN
# , => PUNCT
# wijzigen => VERB
# bij => ADP
# het => DET
# koninklijk => ADJ
# besluit => NOUN
# van => ADP
# 14 => NUM
# april => PROPN
# 1993 => NUM
# en => CCONJ
# bij => ADP
# het => DET
# koninklijk => ADJ
# besluit => NOUN
# van => ADP
# 9 => NUM
# november => PROPN
# 1999 => NUM
# en => CCONJ
# vervangen => VERB
# bij => ADP
# het => DET
# koninklijk => ADJ
# besluit => NOUN
# van => ADP
# 17 => NUM
# februari => PROPN
# 2019 => NUM
# , => PUNCT
# worden => AUX
# de => DET
# woord => NOUN
# " => PUNCT
# op => ADP
# de => DET
# financiÃ => NOUN
# « => PUNCT
# Le => SYM
# rekening => NOUN
# van => ADP
# het => DET
# ontvangkantoor => NOUN
# Belastingen-auto => PROPN
# " => PUNCT
# vervangen => VERB
# door => ADP
# de => DET
# woord => NOUN
# " => PUNCT
# volgens => ADP
# de => DET
# door => ADP
# de => DET
# gewestelijk => ADJ
# overheidsdienst => NOUN
# Brussel => PROPN
# fiscaliteit => ADJ
# aangegeven => VERB
# modaliteit => NOUN
# " => PUNCT
# . => PUNCT
#
#   => SPACE
# HOOFDSTUK => PROPN
# 3 => NUM
# . => PUNCT
# - => PUNCT
# Wijzigingen => NOUN
# van => ADP
# toepassing => NOUN
# op => ADP
# de => DET
# verkeersbelasting => NOUN
# op => ADP
# de => DET
# autovoertuig => NOUN
# en => CCONJ
# de => DET
# belasting => NOUN
# op => ADP
# de => DET
# inverkeerstelling => NOUN
# waarvan => ADV
# het => DET
# belastbaar => ADJ
# feit => NOUN
# vanaf => ADP
# 1 => NUM
# januari => PROPN
# 2020 => NUM
# vallen => VERB
#
#   => SPACE
# Art. => X
# 5 => NUM
# . => PUNCT
# de => DET
# bepaling => NOUN
# van => ADP
# dit => DET
# hoofdstuk => NOUN
# zijn => AUX
# uitsluitend => ADJ
# van => ADP
# toepassing => NOUN
# op => ADP
# de => DET
# verkeersbelasting => NOUN
# op => ADP
# de => DET
# autovoertuig => NOUN
# en => CCONJ
# de => DET
# belasting => NOUN
# op => ADP
# de => DET
# inverkeerstelling => NOUN
# waarvan => ADV
# het => DET
# belastbaar => ADJ
# feit => NOUN
# vanaf => ADP
# 1 => NUM
# januari => PROPN
# 2020 => NUM
# vallen => VERB
# . => PUNCT
#
#   => SPACE
# Art. => X
# 6 => NUM
# . => PUNCT
# in => ADP
# artikel => NOUN
# 15 => NUM
# van => ADP
# hetzelfde => DET
# besluit => NOUN
# , => PUNCT
# wijzigen => VERB
# bij => ADP
# het => DET
# koninklijk => ADJ
# besluit => NOUN
# van => ADP
# 10 => NUM
# november => PROPN
# 1980 => NUM
# en => CCONJ
# bij => ADP
# de => DET
# wet => NOUN
# van => ADP
# 19 => NUM
# februari => PROPN
# 1990 => NUM
# , => PUNCT
# worden => AUX
# de => DET
# volgen => VERB
# wijziging => NOUN
# aan_brengen => PROPN
# : => PUNCT
#
#   => SPACE
# 1Â => SYM
# ° => PUNCT
# paragraaf => NOUN
# 1 => NUM
# worden => AUX
# op_heffen => NOUN
# ; => PUNCT
#
#   => SPACE
# 2Â => SYM
# ° => SYM
# in => ADP
# paragraaf => NOUN
# 2 => NUM
# worden => AUX
# de => DET
# volgen => VERB
# wijziging => NOUN
# aan_brengen => PROPN
# : => PUNCT
#
#   => SPACE
# à => SYM
# ) => PUNCT
# in => ADP
# de => DET
# bepaling => NOUN
# onder => ADP
# 1Â => SYM
# ° => PUNCT
# worden => AUX
# de => DET
# woord => NOUN
# " => PUNCT
# wet => NOUN
# van => ADP
# 27 => NUM
# december => PROPN
# 1974 => NUM
# betreffen => VERB
# de => DET
# taxidienst => NOUN
# en => CCONJ
# in_richten => NOUN
# krachtens => ADP
# een => DET
# vergunning => NOUN
# regelmatig => ADJ
# afgelevren => ADJ
# te => ADP
# uitvoering => NOUN
# van => ADP
# gezegen => NOUN
# wet => NOUN
# " => PUNCT
# vervangen => VERB
# door => ADP
# de => DET
# woord => NOUN
# " => PUNCT
# toepasselijk => ADJ
# gewestelijk => ADJ
# regelgeving => NOUN
# en => CCONJ
# in_richten => NOUN
# krachtens => ADP
# een => DET
# vergunning => NOUN
# regelmatig => ADJ
# afgelevren => ADJ
# te => ADP
# uitvoering => NOUN
# van => ADP
# de => DET
# noemen => VERB
# regelgeving => NOUN
# " => PUNCT
# ; => PUNCT
#
#   => SPACE
# b => SYM
# ) => PUNCT
# de => DET
# bepaling => NOUN
# onder => ADP
# 2Â => SYM
# ° => PUNCT
# worden => AUX
# vervangen => VERB
# als => SCONJ
# volgen => VERB
# : => PUNCT
#
#   => SPACE
# " => SYM
# 2Â => SYM
# ° => SYM
# op => ADP
# de => DET
# autovoertuig => NOUN
# die => PRON
# uitsluitend => ADJ
# aangewend => VERB
# worden => AUX
# tot => ADP
# een => DET
# dienst => NOUN
# voor => ADP
# het => DET
# verhuren => VERB
# van => ADP
# voertuig => NOUN
# met => ADP
# bestuurder => NOUN
# onder => ADP
# de => DET
# voorwaarde => NOUN
# bepalen => VERB
# bij => ADP
# de => DET
# toepasselijk => ADJ
# gewestelijk => ADJ
# regelgeving => NOUN
# en => CCONJ
# in_richten => NOUN
# krachtens => ADP
# een => DET
# vergunning => NOUN
# regelmatig => ADJ
# afgelevren => ADJ
# te => ADP
# uitvoering => NOUN
# van => ADP
# de => DET
# noemen => VERB
# regelgeving => NOUN
# ; => PUNCT
# " => PUNCT
# . => PUNCT
#
#   => SPACE
# Art. => X
# 7 => NUM
# . => PUNCT
# in => ADP
# hetzelfde => DET
# besluit => NOUN
# worden => AUX
# de => DET
# volgen => VERB
# bepaling => NOUN
# op_heffen => NOUN
# : => PUNCT
#
#   => SPACE
# 1Â => SYM
# ° => PUNCT
# de => DET
# titel => NOUN
# I => PROPN
# , => PUNCT
# die => PRON
# bestaan => VERB
# uit => ADP
# de => DET
# artikel => NOUN
# 1 => NUM
# tot => ADP
# en => CCONJ
# met => ADP
# 14 => NUM
# ; => PUNCT
#
#   => SPACE
# 2Â => SYM
# ° => SYM
# het => DET
# hoofdstuk => NOUN
# III => NUM
# van => ADP
# titel => NOUN
# II => PROPN
# , => PUNCT
# dat => PRON
# bestaan => VERB
# uit => ADP
# de => DET
# artikel => NOUN
# 23 => NUM
# en => CCONJ
# 24 => NUM
# ; => PUNCT
#
#   => SPACE
# 3Â => SYM
# ° => SYM
# het => DET
# hoofdstuk => NOUN
# IV => NUM
# van => ADP
# titel => NOUN
# II => PROPN
# , => PUNCT
# dat => PRON
# bestaan => VERB
# uit => ADP
# de => DET
# artikel => NOUN
# 25 => NUM
# en => CCONJ
# 26 => NUM
# ; => PUNCT
#
#   => SPACE
# 4Â => SYM
# ° => SYM
# het => DET
# hoofdstuk => NOUN
# V => NUM
# van => ADP
# titel => NOUN
# II => PROPN
# , => PUNCT
# dat => PRON
# bestaan => VERB
# uit => ADP
# de => DET
# artikel => NOUN
# 27 => NUM
# tot => ADP
# en => CCONJ
# met => ADP
# 29 => NUM
# ; => PUNCT
#
#   => SPACE
# 5Â => SYM
# ° => SYM
# in => ADP
# het => DET
# titel => NOUN
# V => NUM
# , => PUNCT
# artikel => NOUN
# 58 => NUM
# , => PUNCT
# wijzigen => VERB
# bij => ADP
# het => DET
# koninklijk => ADJ
# besluit => NOUN
# van => ADP
# 14 => NUM
# april => PROPN
# 1993 => NUM
# . => PUNCT
#
#   => SPACE
# HOOFDSTUK => PROPN
# 4 => NUM
# . => PUNCT
# - => PUNCT
# Wijzigingen => NOUN
# van => ADP
# toepassing => NOUN
# op => ADP
# de => DET
# verkeersbelasting => NOUN
# op => ADP
# de => DET
# autovoertuig => NOUN
# en => CCONJ
# de => DET
# belasting => NOUN
# op => ADP
# de => DET
# inverkeerstelling => NOUN
# ongeacht => ADP
# de => DET
# datum => NOUN
# van => ADP
# het => DET
# belastbaar => ADJ
# feit => NOUN
#
#   => SPACE
# Art. => X
# 8 => NUM
# . => PUNCT
# in => ADP
# artikel => NOUN
# 30 => NUM
# , => PUNCT
# Â§ => NOUN
# 2 => NUM
# , => PUNCT
# van => ADP
# hetzelfde => DET
# besluit => NOUN
# opnieuw => ADV
# op_nemen => VERB
# bij => ADP
# het => DET
# koninklijk => ADJ
# besluit => NOUN
# van => ADP
# 17 => NUM
# december => PROPN
# 1984 => NUM
# , => PUNCT
# worden => AUX
# de => DET
# volgen => VERB
# wijziging => NOUN
# aan_brengen => PROPN
# : => PUNCT
#
#   => SPACE
# 1Â => SYM
# ° => PUNCT
# in => ADP
# het => DET
# één => NUM
# lid => NOUN
# worden => VERB
# de => DET
# woord => NOUN
# " => PUNCT
# doen => VERB
# door => ADP
# middel => NOUN
# van => ADP
# een => DET
# formulier => NOUN
# dat => PRON
# door => ADP
# administratie => NOUN
# de => DET
# direct => ADJ
# belasting => NOUN
# worden => AUX
# verstrekken => VERB
# " => PUNCT
# vervangen => VERB
# door => ADP
# de => DET
# woord => NOUN
# " => PUNCT
# in_dienen => NOUN
# bij => ADP
# de => DET
# Gewestelijke => ADJ
# overheidsdienst => NOUN
# Brussel => PROPN
# Fiscaliteit => NOUN
# " => PUNCT
# ; => PUNCT
#
#   => SPACE
# 2Â => SYM
# ° => SYM
# het => DET
# twee => NUM
# lid => NOUN
# worden => VERB
# op_heffen => NOUN
# . => PUNCT
#
#   => SPACE
# HOOFDSTUK => NOUN
# 5 => NUM
# . => PUNCT
# - => PUNCT
# Inwerkingtreding => NOUN
# en => CCONJ
# uitvoering => NOUN
#
#   => SPACE
# Art. => X
# 9 => NUM
# . => PUNCT
# dit => DET
# besluit => NOUN
# hebben => AUX
# uitwerking => NOUN
# met => ADP
# ingang => NOUN
# van => ADP
# 1 => NUM
# januari => PROPN
# 2020 => NUM
# . => PUNCT
#
#   => SPACE
# Art. => X
# 10 => NUM
# . => PUNCT
# de => DET
# minister => NOUN
# bevoegd => ADJ
# voor => ADP
# FinanciÃ => NOUN
# « => PUNCT
# n => PRON
# zijn => AUX
# belasten => NOUN
# met => ADP
# de => DET
# uitvoering => NOUN
# van => ADP
# dit => DET
# besluit => NOUN
# . => PUNCT
#
#   => SPACE
# Brussel => PROPN
# , => PUNCT
# 5 => NUM
# maart => PROPN
# 2020 => NUM
# . => PUNCT
#
#   => SPACE
# voor => ADP
# de => DET
# Brussels => PROPN
# hoofdstedelijk => ADJ
# regering => NOUN
# : => PUNCT
#
#   => SPACE
# de => DET
# Minister_President => SYM
# van => ADP
# de => DET
# Brussels => PROPN
# hoofdstedelijk => ADJ
# regering => NOUN
# , => PUNCT
#
#   => SPACE
# R. => PROPN
# VERVOORT => PROPN
#
#   => SPACE
# de => DET
# minister => NOUN
# van => ADP
# de => DET
# Brussels => PROPN
# hoofdstedelijk => ADJ
# regering => NOUN
# , => PUNCT
# belasten => VERB
# met => ADP
# FinanciÃ => NOUN
# « => PUNCT
# n => INTJ
# , => PUNCT
# begroting => NOUN
# , => PUNCT
# openbaar => ADJ
# ambt => NOUN
# en => CCONJ
# de => DET
# Promotie => PROPN
# van => ADP
# Meertaligheid => PROPN
# , => PUNCT
#
#   => SPACE
# S. => PROPN
# GATZ => PROPN
#
#  => SPACE

# %%
# Parser for reviews
parser = Dutch()
def spacy_tokenizer(sentence):
    mytokens = parser(sentence)
    mytokens = [ word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in mytokens ]
    mytokens = [ word for word in mytokens if word not in stopwords and word not in punctuations ]
    mytokens = " ".join([i for i in mytokens])
    return mytokens

# %%
from tqdm import tqdm
tqdm.pandas()

# %%
#Import puntuaction marks from string and also add additional next line tag in it
punctuation=punctuation+ '\n'

# %%
#Tokenize the words from the sentence:
tokens=[token.text for token in doc]
print(tokens)
# Out:
# ['BRUSSELS', 'HOOFDSTEDELIJK', 'GEWEST', '\n', '5', 'MAART', '2020', '.', '-', 'Besluit', 'van', 'de', 'Brusselse', 'Hoofdstedelijke', 'Regering', 'tot', 'wijziging', 'van', 'het', 'koninklijk', 'besluit', 'van', '8', 'juli', '1970', 'houdende', 'de', 'algemene', 'verordening', 'betreffende', 'de', 'met', 'de', 'inkomstenbelastingen', 'gelijkgestelde', 'belastingen', 'in', 'het', 'kader', 'van', 'de', 'overname', 'van', 'de', 'dienst', 'van', 'de', 'verkeersbelasting', 'op', 'de', 'autovoertuigen', 'en', 'de', 'belasting', 'op', 'de', 'inverkeerstelling', 'door', 'het', 'Brussels', 'Hoofdstedelijk', 'Gewest', '\n\n\n', 'De', 'Brusselse', 'Hoofdstedelijke', 'Regering', ',', '\n', 'Gelet', 'op', 'de', 'bijzondere', 'wet', 'van', '8', 'augustus', '1980', 'tot', 'hervorming', 'der', 'instellingen', ',', 'artikel', '20', ';', '\n', 'Gelet', 'op', 'het', 'Wetboek', 'van', 'de', 'met', 'inkomstenbelastingen', 'gelijkgestelde', 'belastingen', ',', 'artikelen', '5', ',', 'Â§', '1', ',', 'tweede', 'lid', ',', 'gewijzigd', 'bij', 'de', 'ordonnantie', 'van', '28', 'november', '2019', ';', '\n', 'Gelet', 'op', 'het', 'koninklijk', 'besluit', 'van', '8', 'juli', '1970', 'houdende', 'de', 'algemene', 'verordening', 'betreffende', 'de', 'met', 'de', 'inkomstenbelastingen', 'gelijkgestelde', 'belastingen', ';', '\n', 'Gelet', 'op', 'de', 'gelijkekansentest', 'uitgevoerd', 'op', '22', 'november', '2019', 'in', 'toepassing', 'van', 'artikel', '2', 'van', 'de', 'ordonnantie', 'van', '4', 'oktober', '2018', 'tot', 'invoering', 'van', 'de', 'gelijkekansentest', ';', '\n', 'Gelet', 'op', 'advies', '66.928/4', 'van', 'de', 'Raad', 'van', 'State', ',', 'gegeven', 'op', '12', 'februari', '2020', ',', 'met', 'toepassing', 'van', 'artikel', '84', ',', 'Â§', '1', ',', 'eerste', 'lid', ',', '2Â', '°', ',', 'van', 'de', 'wetten', 'op', 'de', 'Raad', 'van', 'State', ',', 'gecoÃ¶rdineerd', 'op', '12', 'januari', '1973', ';', '\n', 'Overwegende', 'dat', 'de', 'ordonnantie', 'van', '28', 'november', '2019', 'tot', 'wijziging', 'van', 'het', 'Wetboek', 'van', 'de', 'met', 'inkomstenbelastingen', 'gelijkgestelde', 'belastingen', 'in', 'het', 'kader', 'van', 'de', 'overname', 'van', 'de', 'dienst', 'van', 'de', 'verkeersbelasting', 'op', 'de', 'autovoertuigen', 'en', 'van', 'de', 'belasting', 'op', 'de', 'inverkeerstelling', 'door', 'het', 'Brussels', 'Hoofdstedelijk', 'Gewest', ',', 'in', 'zijn', 'artikelen', '3', ',', '1Â', '°', ',', 'a', ')', ',', 'iv', ',', 'et', 'b', ')', ',', '12', ',', '13', 'en', '15', ',', '2Â', '°', 'en', '3Â', '°', 'de', 'bepalingen', 'die', 'momenteel', 'vervat', 'zijn', 'in', 'de', 'artikelen', '15', ',', 'Â§', '1', ',', 'en', '58', 'van', 'het', 'koninklijk', 'besluit', 'van', '8', 'juli', '1970', 'houdende', 'de', 'algemene', 'verordening', 'betreffende', 'de', 'met', 'de', 'inkomstenbelastingen', 'gelijkgestelde', 'belastingen', ',', 'heeft', 'geÃ¯ntegreerd', 'in', 'de', 'artikelen', '5', ',', 'eerste', 'lid', ',', '3Â', '°', 'bis', ',', 'en', 'tweede', 'lid', ',', 'en', '96', ',', 'eerste', 'lid', ',', '3Â', '°', ',', 'a', ')', 'en', 'tweede', 'lid', 'van', 'het', 'Wetboek', 'van', 'de', 'met', 'inkomstenbelastingen', 'gelijkgestelde', 'belastingen', ';', 'dat', 'deze', 'bepalingen', 'derhalve', 'moeten', 'worden', 'opgeheven', ';', '\n', 'Overwegende', 'dat', 'de', 'ordonnantie', 'van', '19', 'december', '2019', 'houdende', 'de', 'wijziging', 'van', 'de', 'procedurele', 'bepalingen', 'in', 'het', 'kader', 'van', 'de', 'overname', 'van', 'de', 'dienst', 'van', 'de', 'verkeersbelastingen', 'en', 'houdende', 'diverse', 'bepalingen', 'tot', 'gevolg', 'heeft', 'dat', 'de', 'ordonnantie', 'van', '6', 'maart', '2019', 'betreffende', 'de', 'Brusselse', 'Codex', 'Fiscale', 'Procedure', 'en', 'haar', 'uitvoeringsbesluit', 'van', 'toepassing', 'zijn', 'op', 'de', 'verkeersbelasting', 'op', 'de', 'autovoertuigen', 'en', 'de', 'belasting', 'op', 'de', 'inverkeerstelling', 'waarvan', 'het', 'belastbaar', 'feit', 'ontstaat', 'vanaf', '1', 'janu ...

# %%
#Calculating word frequencies from the text after removing stopwords and puntuactions:

stopwords = list(STOP_WORDS)

word_frequencies={}
for word in doc:
    if word.text.lower() not in stopwords:
        if word.text.lower() not in punctuation:
            if word.text not in word_frequencies.keys():
                word_frequencies[word.text] = 1
            else:
                word_frequencies[word.text] += 1

# %%
#Print and see word frequencies to know important words.
print(word_frequencies)
# Out:
# {'BRUSSELS': 1, 'HOOFDSTEDELIJK': 1, 'GEWEST': 1, '5': 6, 'MAART': 1, '2020': 9, 'Besluit': 2, 'Brusselse': 6, 'Hoofdstedelijke': 5, 'Regering': 5, 'wijziging': 3, 'koninklijk': 11, 'besluit': 19, '8': 9, 'juli': 5, '1970': 5, 'houdende': 7, 'algemene': 5, 'verordening': 5, 'inkomstenbelastingen': 9, 'gelijkgestelde': 9, 'belastingen': 11, 'kader': 3, 'overname': 3, 'dienst': 5, 'verkeersbelasting': 9, 'autovoertuigen': 10, 'belasting': 9, 'inverkeerstelling': 9, 'Brussels': 2, 'Hoofdstedelijk': 2, 'Gewest': 2, '\n\n\n': 1, 'Gelet': 5, 'bijzondere': 1, 'wet': 4, 'augustus': 1, '1980': 2, 'hervorming': 1, 'instellingen': 1, 'artikel': 8, '20': 1, 'Wetboek': 3, 'artikelen': 8, 'Â§': 4, '1': 13, 'tweede': 4, 'lid': 8, 'gewijzigd': 4, 'ordonnantie': 5, '28': 2, 'november': 5, '2019': 7, 'gelijkekansentest': 2, 'uitgevoerd': 1, '22': 1, 'toepassing': 9, '2': 5, '4': 3, 'oktober': 1, '2018': 1, 'invoering': 1, 'advies': 1, '66.928/4': 1, 'Raad': 2, 'State': 2, '12': 3, 'februari': 4, '84': 1, '2Â': 8, '°': 20, 'wetten': 1, 'gecoÃ¶rdineerd': 1, 'januari': 7, '1973': 1, 'Overwegende': 2, '3': 3, '1Â': 6, 'a': 3, 'iv': 1, 'et': 1, 'b': 2, '13': 1, '15': 3, '3Â': 4, 'bepalingen': 9, 'momenteel': 1, 'vervat': 2, '58': 2, 'geÃ¯ntegreerd': 1, 'bis': 1, '96': 1, 'derhalve': 1, 'opgeheven': 5, '19': 2, 'december': 3, 'procedurele': 2, 'verkeersbelastingen': 1, 'diverse': 1, 'gevolg': 1, '6': 2, 'maart': 2, 'Codex': 2, 'Fiscale': 1, 'Procedure': 1, 'uitvoeringsbesluit': 1, 'waarvan': 5, 'belastbaar': 6, 'feit': 6, 'ontstaat': 1, 'Titel': 1, 'I': 2, 'betreft': 1, 'zover': 1, 'doel': 1, 'rechtstreeks': 1, 'overgenomen': 1, 'genoemde': 3, 'uitvoeringsbesluiten': 1, 'voorstel': 1, 'Minister': 3, 'FinanciÃ': 3, '«': 4, 'n': 3, 'beraadslaging': 1, 'HOOFDSTUK': 5, 'Inleidende': 1, 'bepaling': 3, 'Artikel': 2, 'uitsluitend': 4, 'Wijzigingen': 3, 'vÃ³Ã³r': 2, 'valt': 4, 'Art.': 10, 'hoofdstuk': 5, 'vervangen': 7, '27': 3, 'volgt': 2, 'Onverminderd': 1, '24': 2, 'betalen': 1, 'rekenplichtige': 2, 'ontvangsten': 2, 'belast': 4, 'fiscale': 2, 'zaken': 2, 'Gewestelijke': 3, 'Overheidsdienst': 3, 'Brussel': 4, 'Fiscaliteit': 3, 'geval': 1, 'afwezigheid': 1, 'plaatsvervangend': 1, '11': 1, 'hetzelfde': 4, '14': 3, 'april': 2, '1993': 2, '9': 2, '1999': 1, '17': 2, 'woorden': 6, 'financiÃ': 1, 'le': 1, 'rekening': 1, 'ontvangkantoor': 1, "Belastingen-auto's": 1, 'aangegeven': 1, 'modaliteiten': 1, '10': 2, '1990': 1, 'volgende': 4, 'wijzigingen': 3, 'aangebracht': 3, 'paragraaf': 2, '1974': 1, 'taxidiensten': 1, 'ingericht': 3, 'vergunning': 3, 'regelmatig': 3, 'afgeleverd': 3, 'uitvoering': 5, 'gezegde': 1, 'toepasselijke': 2, 'gewestelijke': 2, 'regelgeving': 4, 'aangewend': 1, 'verhuren': 1, 'voertuigen': 1, 'bestuurder': 1, 'voorwaarden': 1, '7': 1, 'titel': 5, 'bestaat': 4, 'III': 1, 'II': 3, '23': 1, 'IV': 1, '25': 1, '26': 1, '4Â': 1, 'V': 2, '29': 1, '5Â': 1, 'ongeacht': 1, 'datum': 1, '30': 1, 'opgenomen': 1, '1984': 1, 'gedaan': 1, 'middel': 1, 'formulier': 1, 'Administratie': 1, 'directe': 1, 'verstrekt': 1, 'ingediend': 1, 'Inwerkingtreding': 1, 'uitwerking': 1, 'ingang': 1, 'bevoegd': 1, 'Minister-President': 1, 'R.': 1, 'VERVOORT': 1, 'Begroting': 1, 'Openbaar': 1, 'ambt': 1, 'Promotie': 1, 'Meertaligheid': 1, 'S.': 1, 'GATZ': 1}

# %%
#Calculate the maximum frequency and divide it by all frequencies to get normalized word frequencies.
max_frequency=max(word_frequencies.values())
for word in word_frequencies.keys():
    word_frequencies[word]=word_frequencies[word]/max_frequency

# %%
#Printing normalized word frequencies:
#Printing in descending order 

#print(word_frequencies)
w_sorted_keys = sorted(word_frequencies, key=word_frequencies.get, reverse=True)
for w in w_sorted_keys:
    print(w, word_frequencies[w])
# Out:
# ° 1.0
# besluit 0.95
# 1 0.65
# koninklijk 0.55
# belastingen 0.55
# autovoertuigen 0.5
# Art. 0.5
# 2020 0.45
# 8 0.45
# inkomstenbelastingen 0.45
# gelijkgestelde 0.45
# verkeersbelasting 0.45
# belasting 0.45
# inverkeerstelling 0.45
# toepassing 0.45
# bepalingen 0.45
# artikel 0.4
# artikelen 0.4
# lid 0.4
# 2Â 0.4
# houdende 0.35
# 2019 0.35
# januari 0.35
# vervangen 0.35
# 5 0.3
# Brusselse 0.3
# 1Â 0.3
# belastbaar 0.3
# feit 0.3
# woorden 0.3
# Hoofdstedelijke 0.25
# Regering 0.25
# juli 0.25
# 1970 0.25
# algemene 0.25
# verordening 0.25
# dienst 0.25
# Gelet 0.25
# ordonnantie 0.25
# november 0.25
# 2 0.25
# opgeheven 0.25
# waarvan 0.25
# HOOFDSTUK 0.25
# hoofdstuk 0.25
# uitvoering 0.25
# titel 0.25
# wet 0.2
# Â§ 0.2
# tweede 0.2
# gewijzigd 0.2
# februari 0.2
# 3Â 0.2
# « 0.2
# uitsluitend 0.2
# valt 0.2
# belast 0.2
# Brussel 0.2
# hetzelfde 0.2
# volgende 0.2
# regelgeving 0.2
# bestaat 0.2
# wijziging 0.15
# kader 0.15
# overname 0.15
# Wetboek 0.15
# 4 0.15
# 12 0.15
# 3 0.15
# a 0.15
# 15 0.15
# december 0.15
# genoemde 0.15
# Minister 0.15
# FinanciÃ 0.15
# n 0.15
# bepaling 0.15
# Wijzigingen 0.15
# 27 0.15
# Gewestelijke 0.15
# Overheidsdienst 0.15
# Fiscaliteit 0.15
# 14 0.15
# wijzigingen 0.15
# aangebracht 0.15
# ingericht 0.15
# vergunning 0.15
# regelmatig 0.15
# afgeleverd 0.15
# II 0.15
# Besluit 0.1
# Brussels 0.1
# Hoofdstedelijk 0.1
# Gewest 0.1
# 1980 0.1
# 28 0.1
# gelijkekansentest 0.1
# Raad 0.1
# State 0.1
# Overwegende 0.1
# b 0.1
# vervat 0.1
# 58 0.1
# 19 0.1
# procedurele 0.1
# 6 0.1
# maart 0.1
# Codex 0.1
# I 0.1
# Artikel 0.1
# vÃ³Ã³r 0.1
# volgt 0.1
# 24 0.1
# rekenplichtige 0.1
# ontvangsten 0.1
# fiscale 0.1
# zaken 0.1
# april 0.1
# 1993 0.1
# 9 0.1
# 17 0.1
# 10 0.1
# paragraaf 0.1
# toepasselijke 0.1
# gewestelijke 0.1
# V 0.1
# BRUSSELS 0.05
# HOOFDSTEDELIJK 0.05
# GEWEST 0.05
# MAART 0.05
#
#
#
#  0.05
# bijzondere 0.05
# augustus 0.05
# hervorming 0.05
# instellingen 0.05
# 20 0.05
# uitgevoerd 0.05
# 22 0.05
# oktober 0.05
# 2018 0.05
# invoering 0.05
# advies 0.05
# 66.928/4 0.05
# 84 0.05
# wetten 0.05
# gecoÃ¶rdineerd 0.05
# 1973 0.05
# iv 0.05
# et 0.05
# 13 0.05
# momenteel 0.05
# geÃ¯ntegreerd 0.05
# bis 0.05
# 96 0.05
# derhalve 0.05
# verkeersbelastingen 0.05
# diverse 0.05
# gevolg 0.05
# Fiscale 0.05
# Procedure 0.05
# uitvoeringsbesluit 0.05
# ontstaat 0.05
# Titel 0.05
# betreft 0.05
# zover 0.05
# doel 0.05
# rechtstreeks 0.05
# overgenomen 0.05
# uitvoeringsbesluiten 0.05
# voorstel 0.05
# beraadslaging 0.05
# Inleidende 0.05
# Onverminderd 0.05
# betalen 0.05
# geval 0.05
# afwezigheid 0.05
# plaatsvervangend 0.05
# 11 0.05
# 1999 0.05
# financiÃ 0.05
# le 0.05
# rekening 0.05
# ontvangkantoor 0.05
# Belastingen-auto's 0.05
# aangegeven 0.05
# modaliteiten 0.05
# 1990 0.05
# 1974 0.05
# taxidiensten 0.05
# gezegde 0.05
# aangewend 0.05
# verhuren 0.05
# voertuigen 0.05
# bestuurder 0.05
# voorwaarden 0.05
# 7 0.05
# III 0.05
# 23 0.05
# IV 0.05
# 25 0.05
# 26 0.05
# 4Â 0.05
# 29 0.05
# 5Â 0.05
# ongeacht 0.05
# datum 0.05
# 30 0.05
# opgenomen 0.05
# 1984 0.05
# gedaan 0.05
# middel 0.05
# formulier 0.05
# Administratie 0.05
# directe 0.05
# verstrekt 0.05
# ingediend 0.05
# Inwerkingtreding 0.05
# uitwerking 0.05
# ingang 0.05
# bevoegd 0.05
# Minister-President 0.05
# R. 0.05
# VERVOORT 0.05
# Begroting 0.05
# Openbaar 0.05
# ambt 0.05
# Promotie 0.05
# Meertaligheid 0.05
# S. 0.05
# GATZ 0.05

# %%
#Get sentence tokens 
sentence_tokens= [sent for sent in doc.sents]
print(sentence_tokens)
# Out:
# [BRUSSELS HOOFDSTEDELIJK GEWEST
# , 5 MAART 2020., - Besluit van de Brusselse Hoofdstedelijke Regering tot wijziging van het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen in het kader van de overname van de dienst van de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling door het Brussels Hoofdstedelijk Gewest
#
#
# De Brusselse Hoofdstedelijke Regering,
# , Gelet op de bijzondere wet van 8 augustus 1980 tot hervorming der instellingen, artikel 20;
# , Gelet op het Wetboek van de met inkomstenbelastingen gelijkgestelde belastingen, artikelen, 5, Â§, 1, tweede lid, gewijzigd bij de ordonnantie van 28 november 2019;
# , Gelet op het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen;
# , Gelet op de gelijkekansentest uitgevoerd op 22 november 2019 in toepassing van artikel 2 van de ordonnantie van 4 oktober 2018 tot invoering van de gelijkekansentest;
# , Gelet op advies 66.928/4 van de Raad van State, gegeven op 12 februari 2020, met toepassing van artikel 84, Â§ 1, eerste lid, 2Â°, van de wetten op de Raad van State, gecoÃ¶rdineerd op 12 januari 1973;
# , Overwegende dat de ordonnantie van 28 november 2019 tot wijziging van het Wetboek van de met inkomstenbelastingen gelijkgestelde belastingen in het kader van de overname van de dienst van de verkeersbelasting op de autovoertuigen en van de belasting op de inverkeerstelling door het Brussels Hoofdstedelijk Gewest, in zijn artikelen 3, 1Â°, a), iv, et b), 12, 13 en 15, 2Â° en 3Â° de bepalingen die momenteel vervat zijn in de artikelen 15, Â§ 1, en 58 van het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen, heeft geÃ¯ntegreerd in de artikelen, 5, eerste lid, 3Â° bis, en tweede lid, en 96, eerste lid, 3Â°, a) en tweede lid van het Wetboek van de met inkomstenbelastingen gelijkgestelde belastingen; dat deze bepalingen derhalve moeten worden opgeheven;,
# , Overwegende dat de ordonnantie van 19 december 2019 houdende de wijziging van de procedurele bepalingen in het kader van de overname van de dienst van de verkeersbelastingen en houdende diverse bepalingen tot gevolg heeft dat de ordonnantie van 6 maart 2019 betreffende de Brusselse Codex, Fiscale Procedure en haar uitvoeringsbesluit van toepassing zijn op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit ontstaat vanaf 1 januari 2020; dat de procedurele bepalingen vervat in Titel I van de het besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen, dus, voor wat deze belastingen betreft, moeten worden opgeheven, voor zover hun doel rechtstreeks wordt overgenomen in de genoemde Codex en zijn uitvoeringsbesluiten;
# , Op voorstel van de Minister van FinanciÃ«n, na beraadslaging,
# , Besluit :
# , HOOFDSTUK 1., -, Inleidende bepaling
# , Artikel 1., Dit besluit is uitsluitend van toepassing op:
# 1Â°, de verkeersbelasting op de autovoertuigen;
# 2Â, ° de belasting op de inverkeerstelling.,
# , HOOFDSTUK 2., - Wijzigingen van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit vÃ³Ã³r 1 januari 2020 valt
# Art. 2., De bepalingen van dit hoofdstuk zijn uitsluitend van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit vÃ³Ã³r 1 januari 2020 valt.,
# , Art. 3., Artikel 8 van het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen, vervangen bij het koninklijk besluit van 27 februari 2019, wordt vervangen als volgt:
# "Art. 8., Onverminderd de bepalingen van artikel 24, zijn de met de inkomstenbelastingen gelijkgestelde belastingen te betalen bij de rekenplichtige van de ontvangsten belast met fiscale zaken van de Gewestelijke Overheidsdienst, Brussel, Fiscaliteit of, in geval van zijn afwezigheid, bij de plaatsvervangend rekenplichtige van de ontvangsten belast met fiscale zaken van dezelfde dienst., ".,
# , Art. 4., In artikel 11 van hetzelfde besluit, gewijzigd bij het koninklijk besluit van 14 april 1993 en bij het koninklijk besluit van 9 november 1999 en vervangen bij het koninklijk besluit van 17 februari 2019, worden de woorden " op de financiÃ«le rekening van het ontvangkantoor Belastingen-auto's" vervangen door de woorden "volgens de door de Gewestelijke Overheidsdienst, Brussel, Fiscaliteit aangegeven modaliteiten".,
# , HOOFDSTUK 3., - Wijzigingen van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit vanaf 1 januari 2020 valt
# Art. 5., De bepalingen van dit hoofdstuk zijn uitsluitend van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit vanaf 1 januari 2020 valt.,
# , Art. 6., In artikel 15 van hetzelfde besluit, gewijzigd bij het koninklijk besluit van 10 november 1980 en bij de wet van 19 februari 1990, worden de volgende wijzigingen aangebracht :
# 1Â° paragraaf 1 wordt opgeheven;
# 2Â° in paragraaf 2 worden de volgende wijzigingen aangebracht:
# a) in de bepaling onder 1Â° worden de woorden "wet van 27 december 1974 betreffende de taxidiensten en ingericht krachtens een vergunning regelmatig afgeleverd ter uitvoering van gezegde wet" vervangen door de woorden "toepasselijke gewestelijke regelgeving en ingericht krachtens een vergunning regelmatig afgeleverd ter uitvoering van de genoemde regelgeving";
# b), de bepaling onder 2Â° wordt vervangen als volgt:
# "2Â° op de autovoertuigen die uitsluitend aangewend worden tot een dienst voor het verhuren van voertuigen met bestuurder onder de voorwaarden bepaald bij de toepasselijke gewestelijke regelgeving en ingericht krachtens een vergunning regelmatig afgeleverd ter uitvoering van de genoemde regelgeving;, ".,
# , Art. 7., In hetzelfde besluit worden de volgende bepalingen opgeheven:
# 1Â°, de titel I, die bestaat uit de artikelen 1 tot en met 14 ;
# 2Â° het hoofdstuk III van titel II, dat bestaat uit de artikelen 23 en 24;
# 3Â°, het hoofdstuk IV van titel II, dat bestaat uit de artikelen 25 en 26;
# 4Â°, het hoofdstuk V van titel II, dat bestaat uit de artikelen 27 tot en met 29;
# 5Â° in het titel V, artikel 58, gewijzigd bij het koninklijk besluit van 14 april 1993.,
# , HOOFDSTUK 4., - Wijzigingen van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling ongeacht de datum van het belastbaar feit
# Art. 8., In artikel 30, Â§ 2, van hetzelfde besluit opnieuw opgenomen bij het koninklijk besluit van 17 december 1984, worden de volgende wijzigingen aangebracht:
# 1Â° in het eerste lid worden de woorden "gedaan door middel van een formulier dat door Administratie der directe belastingen wordt verstrekt" vervangen door de woorden "ingediend bij de Gewestelijke Overheidsdienst, Brussel, Fiscaliteit";
# , 2Â, °, het tweede lid wordt opgeheven.,
# , HOOFDSTUK 5., - Inwerkingtreding en uitvoering
# Art. 9., Dit besluit heeft uitwerking met ingang van 1 januari 2020.,
# Art. 10., De Minister bevoegd voor FinanciÃ«n is belast met de uitvoering van dit besluit.,
# , Brussel, 5 maart 2020.,
# , Voor de Brusselse Hoofdstedelijke Regering :
# , De Minister-President van de Brusselse Hoofdstedelijke Regering,
# , R. VERVOORT
# , De Minister van de Brusselse Hoofdstedelijke Regering, belast met FinanciÃ«n, Begroting, Openbaar ambt en de Promotie van Meertaligheid,
# S. GATZ
# ]

# %%
#Calculate the most important sentences by adding the word frequencies in each sentence.
sentence_scores = {}
for sent in sentence_tokens:
    for word in sent:
        if word.text.lower() in word_frequencies.keys():
            if sent not in sentence_scores.keys():                            
             sentence_scores[sent]=word_frequencies[word.text.lower()]
            else:
             sentence_scores[sent]+=word_frequencies[word.text.lower()]

# %%
#Print sentence scores
sentence_scores
# Out:
# {5 MAART 2020.: 0.8500000000000001,
#  - Besluit van de Brusselse Hoofdstedelijke Regering tot wijziging van het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen in het kader van de overname van de dienst van de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling door het Brussels Hoofdstedelijk Gewest
#
#
#  De Brusselse Hoofdstedelijke Regering,: 8.300000000000002,
#  Gelet op de bijzondere wet van 8 augustus 1980 tot hervorming der instellingen, artikel 20;: 1.4000000000000001,
#  Gelet op het Wetboek van de met inkomstenbelastingen gelijkgestelde belastingen, artikelen: 1.85,
#  5, Â§: 0.3,
#  1, tweede lid, gewijzigd bij de ordonnantie van 28 november 2019;: 2.4,
#  Gelet op het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen;: 4.75,
#  Gelet op de gelijkekansentest uitgevoerd op 22 november 2019 in toepassing van artikel 2 van de ordonnantie van 4 oktober 2018 tot invoering van de gelijkekansentest;: 2.5499999999999994,
#  Gelet op advies 66.928/4 van de Raad van State, gegeven op 12 februari 2020, met toepassing van artikel 84, Â§ 1, eerste lid, 2Â°, van de wetten op de Raad van State, gecoÃ¶rdineerd op 12 januari 1973;: 4.449999999999999,
#  Overwegende dat de ordonnantie van 28 november 2019 tot wijziging van het Wetboek van de met inkomstenbelastingen gelijkgestelde belastingen in het kader van de overname van de dienst van de verkeersbelasting op de autovoertuigen en van de belasting op de inverkeerstelling door het Brussels Hoofdstedelijk Gewest, in zijn artikelen 3, 1Â°, a), iv, et b), 12, 13 en 15, 2Â° en 3Â° de bepalingen die momenteel vervat zijn in de artikelen 15, Â§ 1, en 58 van het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen, heeft geÃ¯ntegreerd in de artikelen: 16.25,
#  5, eerste lid, 3Â° bis, en tweede lid, en 96, eerste lid, 3Â°, a) en tweede lid van het Wetboek van de met inkomstenbelastingen gelijkgestelde belastingen; dat deze bepalingen derhalve moeten worden opgeheven;: 6.75,
#  Overwegende dat de ordonnantie van 19 december 2019 houdende de wijziging van de procedurele bepalingen in het kader van de overname van de dienst van de verkeersbelastingen en houdende diverse bepalingen tot gevolg heeft dat de ordonnantie van 6 maart 2019 betreffende de Brusselse Codex: 4.199999999999999,
#  Fiscale Procedure en haar uitvoeringsbesluit van toepassing zijn op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit ontstaat vanaf 1 januari 2020; dat de procedurele bepalingen vervat in Titel I van de het besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen, dus, voor wat deze belastingen betreft, moeten worden opgeheven, voor zover hun doel rechtstreeks wordt overgenomen in de genoemde Codex en zijn uitvoeringsbesluiten;: 11.150000000000004,
#  Op voorstel van de Minister van FinanciÃ«n, na beraadslaging,: 0.45,
#  Besluit :: 0.95,
#  HOOFDSTUK 1.: 0.9,
#  Inleidende bepaling: 0.15,
#  Artikel 1.: 1.05,
#  Dit besluit is uitsluitend van toepassing op:
#  1Â°: 2.5999999999999996,
#  de verkeersbelasting op de autovoertuigen;
#  2Â: 0.95,
#  ° de belasting op de inverkeerstelling.: 1.9,
#  HOOFDSTUK 2.: 0.5,
#  - Wijzigingen van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit vÃ³Ã³r 1 januari 2020 valt
#  Art. 2.: 5.2,
#  De bepalingen van dit hoofdstuk zijn uitsluitend van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit vÃ³Ã³r 1 januari 2020 valt.: 5.7,
#  Art. 3.: 0.15,
#  Artikel 8 van het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen, vervangen bij het koninklijk besluit van 27 februari 2019, wordt vervangen als volgt:
#  "Art. 8.: 9.049999999999999,
#  Onverminderd de bepalingen van artikel 24, zijn de met de inkomstenbelastingen gelijkgestelde belastingen te betalen bij de rekenplichtige van de ontvangsten belast met fiscale zaken van de Gewestelijke Overheidsdienst: 3.150000000000001,
#  Fiscaliteit of, in geval van zijn afwezigheid, bij de plaatsvervangend rekenplichtige van de ontvangsten belast met fiscale zaken van dezelfde dienst.: 1.0,
#  Art. 4.: 0.15,
#  In artikel 11 van hetzelfde besluit, gewijzigd bij het koninklijk besluit van 14 april 1993 en bij het koninklijk besluit van 9 november 1999 en vervangen bij het koninklijk besluit van 17 februari 2019, worden de woorden " op de financiÃ«le rekening van het ontvangkantoor Belastingen-auto's" vervangen door de woorden "volgens de door de Gewestelijke Overheidsdienst: 9.450000000000001,
#  Fiscaliteit aangegeven modaliteiten".: 0.1,
#  HOOFDSTUK 3.: 0.4,
#  - Wijzigingen van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit vanaf 1 januari 2020 valt
#  Art. 5.: 5.25,
#  De bepalingen van dit hoofdstuk zijn uitsluitend van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit vanaf 1 januari 2020 valt.: 5.7,
#  Art. 6.: 0.1,
#  In artikel 15 van hetzelfde besluit, gewijzigd bij het koninklijk besluit van 10 november 1980 en bij de wet van 19 februari 1990, worden de volgende wijzigingen aangebracht :
#  1Â° paragraaf 1 wordt opgeheven;
#  2Â° in paragraaf 2 worden de volgende wijzigingen aangebracht:
#  a) in de bepaling onder 1Â° worden de woorden "wet van 27 december 1974 betreffende de taxidiensten en ingericht krachtens een vergunning regelmatig afgeleverd ter uitvoering van gezegde wet" vervangen door de woorden "toepasselijke gewestelijke regelgeving en ingericht krachtens een vergunning regelmatig afgeleverd ter uitvoering van de genoemde regelgeving";
#  b): 14.400000000000006,
#  de bepaling onder 2Â° wordt vervangen als volgt:
#  "2Â° op de autovoertuigen die uitsluitend aangewend worden tot een dienst voor het verhuren van voertuigen met bestuurder onder de voorwaarden bepaald bij de toepasselijke gewestelijke regelgeving en ingericht krachtens een vergunning regelmatig afgeleverd ter uitvoering van de genoemde regelgeving;: 5.400000000000001,
#  Art. 7.: 0.05,
#  In hetzelfde besluit worden de volgende bepalingen opgeheven:
#  1Â°: 3.05,
#  de titel I, die bestaat uit de artikelen 1 tot en met 14 ;
#  2Â° het hoofdstuk III van titel II, dat bestaat uit de artikelen 23 en 24;
#  3Â°: 4.9,
#  het hoofdstuk IV van titel II, dat bestaat uit de artikelen 25 en 26;
#  4Â°: 2.25,
#  het hoofdstuk V van titel II, dat bestaat uit de artikelen 27 tot en met 29;
#  5Â° in het titel V, artikel 58, gewijzigd bij het koninklijk besluit van 14 april 1993.: 5.1,
#  HOOFDSTUK 4.: 0.4,
#  - Wijzigingen van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling ongeacht de datum van het belastbaar feit
#  Art. 8.: 3.5999999999999996,
#  In artikel 30, Â§ 2, van hetzelfde besluit opnieuw opgenomen bij het koninklijk besluit van 17 december 1984, worden de volgende wijzigingen aangebracht:
#  1Â° in het eerste lid worden de woorden "gedaan door middel van een formulier dat door Administratie der directe belastingen wordt verstrekt" vervangen door de woorden "ingediend bij de Gewestelijke Overheidsdienst: 7.499999999999999,
#  °: 1.0,
#  het tweede lid wordt opgeheven.: 0.8500000000000001,
#  HOOFDSTUK 5.: 0.55,
#  - Inwerkingtreding en uitvoering
#  Art. 9.: 0.35,
#  Dit besluit heeft uitwerking met ingang van 1 januari 2020.: 2.5000000000000004,
#
#  Art. 10.: 0.1,
#  De Minister bevoegd voor FinanciÃ«n is belast met de uitvoering van dit besluit.: 1.8,
#  Brussel, 5 maart 2020.: 0.8500000000000001,
#  De Minister van de Brusselse Hoofdstedelijke Regering, belast met FinanciÃ«n, Begroting, Openbaar ambt en de Promotie van Meertaligheid,
#  S. GATZ: 0.6000000000000001}

# %%
#From headhq import nlargest and calculate  30% of text with maximum score.
from heapq import nlargest
select_length=int(len(sentence_tokens)*0.3)
select_length
summary=nlargest(select_length, sentence_scores,key=sentence_scores.get)
summary
# Out:
# [Overwegende dat de ordonnantie van 28 november 2019 tot wijziging van het Wetboek van de met inkomstenbelastingen gelijkgestelde belastingen in het kader van de overname van de dienst van de verkeersbelasting op de autovoertuigen en van de belasting op de inverkeerstelling door het Brussels Hoofdstedelijk Gewest, in zijn artikelen 3, 1Â°, a), iv, et b), 12, 13 en 15, 2Â° en 3Â° de bepalingen die momenteel vervat zijn in de artikelen 15, Â§ 1, en 58 van het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen, heeft geÃ¯ntegreerd in de artikelen,
#  In artikel 15 van hetzelfde besluit, gewijzigd bij het koninklijk besluit van 10 november 1980 en bij de wet van 19 februari 1990, worden de volgende wijzigingen aangebracht :
#  1Â° paragraaf 1 wordt opgeheven;
#  2Â° in paragraaf 2 worden de volgende wijzigingen aangebracht:
#  a) in de bepaling onder 1Â° worden de woorden "wet van 27 december 1974 betreffende de taxidiensten en ingericht krachtens een vergunning regelmatig afgeleverd ter uitvoering van gezegde wet" vervangen door de woorden "toepasselijke gewestelijke regelgeving en ingericht krachtens een vergunning regelmatig afgeleverd ter uitvoering van de genoemde regelgeving";
#  b),
#  Fiscale Procedure en haar uitvoeringsbesluit van toepassing zijn op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit ontstaat vanaf 1 januari 2020; dat de procedurele bepalingen vervat in Titel I van de het besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen, dus, voor wat deze belastingen betreft, moeten worden opgeheven, voor zover hun doel rechtstreeks wordt overgenomen in de genoemde Codex en zijn uitvoeringsbesluiten;,
#  In artikel 11 van hetzelfde besluit, gewijzigd bij het koninklijk besluit van 14 april 1993 en bij het koninklijk besluit van 9 november 1999 en vervangen bij het koninklijk besluit van 17 februari 2019, worden de woorden " op de financiÃ«le rekening van het ontvangkantoor Belastingen-auto's" vervangen door de woorden "volgens de door de Gewestelijke Overheidsdienst,
#  Artikel 8 van het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen, vervangen bij het koninklijk besluit van 27 februari 2019, wordt vervangen als volgt:
#  "Art. 8.,
#  - Besluit van de Brusselse Hoofdstedelijke Regering tot wijziging van het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen in het kader van de overname van de dienst van de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling door het Brussels Hoofdstedelijk Gewest
#
#
#  De Brusselse Hoofdstedelijke Regering,,
#  In artikel 30, Â§ 2, van hetzelfde besluit opnieuw opgenomen bij het koninklijk besluit van 17 december 1984, worden de volgende wijzigingen aangebracht:
#  1Â° in het eerste lid worden de woorden "gedaan door middel van een formulier dat door Administratie der directe belastingen wordt verstrekt" vervangen door de woorden "ingediend bij de Gewestelijke Overheidsdienst,
#  5, eerste lid, 3Â° bis, en tweede lid, en 96, eerste lid, 3Â°, a) en tweede lid van het Wetboek van de met inkomstenbelastingen gelijkgestelde belastingen; dat deze bepalingen derhalve moeten worden opgeheven;,
#  De bepalingen van dit hoofdstuk zijn uitsluitend van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit vÃ³Ã³r 1 januari 2020 valt.,
#  De bepalingen van dit hoofdstuk zijn uitsluitend van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit vanaf 1 januari 2020 valt.,
#  de bepaling onder 2Â° wordt vervangen als volgt:
#  "2Â° op de autovoertuigen die uitsluitend aangewend worden tot een dienst voor het verhuren van voertuigen met bestuurder onder de voorwaarden bepaald bij de toepasselijke gewestelijke regelgeving en ingericht krachtens een vergunning regelmatig afgeleverd ter uitvoering van de genoemde regelgeving;,
#  - Wijzigingen van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit vanaf 1 januari 2020 valt
#  Art. 5.,
#  - Wijzigingen van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit vÃ³Ã³r 1 januari 2020 valt
#  Art. 2.,
#  het hoofdstuk V van titel II, dat bestaat uit de artikelen 27 tot en met 29;
#  5Â° in het titel V, artikel 58, gewijzigd bij het koninklijk besluit van 14 april 1993.,
#  de titel I, die bestaat uit de artikelen 1 tot en met 14 ;
#  2Â° het hoofdstuk III van titel II, dat bestaat uit de artikelen 23 en 24;
#  3Â°,
#  Gelet op het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen;,
#  Gelet op advies 66.928/4 van de Raad van State, gegeven op 12 februari 2020, met toepassing van artikel 84, Â§ 1, eerste lid, 2Â°, van de wetten op de Raad van State, gecoÃ¶rdineerd op 12 januari 1973;,
#  Overwegende dat de ordonnantie van 19 december 2019 houdende de wijziging van de procedurele bepalingen in het kader van de overname van de dienst van de verkeersbelastingen en houdende diverse bepalingen tot gevolg heeft dat de ordonnantie van 6 maart 2019 betreffende de Brusselse Codex,
#  - Wijzigingen van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling ongeacht de datum van het belastbaar feit
#  Art. 8.,
#  Onverminderd de bepalingen van artikel 24, zijn de met de inkomstenbelastingen gelijkgestelde belastingen te betalen bij de rekenplichtige van de ontvangsten belast met fiscale zaken van de Gewestelijke Overheidsdienst,
#  In hetzelfde besluit worden de volgende bepalingen opgeheven:
#  1Â°,
#  Dit besluit is uitsluitend van toepassing op:
#  1Â°,
#  Gelet op de gelijkekansentest uitgevoerd op 22 november 2019 in toepassing van artikel 2 van de ordonnantie van 4 oktober 2018 tot invoering van de gelijkekansentest;]

# %%
#Get the summary of text
final_summary=[word.text for word in summary]
final_summary
summary=''.join(final_summary)
summary
# Out:
# 'Overwegende dat de ordonnantie van 28 november 2019 tot wijziging van het Wetboek van de met inkomstenbelastingen gelijkgestelde belastingen in het kader van de overname van de dienst van de verkeersbelasting op de autovoertuigen en van de belasting op de inverkeerstelling door het Brussels Hoofdstedelijk Gewest, in zijn artikelen 3, 1Â°, a), iv, et b), 12, 13 en 15, 2Â° en 3Â° de bepalingen die momenteel vervat zijn in de artikelen 15, Â§ 1, en 58 van het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen, heeft geÃ¯ntegreerd in de artikelenIn artikel 15 van hetzelfde besluit, gewijzigd bij het koninklijk besluit van 10 november 1980 en bij de wet van 19 februari 1990, worden de volgende wijzigingen aangebracht :\n1Â° paragraaf 1 wordt opgeheven;\n2Â° in paragraaf 2 worden de volgende wijzigingen aangebracht:\na) in de bepaling onder 1Â° worden de woorden "wet van 27 december 1974 betreffende de taxidiensten en ingericht krachtens een vergunning regelmatig afgeleverd ter uitvoering van gezegde wet" vervangen door de woorden "toepasselijke gewestelijke regelgeving en ingericht krachtens een vergunning regelmatig afgeleverd ter uitvoering van de genoemde regelgeving";\nb)Fiscale Procedure en haar uitvoeringsbesluit van toepassing zijn op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit ontstaat vanaf 1 januari 2020; dat de procedurele bepalingen vervat in Titel I van de het besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen, dus, voor wat deze belastingen betreft, moeten worden opgeheven, voor zover hun doel rechtstreeks wordt overgenomen in de genoemde Codex en zijn uitvoeringsbesluiten;\nIn artikel 11 van hetzelfde besluit, gewijzigd bij het koninklijk besluit van 14 april 1993 en bij het koninklijk besluit van 9 november 1999 en vervangen bij het koninklijk besluit van 17 februari 2019, worden de woorden " op de financiÃ«le rekening van het ontvangkantoor Belastingen-auto\'s" vervangen door de woorden "volgens de door de Gewestelijke OverheidsdienstArtikel 8 van het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen, vervangen bij het koninklijk besluit van 27 februari 2019, wordt vervangen als volgt:\n"Art. 8.- Besluit van de Brusselse Hoofdstedelijke Regering tot wijziging van het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen in het kader van de overname van de dienst van de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling door het Brussels Hoofdstedelijk Gewest\n\n\nDe Brusselse Hoofdstedelijke Regering,\nIn artikel 30, Â§ 2, van hetzelfde besluit opnieuw opgenomen bij het koninklijk besluit van 17 december 1984, worden de volgende wijzigingen aangebracht:\n1Â° in het eerste lid worden de woorden "gedaan door middel van een formulier dat door Administratie der directe belastingen wordt verstrekt" vervangen door de woorden "ingediend bij de Gewestelijke Overheidsdienst5, eerste lid, 3Â° bis, en tweede lid, en 96, eerste lid, 3Â°, a) en tweede lid van het Wetboek van de met inkomstenbelastingen gelijkgestelde belastingen; dat deze bepalingen derhalve moeten worden opgeheven;De bepalingen van dit hoofdstuk zijn uitsluitend van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit vÃ³Ã³r 1 januari 2020 valt.De bepalingen van dit hoofdstuk zijn uitsluitend van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit vanaf 1 januari 2020 valt.de bepaling onder 2Â° wordt vervangen als volgt:\n"2Â° op de autovoertuigen die uitsluitend aangewend worden tot een dienst voo ...

# %%
len(summary)
# Out:
# 6165

# %%
# all the texts together
# import glob 

# path = 'text_nl/*.txt'

# all_texts=""

# for file in glob.glob(path):
#     with open(file, encoding='utf-8', errors='ignore') as file_in:
#         text = file_in.read()
#         all_texts+=text
#         lines = text.split('\n')
#         for line in lines:
#             line = nlp(line)
#             for token in line:
#                 print(token)

# %%
#len(all_texts)

# %%
#docs = list(nlp.pipe(all_texts), n_process=4)
# docs = nlp.pipe(all_texts, n_process=4)

# %%
# from collections import Counter

# all_laws = []

# for d in docs:
#     laws = [ent.text for ent in d.ents if ent.label_ == "LAW"]
#     all_laws.extend(laws)

# Counter(all_laws).most_common(2)

# %% [markdown]
# ### Creating a dataframe from files

# %%
#all the texts together
import glob 
pd.set_option('display.max_rows', None)
pd.set_option('max_colwidth', 400)
path = 'text_nl/*.txt'
#path = 'TaxRelatedFile.txt'

all_texts=""


dataframes = []

df = pd.DataFrame(columns = ["article_content"])

for file in glob.glob(path):
    with open(file, encoding='utf-8', errors='ignore') as file_in:
        dataframe = file_in.read().replace('\n', '')
        dataframes.append(dataframe)

#         text = file_in.read()
#         text = text
     #   df_temp = pd.read_fwf(file_in)
     #    df["article_content"] = pd.read_fwf(file_in)
        
        #df = pd.concat(text, axis=1)
#df = df.append(dataframes, ignore_index=True)
to_append = dataframes
my_series = pd.Series(to_append)
#df = df.append(my_series, ignore_index=True)
#df = pd.concat(my_series, ignore_index=True)

df["article_content"]= my_series
#pd.concat([df,pd.DataFrame(my_series)],axis=1)

# %%
df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                    article_content
# 0   Moniteur Belge - Belgisch Staatsblad <!--  hide jvscr code for old browsers  function NxtHit () {       window.status="volgende woord";       setTimeout ("window.status=' '",6000);}  function PrvHit () {       window.status="Vorige woord";       setTimeout ("window.status=' '",6000);}  function FirstHit () {       window.status="Eerste gevonden woord";       setTimeout ("window.status=' '",60...
# 1   Moniteur Belge - Belgisch Staatsblad <!--  hide jvscr code for old browsers  function NxtHit () {       window.status="volgende woord";       setTimeout ("window.status=' '",6000);}  function PrvHit () {       window.status="Vorige woord";       setTimeout ("window.status=' '",6000);}  function FirstHit () {       window.status="Eerste gevonden woord";       setTimeout ("window.status=' '",60...
# 2   Moniteur Belge - Belgisch Staatsblad <!--  hide jvscr code for old browsers  function NxtHit () {       window.status="volgende woord";       setTimeout ("window.status=' '",6000);}  function PrvHit () {       window.status="Vorige woord";       setTimeout ("window.status=' '",6000);}  function FirstHit () {       window.status="Eerste gevonden woord";       setTimeout ("window.status=' '",60...
# 3   Moniteur Belge - Belgisch Staatsblad <!--  hide jvscr code for old browsers  function NxtHit () {       window.status="volgende woord";       setTimeout ("window.status=' '",6000);}  function PrvHit () {       window.status="Vorige woord";       setTimeout ("window.status=' '",6000);}  function FirstHit () {       window.status="Eerste gevonden woord";       setTimeout ("window.status=' '",60...
# 4   Moniteur Belge - Belgisch Staatsblad <!--  hide jvscr code for old browsers  function NxtHit () {       window.status="volgende woord";       setTimeout ("window.status=' '",6000);}  function PrvHit () {       window.status="Vorige woord";       setTimeout ("window.status=' '",6000);}  function FirstHit () {       window.status="Eerste gevonden woord";       setTimeout ("window.status=' '",60...

# %%
df.iloc[[5]].to_string()
# Out:
# '                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...

# %%
df.iloc[[5]].to_string()

# %%
dataframes
# Out:
# ['BRUSSELS HOOFDSTEDELIJK GEWEST5 MAART 2020. - Besluit van de Brusselse Hoofdstedelijke Regering tot wijziging van het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen in het kader van de overname van de dienst van de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling door het Brussels Hoofdstedelijk GewestDe Brusselse Hoofdstedelijke Regering,Gelet op de bijzondere wet van 8 augustus 1980 tot hervorming der instellingen, artikel 20;Gelet op het Wetboek van de met inkomstenbelastingen gelijkgestelde belastingen, artikelen 5, § 1, tweede lid, gewijzigd bij de ordonnantie van 28 november 2019;Gelet op het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen;Gelet op de gelijkekansentest uitgevoerd op 22 november 2019 in toepassing van artikel 2 van de ordonnantie van 4 oktober 2018 tot invoering van de gelijkekansentest;Gelet op advies 66.928/4 van de Raad van State, gegeven op 12 februari 2020, met toepassing van artikel 84, § 1, eerste lid, 2°, van de wetten op de Raad van State, gecoördineerd op 12 januari 1973;Overwegende dat de ordonnantie van 28 november 2019 tot wijziging van het Wetboek van de met inkomstenbelastingen gelijkgestelde belastingen in het kader van de overname van de dienst van de verkeersbelasting op de autovoertuigen en van de belasting op de inverkeerstelling door het Brussels Hoofdstedelijk Gewest, in zijn artikelen 3, 1°, a), iv, et b), 12, 13 en 15, 2° en 3° de bepalingen die momenteel vervat zijn in de artikelen 15, § 1, en 58 van het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen, heeft geïntegreerd in de artikelen 5, eerste lid, 3° bis, en tweede lid, en 96, eerste lid, 3°, a) en tweede lid van het Wetboek van de met inkomstenbelastingen gelijkgestelde belastingen; dat deze bepalingen derhalve moeten worden opgeheven;Overwegende dat de ordonnantie van 19 december 2019 houdende de wijziging van de procedurele bepalingen in het kader van de overname van de dienst van de verkeersbelastingen en houdende diverse bepalingen tot gevolg heeft dat de ordonnantie van 6 maart 2019 betreffende de Brusselse Codex Fiscale Procedure en haar uitvoeringsbesluit van toepassing zijn op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit ontstaat vanaf 1 januari 2020; dat de procedurele bepalingen vervat in Titel I van de het besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen, dus, voor wat deze belastingen betreft, moeten worden opgeheven, voor zover hun doel rechtstreeks wordt overgenomen in de genoemde Codex en zijn uitvoeringsbesluiten;Op voorstel van de Minister van Financiën, na beraadslaging,Besluit :HOOFDSTUK 1. - Inleidende bepalingArtikel 1. Dit besluit is uitsluitend van toepassing op:1° de verkeersbelasting op de autovoertuigen;2° de belasting op de inverkeerstelling.HOOFDSTUK 2. - Wijzigingen van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit vóór 1 januari 2020 valtArt. 2. De bepalingen van dit hoofdstuk zijn uitsluitend van toepassing op de verkeersbelasting op de autovoertuigen en de belasting op de inverkeerstelling waarvan het belastbaar feit vóór 1 januari 2020 valt.Art. 3. Artikel 8 van het koninklijk besluit van 8 juli 1970 houdende de algemene verordening betreffende de met de inkomstenbelastingen gelijkgestelde belastingen, vervangen bij het koninklijk besluit van 27 februari 2019, wordt vervangen als volgt:"Art. 8. Onverminderd de bepalingen van artikel 24, zijn de met de inkomstenbelastingen gelijkgestelde belastingen te betalen bij de rekenplichtige van de ontvangsten belast met fiscale zaken van d ...
